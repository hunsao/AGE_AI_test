# %% [markdown]
# # SETUP

# %%
import os
import re
import ast
import json
import ollama
import random
import base64
import requests
import itertools
import numpy as np
import pandas as pd
from tqdm import tqdm
from PIL import Image
from scipy import stats
from itertools import product
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from typing import List, Optional
from concurrent.futures import ThreadPoolExecutor, as_completed
from pydantic import BaseModel, Field

# %% [markdown]
# # DF

# %%
folder_path = r'C:\Users\David\Documents\AGEAI\Scripts\OUTPUTS\ANDREA\06_08_midjourney_activities_parejo'

description_list = []

prompt_pattern = re.compile(r'(.*?)(?= --personalize| --style|$)', re.DOTALL)

for file_name in os.listdir(folder_path):
    if file_name.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.tiff')):
        file_path = os.path.join(folder_path, file_name)
        
        image = Image.open(file_path)
        
        info = image.info
        
        description = info.get('Description', None)
        
        if description:
            match = prompt_pattern.match(description)
            cleaned_description = match.group(1) if match else description
        else:
            cleaned_description = None
        
        description_list.append({'filename': file_name, 'prompt': cleaned_description})

df = pd.DataFrame(description_list, columns=['filename', 'prompt'])

df['codi'] = df['filename'].str.split('_').str[0]

df['age_group'] = df['filename'].apply(lambda x: 'older' if 'OP' in x else 'neutral')

df['ID_num'] = df['codi'].str.extract('(\d+)')

df['ID_num'] = pd.to_numeric(df['ID_num'])
df=df.sort_values(by='ID_num', ascending=True)

df = df.reset_index(drop=True)

df_older = df[df['age_group'] == 'older']
df_neutral = df[df['age_group'] == 'neutral']

df_older['ID'] = ''
for prompt in df_older['ID_num'].unique():
    df_subset = df_older[df_older['ID_num'] == prompt]
    count = 1
    for index, row in df_subset.iterrows():
        df_older.loc[index, 'ID'] = f'o_p{row["ID_num"]}_f{count}'
        count += 1

#df_older

df_neutral['ID'] = ''
for prompt in df_neutral['ID_num'].unique():
    df_subset = df_neutral[df_neutral['ID_num'] == prompt]
    count = 1
    for index, row in df_subset.iterrows():
        df_neutral.loc[index, 'ID'] = f'a_p{row["ID_num"]}_f{count}'
        count += 1

#df_neutral
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_16552\2913173971.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_older['ID'] = ''
# C:\Users\David\AppData\Local\Temp\ipykernel_16552\2913173971.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neutral['ID'] = ''

# %%
output_dir = "C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/CSV"

os.makedirs(output_dir, exist_ok=True)
df_older.to_csv(os.path.join(output_dir, "df_older.csv"), index=False)
df_neutral.to_csv(os.path.join(output_dir, "df_neutral.csv"), index=False)

# %%
# Comprimir imagenes
def reduce_image_size(image, max_width, max_height):
    width, height = image.size
    if width > max_width or height > max_height:
        image.thumbnail((max_width, max_height), Image.LANCZOS)
    return image

def process_images(input_folder, neutral_df, older_df, neutral_subfolder, older_subfolder):
    neutral_output_folder = os.path.join(input_folder, neutral_subfolder)
    older_output_folder = os.path.join(input_folder, older_subfolder)
    
    if not os.path.exists(neutral_output_folder):
        os.makedirs(neutral_output_folder)
    if not os.path.exists(older_output_folder):
        os.makedirs(older_output_folder)
    
    neutral_files = neutral_df['filename'].tolist()
    older_files = older_df['filename'].tolist()
    
    # Procesar imágenes
    for filename in os.listdir(input_folder):
        if filename.endswith('.png'):
            input_path = os.path.join(input_folder, filename)
            
            if filename in neutral_files:
                output_folder = neutral_output_folder
            elif filename in older_files:
                output_folder = older_output_folder
            else:
                print(f"Archivo no clasificado: {filename}")
                continue
            
            output_path = os.path.join(output_folder, os.path.splitext(filename)[0] + '.jpg')

            try:
                with Image.open(input_path) as img:
                    img = reduce_image_size(img, 1024, 1024)
                    img = img.convert('RGB')
                    img.save(output_path, 'JPEG', optimize=True, quality=85)
            except Exception as e:
                print(f"Error procesando {filename}: {e}")

    print("Proceso completado.")

input_folder = folder_path
neutral_subfolder = 'neutral_comp'
older_subfolder = 'older_comp'

process_images(input_folder, df_neutral, df_older, neutral_subfolder, older_subfolder)
# Out:
# Proceso completado.

# %% [markdown]
# # OLLAMA

# %%
prompts = {
  "gender": "Determine the gender of the person in the image. Choose one of the following: male, female, or none (if indeterminable). Return the answer in the following JSON format: {\"gender\": \"[gender]\"}.",
  "age_range": "Estimate the age range of the person in the image. Select from the following options: 18-24, 25-34, 35-44, 45-54, 55-64, 65-79, or 80+. Return the answer in the following JSON format: {\"age\": \"[range]\"}.",
  "race": "Identify the race of the person in the image. Choose from the following options: asian, black, white, hispanic, or other. Return the answer in the following JSON format: {\"race\": \"[race]\"}.",
  "emotions_short": "Identify the emotion expressed by the person in the image. Choose from the following: neutral, positive, negative, or exaggerated. Return the answer in the following JSON format: {\"emotion\": \"[emotion]\"}.",
  "personality_short": "Determine the personality trait expressed by the person in the image. Choose from the following options: Openness, Conscientiousness, Extraversion, Agreeableness, or Neuroticism. Return the answer in the following JSON format: {\"personality\": \"[personality]\"}.",
  "location": "Identify the setting of the image. Choose one of the following: indoors, outdoors, or none (if indeterminable). Return the answer in the following JSON format: {\"location\": \"[location]\"}.",
  "objects": "List up to 10 objects visible in the image. Return the list in the following JSON format: {\"objects\": [\"object\", ...]}.",
  "objects_assist_devices": "List any assistive devices visible in the image. Return the list in the following JSON format: {\"assistive_devices\": [\"object\", ...]}.",
  "objects_digi_devices": "List any digital devices visible in the image. Return the list in the following JSON format: {\"digital_devices\": [\"object\", ...]}.",
  "person_count": "Count the number of people visible in the image. Choose one of the following: 1, 2, 3, or +3. Return the answer in the following JSON format: {\"person_count\": \"[count]\"}.",
  "shot": "Identify the type of shot in the image. Choose one of the following options: close-up shot, medium shot, or full shot. Return the answer in the following JSON format: {\"shot\": \"[selected shot]\"}.",
  "position_short": "Describe the posture of the person in the image using one word. Examples: standing, sitting, lying. Return the answer in the following JSON format: {\"position\": \"[position]\"}."
}

# %%
# Define Pydantic models for each prompt output
class Gender(BaseModel):
    gender: str = Field(..., description="Gender of the person in the image (male, female, or none)")

class AgeRange(BaseModel):
    age: str = Field(..., description="Age range of the person in the image (18-24, 25-34, 35-44, 45-54, 55-64, 65-79, or 80+)")

class Race(BaseModel):
    race: str = Field(..., description="Race of the person in the image (asian, black, white, hispanic, or other)")

class Emotion(BaseModel):
    emotion: str = Field(..., description="Emotion expressed by the person in the image (neutral, positive, negative, or exaggerated)")

class Personality(BaseModel):
    personality: str = Field(..., description="Personality trait expressed by the person in the image (Openness, Conscientiousness, Extraversion, Agreeableness, or Neuroticism)")

class Location(BaseModel):
    location: str = Field(..., description="Setting of the image (indoors, outdoors, or none)")

class Objects(BaseModel):
    objects: List[str] = Field(..., description="List of up to 10 objects visible in the image")

class AssistiveDevices(BaseModel):
    assistive_devices: List[str] = Field(..., description="List of assistive devices visible in the image")

class DigitalDevices(BaseModel):
    digital_devices: List[str] = Field(..., description="List of digital devices visible in the image")

class PersonCount(BaseModel):
    person_count: str = Field(..., description="Number of people visible in the image (1, 2, 3, or +3)")

class Shot(BaseModel):
    shot: str = Field(..., description="Type of shot in the image (close-up shot, medium shot, or full shot)")

class Position(BaseModel):
    position: str = Field(..., description="Posture of the person in the image (e.g., standing, sitting, lying)")

class ImageAnalysisResults(BaseModel):
    ID_jpg: str = Field(..., description="Filename of the image")
    gender: Optional[Gender] = None
    age_range: Optional[AgeRange] = None
    race: Optional[Race] = None
    emotions_short: Optional[Emotion] = None
    personality_short: Optional[Personality] = None
    location: Optional[Location] = None
    objects: Optional[Objects] = None
    objects_assist_devices: Optional[AssistiveDevices] = None
    objects_digi_devices: Optional[DigitalDevices] = None
    person_count: Optional[PersonCount] = None
    shot: Optional[Shot] = None
    position_short: Optional[Position] = None
    error: Optional[str] = None

# %%
def call_ollama(image_path, prompt):
    try:
        with open(image_path, 'rb') as file:
            image_bytes = file.read()
        
        response = ollama.chat(
            model='llava:7b-v1.6-mistral-q8_0',
            #format='json',
            messages=[
                {
                    'role': 'system',
                    'content': """You are a helpful visual assistant. Analyze the following image and provide answers to these prompts. 
                    Be concise and precise in your answers, and provide only the information requested. Do not provide any additional information."""
                },
                {
                    'role': 'user',
                    'content': prompt,
                    'images': [image_bytes],
                },
            ],
             options= {
                 'seed': 123,
                 'temperature': 0}
         )
        return response['message']['content']
    except Exception as e:
        print(f"Error calling Ollama: {e}")
        return "Error"

# def process_image(image_path):
#     try:
#         results = {"ID_jpg": os.path.basename(image_path)}
        
#         for prompt_name, prompt_text in prompts.items():
#             results[prompt_name] = call_ollama(image_path, prompt_text)
        
#         return results
#     except Exception as e:
#         print(f"Error processing {image_path}: {e}")
#         return {"ID_jpg": os.path.basename(image_path), "error": str(e)}

def process_image(image_path):
    try:
        results = {"ID_jpg": os.path.basename(image_path)}
        
        for prompt_name, prompt_text in prompts.items():
            response_str = call_ollama(image_path, prompt_text)
            
            try:
                # Clean up the response string (if needed)
                response_str = response_str.strip() 
                if response_str.startswith("```json") and response_str.endswith("```"):
                    response_str = response_str[7:-3].strip()

                response_json = json.loads(response_str) # Use json.loads() for safer parsing

                # Validate JSON using Pydantic models
                if prompt_name == "gender":
                    results[prompt_name] = Gender(**response_json)
                elif prompt_name == "age_range":
                    results[prompt_name] = AgeRange(**response_json)
                elif prompt_name == "race":
                    results[prompt_name] = Race(**response_json)
                elif prompt_name == "emotions_short":
                    results[prompt_name] = Emotion(**response_json)
                elif prompt_name == "personality_short":
                    results[prompt_name] = Personality(**response_json)
                elif prompt_name == "location":
                    results[prompt_name] = Location(**response_json)
                elif prompt_name == "objects":
                    results[prompt_name] = Objects(**response_json)
                elif prompt_name == "objects_assist_devices":
                    results[prompt_name] = AssistiveDevices(**response_json)
                elif prompt_name == "objects_digi_devices":
                    results[prompt_name] = DigitalDevices(**response_json)
                elif prompt_name == "person_count":
                    results[prompt_name] = PersonCount(**response_json)
                elif prompt_name == "shot":
                    results[prompt_name] = Shot(**response_json)
                elif prompt_name == "position_short":
                    results[prompt_name] = Position(**response_json)

            except (json.JSONDecodeError, SyntaxError) as e:
                print(f"Error parsing JSON for {prompt_name} in {image_path}: {e}")

                # Attempt to fix the missing closing brace
                if isinstance(e, json.JSONDecodeError) and "Expecting ',' delimiter" in str(e):
                    try:
                        response_str += "}"  # Add the missing closing brace
                        response_json = json.loads(response_str)

                        # Re-attempt Pydantic validation with the fixed JSON for all prompts
                        if prompt_name == "gender":
                            results[prompt_name] = Gender(**response_json)
                        elif prompt_name == "age_range":
                            results[prompt_name] = AgeRange(**response_json)
                        # ... (Handle all other prompts similarly)

                    except (json.JSONDecodeError, SyntaxError) as e2:
                        print(f"Failed to fix JSON for {prompt_name} in {image_path} after adding closing brace: {e2}")
                        results[prompt_name] = response_str  # Store raw string if fixing fails

                else:
                    results[prompt_name] = response_str  # Store raw string if other parsing errors occur
        
        return ImageAnalysisResults(**results).model_dump() # Use model_dump for dictionary conversion

    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return ImageAnalysisResults(ID_jpg=os.path.basename(image_path), error=str(e)).model_dump() 

def process_folder(folder_path):
    all_results = []
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    for image_file in tqdm(image_files, desc="Processing images"):
        image_path = os.path.join(folder_path, image_file)
        results = process_image(image_path)
        all_results.append(results)
    
    return pd.DataFrame(all_results)

# %%
def call_ollama(image_path: str, prompt: str) -> str:
    try:
        with open(image_path, 'rb') as file:
            image_bytes = file.read()
        
        response = ollama.chat(
            model='llava:7b-v1.6-mistral-q8_0',
            messages=[
                {
                    'role': 'system',
                    'content': """You are a helpful visual assistant. Analyze the following image and provide answers to these prompts. 
                    Be concise and precise in your answers, and provide only the information requested in the exact JSON format specified."""
                },
                {
                    'role': 'user',
                    'content': prompt,
                    'images': [image_bytes],
                },
            ],
            options={'seed': 123, 'temperature': 0}
        )
        return response['message']['content']
    except Exception as e:
        print(f"Error calling Ollama: {e}")
        return json.dumps({"error": str(e)})

def clean_json_string(json_str: str) -> str:
    # Remove any leading/trailing whitespace and non-JSON content
    json_str = json_str.strip()
    if json_str.startswith("```json"):
        json_str = json_str[7:]
    if json_str.endswith("```"):
        json_str = json_str[:-3]
    return json_str.strip()

def parse_json_safely(json_str: str) -> dict:
    try:
        return json.loads(json_str)
    except json.JSONDecodeError as e:
        print(f"JSON Decode Error: {e}")
        # Attempt to fix common JSON errors
        if "Expecting ',' delimiter" in str(e):
            json_str += "}"
        elif "Expecting property name enclosed in double quotes" in str(e):
            json_str = json_str.replace("'", '"')
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return {"error": "Failed to parse JSON"}

def process_single_prompt(image_path: str, prompt_name: str, prompt_text: str) -> tuple:
    response_str = call_ollama(image_path, prompt_text)
    cleaned_response = clean_json_string(response_str)
    parsed_response = parse_json_safely(cleaned_response)
    
    try:
        if prompt_name == "gender":
            return prompt_name, Gender(**parsed_response)
        elif prompt_name == "age_range":
            return prompt_name, AgeRange(**parsed_response)
        # ... [Handle other prompt types] ...
        else:
            return prompt_name, parsed_response
    except Exception as e:
        print(f"Error validating {prompt_name} for {image_path}: {e}")
        return prompt_name, {"error": str(e)}

def process_image(image_path: str) -> ImageAnalysisResults:
    results = {"ID_jpg": os.path.basename(image_path)}
    
    with ThreadPoolExecutor(max_workers=5) as executor:
        future_to_prompt = {executor.submit(process_single_prompt, image_path, prompt_name, prompt_text): prompt_name 
                            for prompt_name, prompt_text in prompts.items()}
        
        for future in as_completed(future_to_prompt):
            prompt_name = future_to_prompt[future]
            try:
                prompt_name, result = future.result()
                results[prompt_name] = result
            except Exception as e:
                print(f"Error processing {prompt_name} for {image_path}: {e}")
                results[prompt_name] = {"error": str(e)}
    
    return ImageAnalysisResults(**results)

def process_folder(folder_path: str) -> pd.DataFrame:
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    all_results = []
    
    with ThreadPoolExecutor(max_workers=3) as executor:
        future_to_image = {executor.submit(process_image, os.path.join(folder_path, image_file)): image_file 
                           for image_file in image_files}
        
        for future in tqdm(as_completed(future_to_image), total=len(image_files), desc="Processing images"):
            image_file = future_to_image[future]
            try:
                result = future.result()
                all_results.append(result.model_dump())
            except Exception as e:
                print(f"Error processing {image_file}: {e}")
                all_results.append({"ID_jpg": image_file, "error": str(e)})
    
    return pd.DataFrame(all_results)

if __name__ == "__main__":
    input_folder = "C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic"
    output_file = "C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/neutral_pydantic_improved.csv"
    
    df_results = process_folder(input_folder)
    df_results.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")
# Out:
# Processing images:   0%|          | 0/5 [00:00<?, ?it/s]
# JSON Decode Error: Expecting ',' delimiter: line 1 column 21 (char 20)
# JSON Decode Error: Expecting ',' delimiter: line 1 column 21 (char 20)
# Processing images:  60%|██████    | 3/5 [01:56<00:55, 27.83s/it]
# JSON Decode Error: Expecting ',' delimiter: line 1 column 27 (char 26)
# JSON Decode Error: Expecting ',' delimiter: line 1 column 21 (char 20)
# JSON Decode Error: Expecting ',' delimiter: line 1 column 21 (char 20)
# Processing images: 100%|██████████| 5/5 [03:21<00:00, 40.27s/it]
# Results saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/neutral_pydantic_improved.csv

# %%
#NEUTRAL
#df_neutral_results = process_folder("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/neutral_comp")
#df_neutral_results.to_csv("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/CSV/neutral_analysis_llava.csv", index=False)

df_neutral_results = process_folder("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic")
df_neutral_results.to_csv("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/neutral_pydantic.csv", index=False)
print(f"Results saved")
# Out:
# Processing images:   0%|          | 0/5 [00:00<?, ?it/s]
# Error parsing JSON for person_count in C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic\103OP_Create_an_image_in_front_view_of_an_older_person_taking_98ee94f2-6af2-4a2c-a90a-d2b13e820f1e_1.png: Expecting ',' delimiter: line 1 column 21 (char 20)
# Processing images:  20%|██        | 1/5 [00:33<02:13, 33.34s/it]
# Error parsing JSON for location in C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic\103OP_Create_an_image_in_front_view_of_an_older_person_taking_98ee94f2-6af2-4a2c-a90a-d2b13e820f1e_2.png: Expecting ',' delimiter: line 1 column 24 (char 23)
# Error parsing JSON for person_count in C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic\103OP_Create_an_image_in_front_view_of_an_older_person_taking_98ee94f2-6af2-4a2c-a90a-d2b13e820f1e_2.png: Expecting ',' delimiter: line 1 column 21 (char 20)
# Processing images:  40%|████      | 2/5 [01:07<01:41, 33.67s/it]
# Error parsing JSON for person_count in C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic\103OP_Create_an_image_in_front_view_of_an_older_person_taking_98ee94f2-6af2-4a2c-a90a-d2b13e820f1e_3.png: Expecting ',' delimiter: line 1 column 21 (char 20)
# Processing images:  60%|██████    | 3/5 [01:47<01:13, 36.76s/it]
# Error parsing JSON for person_count in C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic\103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_0.png: Expecting ',' delimiter: line 1 column 21 (char 20)
# Processing images:  80%|████████  | 4/5 [02:26<00:37, 37.48s/it]
# Error parsing JSON for person_count in C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/AGOST/ANDREA/demo_pydantic\103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_1.png: Expecting ',' delimiter: line 1 column 21 (char 20)
# Processing images: 100%|██████████| 5/5 [03:01<00:00, 36.37s/it]
# Results saved

# %%
#OLDER
df_older_results = process_folder("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/older_comp")
df_older_results.to_csv("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/CSV/older_analysis_llava.csv", index=False)
print(f"Results saved")
# Out:
# Processing images: 100%|██████████| 403/403 [4:25:07<00:00, 39.47s/it]
# Results saved

# %% [markdown]
# # MERGE FINAL

# %%
output_dir = "C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/CSV/"

df_neutral = pd.read_csv(f'{output_dir}/df_neutral.csv')
df_older = pd.read_csv(f'{output_dir}/df_older.csv')
df_merged = pd.concat([df_neutral, df_older], axis=0)
df_merged = df_merged.rename(columns={'filename': 'filename_png'})
df_merged['filename_merge'] = df_merged['filename_png'].str.replace('.png', '')
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_1868\3562959006.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_merged['filename_merge'] = df_merged['filename_png'].str.replace('.png', '')

# %%
df_neutral_cv = pd.read_csv("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/CSV/neutral_analysis_llava.csv")
df_older_cv = pd.read_csv("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/CSV/older_analysis_llava.csv")

df_merged_2 = pd.concat([df_neutral_cv, df_older_cv], axis=0)
df_merged_2 = df_merged_2.rename(columns={'ID_jpg': 'filename_jpg'})

# %%
df_merged_2['filename_merge'] = df_merged_2['filename_jpg'].str.replace('.jpg', '')
df_merged = pd.merge(df_merged, df_merged_2, on='filename_merge', how='left')
df_merged = df_merged.drop(columns=["ID_num", "filename_merge"])
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_1868\300149777.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_merged_2['filename_merge'] = df_merged_2['filename_jpg'].str.replace('.jpg', '')

# %%
def clean_json(text):
    if isinstance(text, str):
        # Eliminar delimitadores de código y la etiqueta 'json'
        cleaned_text = re.sub(r'```json', '', text)  # Eliminar '```json'
        cleaned_text = re.sub(r'```', '', cleaned_text)  # Eliminar '```'
        
        # Utilizamos expresiones regulares para eliminar espacios alrededor de '{' y '}'
        cleaned_text = re.sub(r'\{\s+', '{', cleaned_text)
        cleaned_text = re.sub(r'\s+\}', '}', cleaned_text)
        
        # Eliminamos '\n' y luego eliminamos cualquier espacio en blanco adicional
        cleaned_text = cleaned_text.replace('\n', '').strip()
        
        return cleaned_text
    return text

# Definimos la función para asegurar el formato de lista
def ensure_list_format(value):
    if isinstance(value, str):
        try:
            # Intenta convertir la cadena a un diccionario
            data = ast.literal_eval(value)
            if isinstance(data, dict):
                for key in data:
                    # Verifica si el valor asociado a cada clave no está en una lista
                    if not isinstance(data[key], list):
                        data[key] = [data[key]]
                # Convierte el diccionario de vuelta a cadena
                return str(data)
            return value
        except:
            return value
    return value

# Lista de columnas que queremos transformar
columns_to_transform = [
    'gender', 
    'age_range', 
    'race', 
    'emotions_short', 
    'location', 
    'personality_short', 
    'shot', 
    'position_short',
    'objects',
    'objects_assist_devices',
    'objects_digi_devices',
    'person_count'
]

#excepto 'filename_png' y 'filename_jpg'
for column in df_merged.columns:
    if column not in ['filename_png', 'filename_jpg']:
        df_merged[column] = df_merged[column].apply(clean_json)
        df_merged[column] = df_merged[column].apply(lambda x: x.lower() if isinstance(x, str) else x)
        df_merged[column] = df_merged[column].apply(ensure_list_format)

# %%
df_merged['age_range'].unique()
# Out:
# array(["{'age': ['25-34']}", "{'age': ['18-24']}", "{'age': ['35-44']}",
#        "{'age': ['45-54']}", "{'age': ['65-79']}", "{'age': ['80+']}",
#        "{'age': ['55-64']}", '{"age": "[80+"]"}', '{{"age": "[80+]"}',
#        '{{"age": "[80+]"}.}'], dtype=object)

# %%
# Lista de valores válidos
valid_age_ranges = {'18-24', '25-34', '35-44', '45-54', '55-64', '65-79', '80+'}

def extract_and_format_age(age_str):
    # Limpiar espacios adicionales
    age_str = age_str.strip()
    
    # Intentar interpretar el string como un diccionario literal
    try:
        age_dict = ast.literal_eval(age_str)
    except (ValueError, SyntaxError):
        return age_str  # Si no se puede interpretar, devolver el string original
    
    # Extraer el valor de la clave 'age'
    if isinstance(age_dict, dict) and 'age' in age_dict:
        age_value = age_dict['age']
        
        # Si el valor es una lista, tomar el primer elemento
        if isinstance(age_value, list):
            age_value = age_value[0]
        
        # Limpiar corchetes y comillas adicionales
        if isinstance(age_value, str):
            # Usar expresiones regulares para extraer el texto deseado
            age_value = re.sub(r'[^\w\s\-+]', '', age_value)
            age_value = re.sub(r'\s+', '', age_value)  # Eliminar espacios adicionales
        
        # Verificar que el valor extraído esté en la lista de valores válidos
        if age_value in valid_age_ranges:
            return f"{{'age': ['{age_value}']}}"
    
    # Si no se puede formatear, devolver el valor original
    return age_str

df_merged['age_range'] = df_merged['age_range'].apply(extract_and_format_age)

# %%
#AGERANGE
mapping = {
    '{"age": "[80+"]"}': "{'age': ['80+']}",
    '{"age": "[80+"]"}': "{'age': ['80+']}",
    '{{"age": "[80+]"}': "{'age': ['80+']}",
    '{{"age": "[80+]"}.}': "{'age': ['80+']}",
}

df_merged['age_range'] = df_merged['age_range'].map(mapping).fillna(df_merged['age_range'])
df_merged['age_range'].unique()
# Out:
# array(["{'age': ['25-34']}", "{'age': ['18-24']}", "{'age': ['35-44']}",
#        "{'age': ['45-54']}", "{'age': ['65-79']}", "{'age': ['80+']}",
#        "{'age': ['55-64']}"], dtype=object)

# %%
df_merged
# Out:
#                                           filename_png  \
# 0    01P_a_person_walking_to_the_bathroom_in_photor...
# 1    01P_a_person_walking_to_the_bathroom_in_photor...
# 2    01P_a_person_walking_to_the_bathroom_in_photor...
# 3    01P_a_person_walking_to_the_bathroom_in_photor...
# 4    2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..                                                 ...
# 803  139OP_a_front_photo_of_an_older_person_doing_d...
# 804  140OP_an_older_person_at_the_hospital_in_photo...
# 805  140OP_an_older_person_at_the_hospital_in_photo...
# 806  140OP_an_older_person_at_the_hospital_in_photo...
# 807  140OP_an_older_person_at_the_hospital_in_photo...
#
#                                                 prompt   codi age_group  \
# 0    a person walking to the bathroom in photoreali...    01p   neutral
# 1    a person walking to the bathroom in photoreali...    01p   neutral
# 2    a person walking to the bathroom in photoreali...    01p   neutral
# 3    a person walking to the bathroom in photoreali...    01p   neutral
# 4    a front photo of a person walking to a store i...     2p   neutral
# ..                                                 ...    ...       ...
# 803  a front photo of an older person doing diet an...  139op     older
# 804  an older person at the hospital in photorealis...  140op     older
# 805  an older person at the hospital in photorealis...  140op     older
# 806  an older person at the hospital in photorealis...  140op     older
# 807  an older person at the hospital in photorealis...  140op     older
#
#             ID                                       filename_jpg  \
# 0      a_p1_f1  01P_a_person_walking_to_the_bathroom_in_photor...
# 1      a_p1_f2  01P_a_person_walking_to_the_bathroom_in_photor...
# 2      a_p1_f3  01P_a_person_walking_to_the_bathroom_in_photor...
# 3      a_p1_f4  01P_a_person_walking_to_the_bathroom_in_photor...
# 4      a_p2_f1  2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..         ...                                                ...
# 803  o_p139_f4  139OP_a_front_photo_of_an_older_person_doing_d...
# 804  o_p140_f1  140OP_an_older_person_at_the_hospital_in_photo...
# 805  o_p140_f2  140OP_an_older_person_at_the_hospital_in_photo...
# 806  o_p140_f3  140OP_an_older_person_at_the_hospital_in_photo...
# 807  o_p140_f4  140OP_an_older_person_at_the_hospital_in_photo...
#
#                      gender             age_range                 race  \
# 0      {'gender': ['male']}    {'age': ['25-34']}  {'race': ['white']}
# 1      {'gender': ['male']}    {'age': ['18-24']}  {'race': ['white']}
# 2      {'gender': ['male']}    {'age': ['25-34']}  {'race': ['white']}
# 3    {'gender': ['female']}    {'age': ['35-44']}  {'race': ['other']}
# 4      {'gender': ['male']}    {'age': ['25-34']}  {'race': ['white']}
# ..                      ...                   ...                  ...
# 803    {'gender': ['male']}    {'age': ['65-79']}  {'race': ['white']}
# 804    {'gender': ['male']}      {'age': ['80+']}  {'race': ['white']}
# 805    {'gender': ['male']}      {'age': ['80+']}  {'race': ['white']}
# 806    {'gender': ['male']}     {"age": "[65-79]"  {'race': ['white']}
# 807  {'gender': ['female']}  {'age': ['[65-79]']}  {'race': ['white']}
#
#                 emotions_short                       personality_short  \
# 0     {'emotion': ['neutral']}       {'personality': ['extraversion']}
# 1     {'emotion': ['neutral']}           {'personality': ['openness']}
# 2     {'emotion': ['neutral']}           {'personality': ['openness']}
# 3     {'emotion': ['neutral']}      {'personality': ['agreeableness']}
# 4     {'emotion': ['neutral']}  {'personality': ['conscientiousness']}
# ..                         ...                                     ...
# 803      {"emotion": "neutral"  {'personality': ['conscientiousness']}
# 804  {'emotion': ['negative']}      {'personality': ['agreeableness']}
# 805  {'emotion': ['negative']}      {'personality': ['agreeableness']}
# 806   {'emotion': ['neutral']}      {'personality': ['agreeableness']}
# 807  {'emotion': ['negative']}      {'personality': ['agreeableness']}
#
#                        location  \
# 0         {"location": "indoor"
# 1      {'location': ['indoor']}
# 2      {'location': ['indoor']}
# 3      {'location': ['indoor']}
# 4    {'location': ['outdoors']}
# ..                          ...
# 803       {"location": "indoor"
# 804    {'location': ['indoor']}
# 805   {'location': ['indoors']}
# 806   {'location': ['indoors']}
# 807       {"location": "indoor"
#
#                                                objects  \
# 0    {'objects': ['bathroom sink', 'glass door', 'l...
# 1    {'objects': ['person', 'doorway', 'wall tile',...
# 2    {'objects': ['person', 'sink', 'plant', 'doorw...
# 3    {'objects': ['person', 'sink', 'bathroom tiles...
# 4    {'objects': ['man walking on sidewalk', 'store...
# ..                                                 ...
# 803  {'objects': ['tablet', 'pen', 'book', 'wooden ...
# 804  {'objects': ['man', 'chair', 'waiting area', '...
# 805  {'objects': ['man', 'hospital bed', 'medical e...
# 806  {'objects': ['hospital bed', 'white pillowcase...
# 807  {'objects': ['person', 'hospital bed', 'headre...
#
#                                 objects_assist_devices  \
# 0    {'assistive_devices': ['no assistive devices a...
# 1                      {'assistive_devices': ['door']}
# 2                      {'assistive_devices': ['sink']}
# 3                      {'assistive_devices': ['sink']}
# 4                  {'assistive_devices': ['backpack']}
# ..                                                 ...
# 803                     {'assistive_devices': ['pen']}
# 804                    {'assistive_devices': ['cane']}
# 805                    {'assistive_devices': ['cane']}
# 806                          {'assistive_devices': []}
# 807               {'assistive_devices': ['headscarf']}
#
#                           objects_digi_devices             person_count  \
# 0                      {'digital_devices': []}     {"person_count": "1"
# 1                      {'digital_devices': []}     {"person_count": "1"
# 2                      {'digital_devices': []}     {"person_count": "1"
# 3                      {'digital_devices': []}     {"person_count": "1"
# 4            {'digital_devices': ['notebook']}     {"person_count": "1"
# ..                                         ...                      ...
# 803                    {'digital_devices': []}  {'person_count': ['1']}
# 804                    {'digital_devices': []}     {"person_count": "1"
# 805                    {'digital_devices': []}     {"person_count": "1"
# 806  {'digital_devices': ['computer monitor']}     {"person_count": "1"
# 807                    {'digital_devices': []}     {"person_count": "1"
#
#                             shot              position_short
# 0              {"shot": "medium"  {'position': ['standing']}
# 1           {'shot': ['medium']}  {'position': ['standing']}
# 2        {'shot': ['full shot']}  {'position': ['standing']}
# 3        {'shot': ['full shot']}  {'position': ['standing']}
# 4      {'shot': ['medium shot']}  {'position': ['standing']}
# ..                           ...                         ...
# 803  {'shot': ['close-up shot']}   {'position': ['sitting']}
# 804      {'shot': ['full shot']}   {'position': ['sitting']}
# 805      {'shot': ['full shot']}   {'position': ['sitting']}
# 806      {'shot': ['full shot']}     {'position': ['lying']}
# 807  {'shot': ['close-up shot']}     {'position': ['lying']}
#
# [808 rows x 18 columns]

# %%
#df_merged['gender'].unique()
#df_merged['race'].unique()
#df_merged['location'].unique()
#df_merged['emotions_short'].unique()
#df_merged['personality_short'].unique()
#df_merged['shot'].unique()
#df_merged['person_count'].unique()
# Out:
# array(['{"person_count": "1"', "{'person_count': ['1']}",
#        '{"person_count": "1"}.', '{"person_count": "0"}.',
#        "{'person_count': [1]}", '{"person_count": "2"',
#        "{'person_count': [0]}", '{"person_count": "3"',
#        "{'person_count': ['3']}", "{'person_count': [2]}",
#        '{"person_count": "4"', "{'person_count': ['2']}",
#        "{'person_count': [3]}", '{"person_count": "5"',
#        "{'person_count': ['4']}", "{'person_count': [4]}",
#        "{'person_count': ['9']}", "{'person_count': [6]}"], dtype=object)

# %%
# Función para estandarizar las entradas de la columna 'race'
def clean_race(race):
    # Encontrar la categoría dentro de la cadena usando regex
    match = re.search(r'["\']race["\']: ?\[?["\']?(\w+)["\']?\]?', race)
    if match:
        # Obtener la categoría encontrada
        category = match.group(1)
        # Retornar el formato estandarizado
        return f"{{'race': ['{category}']}}"
    else:
        # Si no se encuentra la categoría, retornar la entrada original
        return race

# Aplicar la función a la columna 'race'
df_merged['race'] = df_merged['race'].apply(clean_race)

# Verificar las categorías únicas después de la limpieza
df_merged['race'].unique()
# Out:
# array(["{'race': ['white']}", "{'race': ['other']}",
#        "{'race': ['[hispanic]']}", "{'race': ['asian']}",
#        "{'race': ['black']}", "{'race': ['hispanic']}",
#        "{'race': ['[white]']}"], dtype=object)

# %%
location_mapping = {
    "indoor": "indoor",
    "indoors": "indoor",
    "inddoors": "indoor",
    "indors": "indoor",
    "indors": "indoor",
    "indoor market": "indoor",
    "ind indoors": "indoor",
    "indindoors": "indoor",
    "outdoor": "outdoors",
    "outdoors": "outdoors",
    "indeterminate": "none",
    "indeterminable": "none",
    "none": "none"
}

# Función para limpiar y mapear los valores de 'location'
def clean_location(location):
    # Encontrar la categoría dentro de la cadena usando regex
    match = re.search(r'["\']location["\']: ?\[?["\']?([\w\s]+)["\']?\]?', location)
    if match:
        # Obtener la categoría encontrada
        category = match.group(1).strip().lower()
        # Mapear la categoría a la estándar
        category = location_mapping.get(category, 'none')  # Por defecto 'none' si no se encuentra el match
        # Retornar el formato estandarizado
        return f"{{'location': ['{category}']}}"
    else:
        # Si no se encuentra la categoría, retornar 'none' por defecto
        return "{'location': ['none']}"

# Aplicar la función a la columna 'location'
df_merged['location'] = df_merged['location'].apply(clean_location)

# Verificar las categorías únicas después de la limpieza
df_merged['location'].unique()
# Out:
# array(["{'location': ['indoor']}", "{'location': ['outdoors']}",
#        "{'location': ['none']}"], dtype=object)

# %%
import re

# Función para limpiar y estandarizar los valores en la columna 'personality_short'
def clean_personality(personality):
    # Encontrar la categoría dentro de la cadena usando regex
    match = re.search(r'["\']personality["\']: ?\[?["\']?(\w+)["\']?\]?', personality)
    if match:
        # Obtener la categoría encontrada
        category = match.group(1).strip().lower()
        # Retornar el formato estandarizado
        return f"{{'personality': ['{category}']}}"
    else:
        # Si no se encuentra la categoría, retornar la entrada original
        return personality

# Aplicar la función a la columna 'personality_short'
df_merged['personality_short'] = df_merged['personality_short'].apply(clean_personality)

# Verificar las categorías únicas después de la limpieza
df_merged['personality_short'].unique()
# Out:
# array(["{'personality': ['extraversion']}",
#        "{'personality': ['openness']}",
#        "{'personality': ['agreeableness']}",
#        "{'personality': ['conscientiousness']}",
#        "{'personality': ['neuroticism']}"], dtype=object)

# %%
# Diccionario para mapear los valores incorrectos a los correctos
shot_mapping = {
    "medium": "medium",
    "medium shot": "medium",
    "full": "full shot",
    "full shot": "full shot",
    "close-up": "close-up shot",
    "close-up shot": "close-up shot"
}

# Función para limpiar y estandarizar los valores en la columna 'shot'
def clean_shot(shot):
    # Encontrar la categoría dentro de la cadena usando regex
    match = re.search(r'["\']shot["\']: ?\[?["\']?([\w\s-]+)["\']?\]?', shot)
    if match:
        # Obtener la categoría encontrada
        category = match.group(1).strip().lower()
        # Mapear la categoría a la estándar
        category = shot_mapping.get(category, 'medium')  # Usar 'medium' por defecto si no se encuentra el match
        # Retornar el formato estandarizado
        return f"{{'shot': ['{category}']}}"
    else:
        # Si no se encuentra la categoría, retornar 'medium' por defecto
        return "{'shot': ['medium']}"

# Aplicar la función a la columna 'shot'
df_merged['shot'] = df_merged['shot'].apply(clean_shot)

# Verificar las categorías únicas después de la limpieza
df_merged['shot'].unique()
# Out:
# array(["{'shot': ['medium']}", "{'shot': ['full shot']}",
#        "{'shot': ['close-up shot']}"], dtype=object)

# %%
# Definir categorías específicas a las que se deben mapear los valores
specific_categories = {
    'standing': "{'position': ['standing']}",
    'sitting': "{'position': ['sitting']}",
    'lying': "{'position': ['lying']}",
    'crouched': "{'position': ['crouched']}",
    'none': "{'position': ['none']}",
    'walking': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'bending': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'no person present': "{'position': ['none']}",  # Agrupar como 'none'
    'kneeling': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'bending over': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'kissing': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'shaking hands': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'running': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'praying': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'squatting': "{'position': ['sitting']}",  # Agrupar bajo 'sitting'
    'crouching': "{'position': ['crouched']}",  # Agrupar bajo 'crouched'
    'kicking': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'climbing': "{'position': ['standing']}",  # Agrupar bajo 'standing'
    'brushing teeth': "{'position': ['standing']}"  # Agrupar bajo 'standing'
}

# Función para limpiar y mapear categorías
def map_to_specific_category(position_str):
    try:
        # Intentar convertir el valor a un diccionario Python
        position_dict = ast.literal_eval(position_str)
        # Extraer el valor de la clave 'position'
        position_value = position_dict.get('position', '')
        # Si 'position' es una lista, tomar el primer elemento
        if isinstance(position_value, list):
            simplified_value = specific_categories.get(position_value[0], position_value[0])
            return simplified_value
        return specific_categories.get(position_value, f"{{'position': ['{position_value}']}}")
    except (SyntaxError, ValueError) as e:
        # Manejar casos donde el formato sea incorrecto
        print(f"Error al procesar el valor: {position_str} - {e}")
        return "{'position': ['none']}"

# Aplicar la función a la columna 'position_short'
df_merged['position_short'] = df_merged['position_short'].apply(map_to_specific_category)

# Verificar el resultado
print(df_merged['position_short'].unique())
# Out:
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "lying" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "lying" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "sitting" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "sitting" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "sitting" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "sitting" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "sitting" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "squatting" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "sitting" - '{' was never closed (<unknown>, line 1)
# Error al procesar el valor: {"position": "standing" - '{' was never closed (<unknown>, line 1)
# ["{'position': ['standing']}" "{'position': ['none']}"
#  "{'position': ['sitting']}" "{'position': ['lying']}"
#  "{'position': ['crouched']}"]

# %%
#GENDER
df_merged['gender'].unique()
mapping = {
    '{"gender": "male"}': "{'gender': ['male']}",
    '{"gender": "female"}': "{'gender': ['female']}",
    '{"gender": "none"}': "{'gender': ['none']}",

    '{"gender": "male"': "{'gender': ['male']}",
    '{"gender": "male"}.': "{'gender': ['male']}",
    '{"gender": "female"': "{'gender': ['female']}",
    '{"gender": "none"': "{'gender': ['none']}",
}
df_merged['gender'] = df_merged['gender'].map(mapping).fillna(df_merged['gender'])
df_merged['gender'].unique()

#RACE
df_merged['race'].unique()
mapping = {
    '{"race": "white"}': "{'race': ['white']}",
    "{'race': ['[hispanic]']}": "{'race': ['hispanic']}",
    "{'race': ['[white]']}": "{'race': ['white']}",
}
df_merged['race'] = df_merged['race'].map(mapping).fillna(df_merged['race'])
df_merged['race'].unique()

#LOCATION
#df_merged['location'].unique()
# mapping = {
#     #'{"location": ["indoor"]}': '{"location": ["indoors"]}',
#     "{'location': ['indoor']}": "{'location': ['indoors']}",
#     #'{"location": "indoors"}': '{"location": ["indoors"]}',
#     #'{"location": "indoor"}': '{"location": ["indoors"]}',
#     "{'location': ['indors']}": "{'location': ['indoors']}",
#     "{'location': ['inddoors']}": "{'location': ['indoors']}",  
#     "{'location': ['individual']}": "{'location': ['indoors']}",  
#     "{'location': ['indicators']}": "{'location': ['indoors']}",  
# }
# df_merged['location'] = df_merged['location'].map(mapping).fillna(df_merged['location'])
# df_merged['location'].unique()

#EMTOIONS SHORT
df_merged['emotions_short'].unique()
mapping = {
    '{"emotion": "neutral"}': '{"emotion": ["neutral"]}',
    '{"emotion": "positive"}': '{"emotion": ["positive"]}',
    '{"emotion": "negative"}': '{"emotion": ["negative"]}',
    '{"emotion": "neutral"': "{'emotion': ['neutral']}",
    '{"emotion": "positive"': "{'emotion': ['positive']}",
    '{"emotion": "negative"': "{'emotion': ['negative']}",
}

df_merged['emotions_short'] = df_merged['emotions_short'].map(mapping).fillna(df_merged['emotions_short'])
df_merged['emotions_short'].unique()

#PERSONALITY SHORT
#df_merged['personality_short'].unique()

# #SHOT
# #df_merged['shot'].unique()
# mapping = {
#     #'{"shot": "close-up shot"}': '{"shot": ["close-up shot"]}',
#     #'{"shot": "full shot"}': '{"shot": ["full shot"]}',
#     "{'shot': ['medium']}": "{'shot': ['medium shot']}",
#     #'{"shot": ["medium"]}': '{"shot": ["medium shot"]}',
#     #'{"shot": "medium shot"}': '{"shot": ["medium shot"]}',
#     "{'shot': ['close-up']}": "{'shot': ['close-up shot']}",
# }
# df_merged['shot'] = df_merged['shot'].map(mapping).fillna(df_merged['shot'])
# df_merged['shot'].unique()

# #POSITION SHORT

#PERSON COUNT
def normalize_person_count(value):
    # Remover cualquier punto al final
    value = value.strip(".")
    
    # Corregir comillas desbalanceadas
    value = re.sub(r'["]', "'", value)  # Reemplazar comillas dobles por simples
    value = re.sub(r"''", "'", value)   # Reemplazar comillas simples dobles por una
    
    # Extraer números dentro de las comillas
    numbers = re.findall(r"'(\d+)'", value)
    if not numbers:  # Si no se encontraron números entre comillas, intentar encontrarlos sin comillas
        numbers = re.findall(r"(\d+)", value)
    
    if numbers:
        numbers = list(map(int, numbers))
        if any(num >= 3 for num in numbers):
            return "{'person_count': ['+3']}"
        else:
            return "{'person_count': ['" + "', '".join(map(str, numbers)) + "']}"
    else:
        return value

# Aplicar la normalización a la columna 'person_count'
df_merged['person_count'] = df_merged['person_count'].apply(normalize_person_count)

mapping = {
    "{'person_count': [1]}": "{'person_count': ['1']}",
    "{'person_count': [2]}": "{'person_count': ['2']}",
    "{'person_count': [3]}": "{'person_count': ['3']}",
}
df_merged['person_count'] = df_merged['person_count'].map(mapping).fillna(df_merged['person_count'])
df_merged['person_count'].unique()
# Out:
# array(["{'person_count': ['1']}", "{'person_count': ['0']}",
#        "{'person_count': ['2']}", "{'person_count': ['+3']}"],
#       dtype=object)

# %%
df_merged
# Out:
#                                           filename_png  \
# 0    01P_a_person_walking_to_the_bathroom_in_photor...
# 1    01P_a_person_walking_to_the_bathroom_in_photor...
# 2    01P_a_person_walking_to_the_bathroom_in_photor...
# 3    01P_a_person_walking_to_the_bathroom_in_photor...
# 4    2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..                                                 ...
# 803  139OP_a_front_photo_of_an_older_person_doing_d...
# 804  140OP_an_older_person_at_the_hospital_in_photo...
# 805  140OP_an_older_person_at_the_hospital_in_photo...
# 806  140OP_an_older_person_at_the_hospital_in_photo...
# 807  140OP_an_older_person_at_the_hospital_in_photo...
#
#                                                 prompt   codi age_group  \
# 0    a person walking to the bathroom in photoreali...    01p   neutral
# 1    a person walking to the bathroom in photoreali...    01p   neutral
# 2    a person walking to the bathroom in photoreali...    01p   neutral
# 3    a person walking to the bathroom in photoreali...    01p   neutral
# 4    a front photo of a person walking to a store i...     2p   neutral
# ..                                                 ...    ...       ...
# 803  a front photo of an older person doing diet an...  139op     older
# 804  an older person at the hospital in photorealis...  140op     older
# 805  an older person at the hospital in photorealis...  140op     older
# 806  an older person at the hospital in photorealis...  140op     older
# 807  an older person at the hospital in photorealis...  140op     older
#
#             ID                                       filename_jpg  \
# 0      a_p1_f1  01P_a_person_walking_to_the_bathroom_in_photor...
# 1      a_p1_f2  01P_a_person_walking_to_the_bathroom_in_photor...
# 2      a_p1_f3  01P_a_person_walking_to_the_bathroom_in_photor...
# 3      a_p1_f4  01P_a_person_walking_to_the_bathroom_in_photor...
# 4      a_p2_f1  2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..         ...                                                ...
# 803  o_p139_f4  139OP_a_front_photo_of_an_older_person_doing_d...
# 804  o_p140_f1  140OP_an_older_person_at_the_hospital_in_photo...
# 805  o_p140_f2  140OP_an_older_person_at_the_hospital_in_photo...
# 806  o_p140_f3  140OP_an_older_person_at_the_hospital_in_photo...
# 807  o_p140_f4  140OP_an_older_person_at_the_hospital_in_photo...
#
#                      gender           age_range                 race  \
# 0      {'gender': ['male']}  {'age': ['25-34']}  {'race': ['white']}
# 1      {'gender': ['male']}  {'age': ['18-24']}  {'race': ['white']}
# 2      {'gender': ['male']}  {'age': ['25-34']}  {'race': ['white']}
# 3    {'gender': ['female']}  {'age': ['35-44']}  {'race': ['other']}
# 4      {'gender': ['male']}  {'age': ['25-34']}  {'race': ['white']}
# ..                      ...                 ...                  ...
# 803    {'gender': ['male']}  {'age': ['65-79']}  {'race': ['white']}
# 804    {'gender': ['male']}    {'age': ['80+']}  {'race': ['white']}
# 805    {'gender': ['male']}    {'age': ['80+']}  {'race': ['white']}
# 806    {'gender': ['male']}   {"age": "[65-79]"  {'race': ['white']}
# 807  {'gender': ['female']}  {'age': ['65-79']}  {'race': ['white']}
#
#                 emotions_short                       personality_short  \
# 0     {'emotion': ['neutral']}       {'personality': ['extraversion']}
# 1     {'emotion': ['neutral']}           {'personality': ['openness']}
# 2     {'emotion': ['neutral']}           {'personality': ['openness']}
# 3     {'emotion': ['neutral']}      {'personality': ['agreeableness']}
# 4     {'emotion': ['neutral']}  {'personality': ['conscientiousness']}
# ..                         ...                                     ...
# 803   {'emotion': ['neutral']}  {'personality': ['conscientiousness']}
# 804  {'emotion': ['negative']}      {'personality': ['agreeableness']}
# 805  {'emotion': ['negative']}      {'personality': ['agreeableness']}
# 806   {'emotion': ['neutral']}      {'personality': ['agreeableness']}
# 807  {'emotion': ['negative']}      {'personality': ['agreeableness']}
#
#                        location  \
# 0         {"location": "indoor"
# 1      {'location': ['indoor']}
# 2      {'location': ['indoor']}
# 3      {'location': ['indoor']}
# 4    {'location': ['outdoors']}
# ..                          ...
# 803       {"location": "indoor"
# 804    {'location': ['indoor']}
# 805   {'location': ['indoors']}
# 806   {'location': ['indoors']}
# 807       {"location": "indoor"
#
#                                                objects  \
# 0    {'objects': ['bathroom sink', 'glass door', 'l...
# 1    {'objects': ['person', 'doorway', 'wall tile',...
# 2    {'objects': ['person', 'sink', 'plant', 'doorw...
# 3    {'objects': ['person', 'sink', 'bathroom tiles...
# 4    {'objects': ['man walking on sidewalk', 'store...
# ..                                                 ...
# 803  {'objects': ['tablet', 'pen', 'book', 'wooden ...
# 804  {'objects': ['man', 'chair', 'waiting area', '...
# 805  {'objects': ['man', 'hospital bed', 'medical e...
# 806  {'objects': ['hospital bed', 'white pillowcase...
# 807  {'objects': ['person', 'hospital bed', 'headre...
#
#                                 objects_assist_devices  \
# 0    {'assistive_devices': ['no assistive devices a...
# 1                      {'assistive_devices': ['door']}
# 2                      {'assistive_devices': ['sink']}
# 3                      {'assistive_devices': ['sink']}
# 4                  {'assistive_devices': ['backpack']}
# ..                                                 ...
# 803                     {'assistive_devices': ['pen']}
# 804                    {'assistive_devices': ['cane']}
# 805                    {'assistive_devices': ['cane']}
# 806                          {'assistive_devices': []}
# 807               {'assistive_devices': ['headscarf']}
#
#                           objects_digi_devices             person_count  \
# 0                      {'digital_devices': []}  {'person_count': ['1']}
# 1                      {'digital_devices': []}  {'person_count': ['1']}
# 2                      {'digital_devices': []}  {'person_count': ['1']}
# 3                      {'digital_devices': []}  {'person_count': ['1']}
# 4            {'digital_devices': ['notebook']}  {'person_count': ['1']}
# ..                                         ...                      ...
# 803                    {'digital_devices': []}  {'person_count': ['1']}
# 804                    {'digital_devices': []}  {'person_count': ['1']}
# 805                    {'digital_devices': []}  {'person_count': ['1']}
# 806  {'digital_devices': ['computer monitor']}  {'person_count': ['1']}
# 807                    {'digital_devices': []}  {'person_count': ['1']}
#
#                             shot              position_short
# 0              {"shot": "medium"  {'position': ['standing']}
# 1           {'shot': ['medium']}  {'position': ['standing']}
# 2        {'shot': ['full shot']}  {'position': ['standing']}
# 3        {'shot': ['full shot']}  {'position': ['standing']}
# 4      {'shot': ['medium shot']}  {'position': ['standing']}
# ..                           ...                         ...
# 803  {'shot': ['close-up shot']}   {'position': ['sitting']}
# 804      {'shot': ['full shot']}   {'position': ['sitting']}
# 805      {'shot': ['full shot']}   {'position': ['sitting']}
# 806      {'shot': ['full shot']}     {'position': ['lying']}
# 807  {'shot': ['close-up shot']}     {'position': ['lying']}
#
# [808 rows x 18 columns]

# %%
df_merged['gender'].unique()
df_merged['race'].unique()
df_merged['location'].unique()
df_merged['emotions_short'].unique()
df_merged['personality_short'].unique()
df_merged['shot'].unique()
df_merged['person_count'].unique()
df_merged['position_short'].unique()
# Out:
# array(["{'position': ['standing']}", "{'position': ['none']}",
#        "{'position': ['sitting']}", "{'position': ['lying']}",
#        "{'position': ['crouched']}"], dtype=object)

# %%
def ensure_list(value):
    # Intenta convertir la cadena a una lista de Python
    if isinstance(value, str):
        try:
            # Evalúa la cadena para convertirla en una lista o dict
            data = ast.literal_eval(value)
            # Si es un diccionario, toma el primer valor, que se asume es una lista
            if isinstance(data, dict):
                return list(data.values())[0] if isinstance(list(data.values())[0], list) else [list(data.values())[0]]
            # Si es una lista, devuélvela tal cual
            elif isinstance(data, list):
                return data
        except:
            return [value]  # Si falla la evaluación, devuelve el valor original como un solo elemento de una lista
    return value if isinstance(value, list) else [value]  # Si ya es una lista, devuélvela; si no, envuélvela en una lista

def is_list(value):
    return isinstance(value, list)

# Lista de columnas que quieres transformar
columns_to_transform = [
    'gender',
    'age_range',
    'race', 
    'emotions_short', 
    'location', 
    'personality_short', 
    'shot', 
    'position_short',
    'objects',
    'objects_assist_devices',
    'objects_digi_devices',
    'person_count',
    'shot'
]

# Aplica la transformación a cada columna
for column in columns_to_transform:
    df_merged[column] = df_merged[column].apply(ensure_list)

# Verificar que ahora todas son listas de Python
for column in columns_to_transform:
    if df_merged[column].apply(is_list).all():
        print(f"Todos los valores en la columna '{column}' son listas de Python.")
    else:
        print(f"Algunos valores en la columna '{column}' NO son listas de Python.")

def convert_assist_devices(value):
    if isinstance(value, list) or isinstance(value, str):
        if isinstance(value, list):
            value = str(value)

        if 'assistive_devices' in value:
            return ['none']
        
        if isinstance(value, str) and not value.strip():
            return ['none']

        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict) and 'assistive_devices' in data:
                return ['none']
        except (ValueError, SyntaxError):
            pass

    if isinstance(value, list) and not value:
        return ['none']
    return value

df_merged['objects_assist_devices'] = df_merged['objects_assist_devices'].apply(convert_assist_devices)

def convert_digi_devices(value):
    if isinstance(value, list) or isinstance(value, str):
        if isinstance(value, list):
            value = str(value)

        if 'digital_devices' in value:
            return ['none']
        
        if isinstance(value, str) and not value.strip():
            return ['none']

        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict) and 'digital_devices' in data:
                return ['none']
        except (ValueError, SyntaxError):
            pass

    if isinstance(value, list) and not value:
        return ['none']
    return value

df_merged['objects_digi_devices'] = df_merged['objects_digi_devices'].apply(convert_digi_devices)
# Out:
# Todos los valores en la columna 'gender' son listas de Python.
# Todos los valores en la columna 'age_range' son listas de Python.
# Todos los valores en la columna 'race' son listas de Python.
# Todos los valores en la columna 'emotions_short' son listas de Python.
# Todos los valores en la columna 'location' son listas de Python.
# Todos los valores en la columna 'personality_short' son listas de Python.
# Todos los valores en la columna 'shot' son listas de Python.
# Todos los valores en la columna 'position_short' son listas de Python.
# Todos los valores en la columna 'objects' son listas de Python.
# Todos los valores en la columna 'objects_assist_devices' son listas de Python.
# Todos los valores en la columna 'objects_digi_devices' son listas de Python.
# Todos los valores en la columna 'person_count' son listas de Python.
# Todos los valores en la columna 'shot' son listas de Python.

# %%
def reemplazar_lista_vacia(valor):
    if isinstance(valor, str):
        valor = ast.literal_eval(valor)  # Convertir la cadena a una lista o diccionario
    
    if isinstance(valor, list) and not valor:
        return ['none']
    elif isinstance(valor, dict) and not valor:
        return ['none']
    return valor

df_merged['objects_digi_devices'] = df_merged['objects_digi_devices'].apply(reemplazar_lista_vacia)
df_merged['objects_assist_devices'] = df_merged['objects_assist_devices'].apply(reemplazar_lista_vacia)

# Ahora, las listas vacías en 'objects_digi_devices' y 'objects_assist_devices' 
# se han reemplazado por ['none']

# %%
df_merged
# Out:
#                                           filename_png  \
# 0    01P_a_person_walking_to_the_bathroom_in_photor...
# 1    01P_a_person_walking_to_the_bathroom_in_photor...
# 2    01P_a_person_walking_to_the_bathroom_in_photor...
# 3    01P_a_person_walking_to_the_bathroom_in_photor...
# 4    2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..                                                 ...
# 803  139OP_a_front_photo_of_an_older_person_doing_d...
# 804  140OP_an_older_person_at_the_hospital_in_photo...
# 805  140OP_an_older_person_at_the_hospital_in_photo...
# 806  140OP_an_older_person_at_the_hospital_in_photo...
# 807  140OP_an_older_person_at_the_hospital_in_photo...
#
#                                                 prompt   codi age_group  \
# 0    a person walking to the bathroom in photoreali...    01p   neutral
# 1    a person walking to the bathroom in photoreali...    01p   neutral
# 2    a person walking to the bathroom in photoreali...    01p   neutral
# 3    a person walking to the bathroom in photoreali...    01p   neutral
# 4    a front photo of a person walking to a store i...     2p   neutral
# ..                                                 ...    ...       ...
# 803  a front photo of an older person doing diet an...  139op     older
# 804  an older person at the hospital in photorealis...  140op     older
# 805  an older person at the hospital in photorealis...  140op     older
# 806  an older person at the hospital in photorealis...  140op     older
# 807  an older person at the hospital in photorealis...  140op     older
#
#             ID                                       filename_jpg    gender  \
# 0      a_p1_f1  01P_a_person_walking_to_the_bathroom_in_photor...    [male]
# 1      a_p1_f2  01P_a_person_walking_to_the_bathroom_in_photor...    [male]
# 2      a_p1_f3  01P_a_person_walking_to_the_bathroom_in_photor...    [male]
# 3      a_p1_f4  01P_a_person_walking_to_the_bathroom_in_photor...  [female]
# 4      a_p2_f1  2P_a_front_photo_of_a_person_walking_to_a_stor...    [male]
# ..         ...                                                ...       ...
# 803  o_p139_f4  139OP_a_front_photo_of_an_older_person_doing_d...    [male]
# 804  o_p140_f1  140OP_an_older_person_at_the_hospital_in_photo...    [male]
# 805  o_p140_f2  140OP_an_older_person_at_the_hospital_in_photo...    [male]
# 806  o_p140_f3  140OP_an_older_person_at_the_hospital_in_photo...    [male]
# 807  o_p140_f4  140OP_an_older_person_at_the_hospital_in_photo...  [female]
#
#                age_range     race emotions_short    personality_short  \
# 0                [25-34]  [white]      [neutral]       [extraversion]
# 1                [18-24]  [white]      [neutral]           [openness]
# 2                [25-34]  [white]      [neutral]           [openness]
# 3                [35-44]  [other]      [neutral]      [agreeableness]
# 4                [25-34]  [white]      [neutral]  [conscientiousness]
# ..                   ...      ...            ...                  ...
# 803              [65-79]  [white]      [neutral]  [conscientiousness]
# 804                [80+]  [white]     [negative]      [agreeableness]
# 805                [80+]  [white]     [negative]      [agreeableness]
# 806  [{"age": "[65-79]"]  [white]      [neutral]      [agreeableness]
# 807            [[65-79]]  [white]     [negative]      [agreeableness]
#
#        location                                            objects  \
# 0      [indoor]  [bathroom sink, glass door, large window, towe...
# 1      [indoor]  [person, doorway, wall tile, wood flooring, li...
# 2      [indoor]  [person, sink, plant, doorway, tile flooring, ...
# 3      [indoor]  [person, sink, bathroom tiles, light fixture, ...
# 4    [outdoors]  [man walking on sidewalk, storefront with awni...
# ..          ...                                                ...
# 803    [indoor]  [tablet, pen, book, wooden cutting board with ...
# 804    [indoor]  [man, chair, waiting area, building entrance, ...
# 805    [indoor]  [man, hospital bed, medical equipment, grey ha...
# 806    [indoor]  [hospital bed, white pillowcase, man lying dow...
# 807    [indoor]  [person, hospital bed, headrest, candle, blank...
#
#                                 objects_assist_devices  objects_digi_devices  \
# 0    ['no assistive devices are visible in the image']                    []
# 1                                             ['door']                    []
# 2                                             ['sink']                    []
# 3                                             ['sink']                    []
# 4                                         ['backpack']          ['notebook']
# ..                                                 ...                   ...
# 803                                            ['pen']                    []
# 804                                           ['cane']                    []
# 805                                           ['cane']                    []
# 806                                                 []  ['computer monitor']
# 807                                      ['headscarf']                    []
#
#     person_count             shot position_short
# 0            [1]         [medium]     [standing]
# 1            [1]         [medium]     [standing]
# 2            [1]      [full shot]     [standing]
# 3            [1]      [full shot]     [standing]
# 4            [1]         [medium]     [standing]
# ..           ...              ...            ...
# 803          [1]  [close-up shot]      [sitting]
# 804          [1]      [full shot]      [sitting]
# 805          [1]      [full shot]      [sitting]
# 806          [1]      [full shot]        [lying]
# 807          [1]  [close-up shot]        [lying]
#
# [808 rows x 18 columns]

# %% [markdown]
# # PIL BRIGHTNESS

# %%
def rgb_to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(int(rgb[0]), int(rgb[1]), int(rgb[2]))

def rgb_to_css(rgb):
    return f'rgb({int(rgb[0])}, {int(rgb[1])}, {int(rgb[2])})'

def simplify_color(rgb):
    color_names = {
        (0, 0, 0): "Negro", (255, 255, 255): "Blanco",
        (255, 0, 0): "Rojo", (0, 255, 0): "Verde", (0, 0, 255): "Azul",
        (255, 255, 0): "Amarillo", (255, 0, 255): "Magenta", (0, 255, 255): "Cian",
        (128, 128, 128): "Gris"
    }
    
    distances = {name: sum((a - b) ** 2 for a, b in zip(rgb, color_rgb))
                 for color_rgb, name in color_names.items()}
    return min(distances, key=distances.get)

def analizar_imagen(ruta_imagen, max_size=1000):
    try:
        with Image.open(ruta_imagen) as imagen:
            if max(imagen.size) > max_size:
                imagen.thumbnail((max_size, max_size))
            
            imagen_array = np.array(imagen)
        
        brillo_promedio = np.mean(imagen_array)
        
        contraste = np.std(imagen_array)
        
        if len(imagen_array.shape) == 3:  # Imagen a color
            pixels = imagen_array.reshape(-1, 3)
            color_dominante, conteo = stats.mode(pixels, axis=0)
            color_dominante = color_dominante.ravel()
            conteo = conteo.ravel()[0]  # Tomar el primer elemento del array de conteo
        else:  # Imagen en escala de grises
            color_dominante = np.array([brillo_promedio] * 3)
            conteo = imagen_array.size
        
        # Calcular el porcentaje de píxeles del color dominante
        total_pixels = imagen_array.size // 3 if len(imagen_array.shape) == 3 else imagen_array.size
        porcentaje_dominante = (conteo / total_pixels) * 100
        
        return {
            'filename_jpg': os.path.basename(ruta_imagen),
            'brillo_promedio': float(brillo_promedio),
            'contraste': float(contraste),
            'color_dominante': {
                'rgb': tuple(map(int, color_dominante)),
                'hex': rgb_to_hex(color_dominante),
                'css': rgb_to_css(color_dominante),
                'simplificado': simplify_color(tuple(map(int, color_dominante)))
            },
            'porcentaje_dominante': float(porcentaje_dominante)
        }
    except Exception as e:
        print(f"Error al procesar {os.path.basename(ruta_imagen)}: {str(e)}")
        return None

def analizar_carpeta(ruta_carpeta, limit=None):
    resultados = []
    archivos = [f for f in os.listdir(ruta_carpeta) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
    
    if limit:
        archivos = archivos[:limit]
    
    total = len(archivos)
    for i, archivo in enumerate(archivos, 1):
        ruta_completa = os.path.join(ruta_carpeta, archivo)
        resultado = analizar_imagen(ruta_completa)
        if resultado:
            resultados.append(resultado)
        print(f"Procesado {i}/{total}: {archivo}")
    
    return resultados

if __name__ == '__main__':
    resultados_n = analizar_carpeta("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/neutral_comp")
    resultados_o = analizar_carpeta("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities_parejo/older_comp")
    
    for resultado_n in resultados_n:
        print(f"\nImagen: {resultado_n['filename_jpg']}")
        print(f"  Brillo promedio: {resultado_n['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_n['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_n['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_n['color_dominante']['hex']}")
        print(f"    CSS: {resultado_n['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_n['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_n['porcentaje_dominante']:.2f}%")

    for resultado_o in resultados_o:
        print(f"\nImagen: {resultado_o['filename_jpg']}")
        print(f"  Brillo promedio: {resultado_o['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_o['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_o['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_o['color_dominante']['hex']}")
        print(f"    CSS: {resultado_o['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_o['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_o['porcentaje_dominante']:.2f}%")
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_1868\4436073.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   color_dominante, conteo = stats.mode(pixels, axis=0)
# Procesado 1/405: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_0.jpg
# Procesado 2/405: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_1.jpg
# Procesado 3/405: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_2.jpg
# Procesado 4/405: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_3.jpg
# Procesado 5/405: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_0.jpg
# Procesado 6/405: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_1.jpg
# Procesado 7/405: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_2.jpg
# Procesado 8/405: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_3.jpg
# Procesado 9/405: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_0.jpg
# Procesado 10/405: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_1.jpg
# Procesado 11/405: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_2.jpg
# Procesado 12/405: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_3.jpg
# Procesado 13/405: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_0.jpg
# Procesado 14/405: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_1.jpg
# Procesado 15/405: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_2.jpg
# Procesado 16/405: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_3.jpg
# Procesado 17/405: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_0.jpg
# Procesado 18/405: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_1.jpg
# Procesado 19/405: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_2.jpg
# Procesado 20/405: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_3.jpg
# Procesado 21/405: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_0.jpg
# Procesado 22/405: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_1.jpg
# Procesado 23/405: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_2.jpg
# Procesado 24/405: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_3.jpg
# Procesado 25/405: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_0.jpg
# Procesado 26/405: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_1.jpg
# Procesado 27/405: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_2.jpg
# Procesado 28/405: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_3.jpg
# Procesado 29/405: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_0.jpg
# Procesado 30/405: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_1.jpg
# Procesado 31/405: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_2.jpg
# Procesado 32/405: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_3.jpg
# Procesado 33/405: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_0.jpg
# Procesado 34/405: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_1.jpg
# Procesado 35/405: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_2.jpg
# Procesado 36/405: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_3.jpg
# Procesado 37/405: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_0.jpg
# Procesado 38/405: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_1.jpg
# Procesado 39/405: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_2.jpg
# Procesado 40/405: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_3.jpg
# Procesado 41/405: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_0.jpg
# Procesado 42/405: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_1.jpg
# Procesado 43/405: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_2.jpg
# Procesado 44/405: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_3.jpg
# Procesado 45/405: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_0.jpg
# Procesado 46/405: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_1.jpg
# Procesado 47/405: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_2.jpg
# Procesado 48/405: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_3.jpg
# Procesado 49/405: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_0.jpg
# Procesado 50/405: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_1.jpg
# Procesado 51/405: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_2.jpg
# Procesado 52/405: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_3.jpg
# Procesado 53/405: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_0.jpg
# Procesado 54/405: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_1.jpg
# Procesado 55/405: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_2.jpg
# Procesado 56/405: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_3.jpg
# Procesado 57/405: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_0.jpg
# Procesado 58/405: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_1.jpg
# Procesado 59/405: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_2.jpg
# Procesado 60/405: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_3.jpg
# Procesado 61/405: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_0.jpg
# Procesado 62/405: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_1.jpg
# Procesado 63/405: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_2.jpg
# Procesado 64/405: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_3.jpg
# Procesado 65/405: 11oP_a_portrait_of_an_older_person_setting_the_table_--perso_efb34cee-8e1e-412d-90b4-72df2d9d35ae_1.jpg
# Procesado 66/405: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_0.jpg
# Procesado 67/405: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_1.jpg
# Procesado 68/405: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_2.jpg
# Procesado 69/405: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_3.jpg
# Procesado 70/405: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_0.jpg
# Procesado 71/405: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_1.jpg
# Procesado 72/405: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_2.jpg
# Procesado 73/405: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_3.jpg
# Procesado 74/405: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_0.jpg
# Procesado 75/405: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_1.jpg
# Procesado 76/405: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_2.jpg
# Procesado 77/405: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_3.jpg
# Procesado 78/405: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_0.jpg
# Procesado 79/405: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_1.jpg
# Procesado 80/405: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_2.jpg
# Procesado 81/405: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_3.jpg
# Procesado 82/405: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_0.jpg
# Procesado 83/405: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_1.jpg
# Procesado 84/405: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_2.jpg
# Procesado 85/405: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_3.jpg
# Procesado 86/405: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_0.jpg
# Procesado 87/405: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_1.jpg
# Procesado 88/405: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_2.jpg
# Procesado 89/405: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_3.jpg
# Procesado 90/405: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_0.jpg
# Procesado 91/405: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_1.jpg
# Procesado 92/405: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_2.jpg
# Procesado 93/405: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_3.jpg
# Procesado 94/405: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_0.jpg
# Procesado 95/405: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_1.jpg
# Procesado 96/405: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_2.jpg
# Procesado 97/405: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_3.jpg
# Procesado 98/405: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_0.jpg
# Procesado 99/405: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_1.jpg
# Procesado 100/405: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_2.jpg
# Procesado 101/405: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_3.jpg
# Procesado 102/405: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_0.jpg
# Procesado 103/405: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_1.jpg
# Procesado 104/405: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_2.jpg
# Procesado 105/405: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_3.jpg
# Procesado 106/405: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_0.jpg
# Procesado 107/405: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_1.jpg
# Procesado 108/405: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_2.jpg
# Procesado 109/405: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_3.jpg
# Procesado 110/405: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_0.jpg
# Procesado 111/405: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_1.jpg
# Procesado 112/405: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_2.jpg
# Procesado 113/405: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_3.jpg
# Procesado 114/405: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_0.jpg
# Procesado 115/405: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_1.jpg
# Procesado 116/405: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_2.jpg
# Procesado 117/405: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_3.jpg
# Procesado 118/405: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_0.jpg
# Procesado 119/405: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_1.jpg
# Procesado 120/405: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_2.jpg
# Procesado 121/405: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_3.jpg
# Procesado 122/405: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_0.jpg
# Procesado 123/405: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_1.jpg
# Procesado 124/405: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_2.jpg
# Procesado 125/405: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_3.jpg
# Procesado 126/405: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_0.jpg
# Procesado 127/405: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_1.jpg
# Procesado 128/405: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_2.jpg
# Procesado 129/405: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_3.jpg
# Procesado 130/405: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_0.jpg
# Procesado 131/405: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_1.jpg
# Procesado 132/405: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_2.jpg
# Procesado 133/405: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_3.jpg
# Procesado 134/405: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_0.jpg
# Procesado 135/405: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_1.jpg
# Procesado 136/405: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_2.jpg
# Procesado 137/405: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_3.jpg
# Procesado 138/405: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_0.jpg
# Procesado 139/405: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_1.jpg
# Procesado 140/405: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_2.jpg
# Procesado 141/405: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_3.jpg
# Procesado 142/405: 14P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_0.jpg
# Procesado 143/405: 14P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_1.jpg
# Procesado 144/405: 14P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_2.jpg
# Procesado 145/405: 14P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_3.jpg
# Procesado 146/405: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_0.jpg
# Procesado 147/405: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_1.jpg
# Procesado 148/405: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_2.jpg
# Procesado 149/405: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_3.jpg
# Procesado 150/405: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_0.jpg
# Procesado 151/405: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_1.jpg
# Procesado 152/405: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_2.jpg
# Procesado 153/405: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_3.jpg
# Procesado 154/405: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_0.jpg
# Procesado 155/405: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_1.jpg
# Procesado 156/405: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_2.jpg
# Procesado 157/405: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_3.jpg
# Procesado 158/405: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_0.jpg
# Procesado 159/405: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_1.jpg
# Procesado 160/405: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_2.jpg
# Procesado 161/405: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_3.jpg
# Procesado 162/405: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_0.jpg
# Procesado 163/405: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_1.jpg
# Procesado 164/405: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_2.jpg
# Procesado 165/405: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_3.jpg
# Procesado 166/405: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_0.jpg
# Procesado 167/405: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_1.jpg
# Procesado 168/405: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_2.jpg
# Procesado 169/405: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_3.jpg
# Procesado 170/405: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_0.jpg
# Procesado 171/405: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_1.jpg
# Procesado 172/405: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_2.jpg
# Procesado 173/405: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_3.jpg
# Procesado 174/405: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_0.jpg
# Procesado 175/405: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_1.jpg
# Procesado 176/405: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_2.jpg
# Procesado 177/405: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_3.jpg
# Procesado 178/405: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_0.jpg
# Procesado 179/405: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_1.jpg
# Procesado 180/405: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_2.jpg
# Procesado 181/405: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_3.jpg
# Procesado 182/405: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_0.jpg
# Procesado 183/405: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_1.jpg
# Procesado 184/405: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_2.jpg
# Procesado 185/405: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_3.jpg
# Procesado 186/405: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_0.jpg
# Procesado 187/405: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_1.jpg
# Procesado 188/405: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_2.jpg
# Procesado 189/405: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_3.jpg
# Procesado 190/405: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_0.jpg
# Procesado 191/405: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_1.jpg
# Procesado 192/405: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_2.jpg
# Procesado 193/405: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_3.jpg
# Procesado 194/405: 31P_a_person_in_the_bathroom_--personalize_deewgch_--v_6.1_e27dd7f5-6b9f-4ec9-85c4-1829ca04e2d4_0.jpg
# Procesado 195/405: 31P_a_person_in_the_bathroom_--personalize_deewgch_--v_6.1_e27dd7f5-6b9f-4ec9-85c4-1829ca04e2d4_1.jpg
# Procesado 196/405: 31P_a_person_in_the_bathroom_--personalize_deewgch_--v_6.1_e27dd7f5-6b9f-4ec9-85c4-1829ca04e2d4_2.jpg
# Procesado 197/405: 31P_a_person_in_the_bathroom_--personalize_deewgch_--v_6.1_e27dd7f5-6b9f-4ec9-85c4-1829ca04e2d4_3.jpg
# Procesado 198/405: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_0.jpg
# Procesado 199/405: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_1.jpg
# Procesado 200/405: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_2.jpg
# Procesado 201/405: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_3.jpg
# Procesado 202/405: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_0.jpg
# Procesado 203/405: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_1.jpg
# Procesado 204/405: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_2.jpg
# Procesado 205/405: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_3.jpg
# Procesado 206/405: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_0.jpg
# Procesado 207/405: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_1.jpg
# Procesado 208/405: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_2.jpg
# Procesado 209/405: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_3.jpg
# Procesado 210/405: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_0.jpg
# Procesado 211/405: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_1.jpg
# Procesado 212/405: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_2.jpg
# Procesado 213/405: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_3.jpg
# Procesado 214/405: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_0.jpg
# Procesado 215/405: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_1.jpg
# Procesado 216/405: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_2.jpg
# Procesado 217/405: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_3.jpg
# Procesado 218/405: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_0.jpg
# Procesado 219/405: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_1.jpg
# Procesado 220/405: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_2.jpg
# Procesado 221/405: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_3.jpg
# Procesado 222/405: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_0.jpg
# Procesado 223/405: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_1.jpg
# Procesado 224/405: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_2.jpg
# Procesado 225/405: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_3.jpg
# Procesado 226/405: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_0.jpg
# Procesado 227/405: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_1.jpg
# Procesado 228/405: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_2.jpg
# Procesado 229/405: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_3.jpg
# Procesado 230/405: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_0.jpg
# Procesado 231/405: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_1.jpg
# Procesado 232/405: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_2.jpg
# Procesado 233/405: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_3.jpg
# Procesado 234/405: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_0.jpg
# Procesado 235/405: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_1.jpg
# Procesado 236/405: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_2.jpg
# Procesado 237/405: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_3.jpg
# Procesado 238/405: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_0.jpg
# Procesado 239/405: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_1.jpg
# Procesado 240/405: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_2.jpg
# Procesado 241/405: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_3.jpg
# Procesado 242/405: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_0.jpg
# Procesado 243/405: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_1.jpg
# Procesado 244/405: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_2.jpg
# Procesado 245/405: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_3.jpg
# Procesado 246/405: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_0.jpg
# Procesado 247/405: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_1.jpg
# Procesado 248/405: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_2.jpg
# Procesado 249/405: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_3.jpg
# Procesado 250/405: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_0.jpg
# Procesado 251/405: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_1.jpg
# Procesado 252/405: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_2.jpg
# Procesado 253/405: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_3.jpg
# Procesado 254/405: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_0.jpg
# Procesado 255/405: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_1.jpg
# Procesado 256/405: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_2.jpg
# Procesado 257/405: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_3.jpg
# Procesado 258/405: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_0.jpg
# Procesado 259/405: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_1.jpg
# Procesado 260/405: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_2.jpg
# Procesado 261/405: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_3.jpg
# Procesado 262/405: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_0.jpg
# Procesado 263/405: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_1.jpg
# Procesado 264/405: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_2.jpg
# Procesado 265/405: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_3.jpg
# Procesado 266/405: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_0.jpg
# Procesado 267/405: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_1.jpg
# Procesado 268/405: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_2.jpg
# Procesado 269/405: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_3.jpg
# Procesado 270/405: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_0.jpg
# Procesado 271/405: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_1.jpg
# Procesado 272/405: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_2.jpg
# Procesado 273/405: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_3.jpg
# Procesado 274/405: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_0.jpg
# Procesado 275/405: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_1.jpg
# Procesado 276/405: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_2.jpg
# Procesado 277/405: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_3.jpg
# Procesado 278/405: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_0.jpg
# Procesado 279/405: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_1.jpg
# Procesado 280/405: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_2.jpg
# Procesado 281/405: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_3.jpg
# Procesado 282/405: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_0.jpg
# Procesado 283/405: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_1.jpg
# Procesado 284/405: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_2.jpg
# Procesado 285/405: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_3.jpg
# Procesado 286/405: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_0.jpg
# Procesado 287/405: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_1.jpg
# Procesado 288/405: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_2.jpg
# Procesado 289/405: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_3.jpg
# Procesado 290/405: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_0.jpg
# Procesado 291/405: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_1.jpg
# Procesado 292/405: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_2.jpg
# Procesado 293/405: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_3.jpg
# Procesado 294/405: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_0.jpg
# Procesado 295/405: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_1.jpg
# Procesado 296/405: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_2.jpg
# Procesado 297/405: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_3.jpg
# Procesado 298/405: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_0.jpg
# Procesado 299/405: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_1.jpg
# Procesado 300/405: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_2.jpg
# Procesado 301/405: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_3.jpg
# Procesado 302/405: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_0.jpg
# Procesado 303/405: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_1.jpg
# Procesado 304/405: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_2.jpg
# Procesado 305/405: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_3.jpg
# Procesado 306/405: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_0.jpg
# Procesado 307/405: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_1.jpg
# Procesado 308/405: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_2.jpg
# Procesado 309/405: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_3.jpg
# Procesado 310/405: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_0.jpg
# Procesado 311/405: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_1.jpg
# Procesado 312/405: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_2.jpg
# Procesado 313/405: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_3.jpg
# Procesado 314/405: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_0.jpg
# Procesado 315/405: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_1.jpg
# Procesado 316/405: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_2.jpg
# Procesado 317/405: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_3.jpg
# Procesado 318/405: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_0.jpg
# Procesado 319/405: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_1.jpg
# Procesado 320/405: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_2.jpg
# Procesado 321/405: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_3.jpg
# Procesado 322/405: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_0.jpg
# Procesado 323/405: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_1.jpg
# Procesado 324/405: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_2.jpg
# Procesado 325/405: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_3.jpg
# Procesado 326/405: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_0.jpg
# Procesado 327/405: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_1.jpg
# Procesado 328/405: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_2.jpg
# Procesado 329/405: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_3.jpg
# Procesado 330/405: 72P_portrait_of_a_person_consulting_the_doctors_in_photorea_8f1115a3-d82d-40fe-b30a-a9ab1d7d8657_0.jpg
# Procesado 331/405: 72P_portrait_of_a_person_consulting_the_doctors_in_photorea_8f1115a3-d82d-40fe-b30a-a9ab1d7d8657_1.jpg
# Procesado 332/405: 72P_portrait_of_a_person_consulting_the_doctors_in_photorea_8f1115a3-d82d-40fe-b30a-a9ab1d7d8657_2.jpg
# Procesado 333/405: 72P_portrait_of_a_person_consulting_the_doctors_in_photorea_8f1115a3-d82d-40fe-b30a-a9ab1d7d8657_3.jpg
# Procesado 334/405: 74P_a_person_in_medical_examinations_in_photorealistic_styl_34427152-ce9f-4a12-b396-d546b3abbcf1_0.jpg
# Procesado 335/405: 74P_a_person_in_medical_examinations_in_photorealistic_styl_34427152-ce9f-4a12-b396-d546b3abbcf1_1.jpg
# Procesado 336/405: 74P_a_person_in_medical_examinations_in_photorealistic_styl_34427152-ce9f-4a12-b396-d546b3abbcf1_2.jpg
# Procesado 337/405: 74P_a_person_in_medical_examinations_in_photorealistic_styl_34427152-ce9f-4a12-b396-d546b3abbcf1_3.jpg
# Procesado 338/405: 75P_Create_an_image_in_a_front_view_of_a_person_calling_fri_d6810916-71db-4a62-b89b-b19103c0ffdf_0.jpg
# Procesado 339/405: 75P_Create_an_image_in_a_front_view_of_a_person_calling_fri_d6810916-71db-4a62-b89b-b19103c0ffdf_1.jpg
# Procesado 340/405: 75P_Create_an_image_in_a_front_view_of_a_person_calling_fri_d6810916-71db-4a62-b89b-b19103c0ffdf_2.jpg
# Procesado 341/405: 75P_Create_an_image_in_a_front_view_of_a_person_calling_fri_d6810916-71db-4a62-b89b-b19103c0ffdf_3.jpg
# Procesado 342/405: 77P_Create_an_image_in_front_view_of_a_person_talking_in_a__cbfa6882-fe54-4d4d-83b5-30cd198749d0_0.jpg
# Procesado 343/405: 77P_Create_an_image_in_front_view_of_a_person_talking_in_a__cbfa6882-fe54-4d4d-83b5-30cd198749d0_1.jpg
# Procesado 344/405: 77P_Create_an_image_in_front_view_of_a_person_talking_in_a__cbfa6882-fe54-4d4d-83b5-30cd198749d0_2.jpg
# Procesado 345/405: 77P_Create_an_image_in_front_view_of_a_person_talking_in_a__cbfa6882-fe54-4d4d-83b5-30cd198749d0_3.jpg
# Procesado 346/405: 79P_Create_an_image_in_front_view_of_a_person_staying_in_to_b8993739-53e2-45ce-b7c2-9d064faaf7d6_0.jpg
# Procesado 347/405: 79P_Create_an_image_in_front_view_of_a_person_staying_in_to_b8993739-53e2-45ce-b7c2-9d064faaf7d6_1.jpg
# Procesado 348/405: 79P_Create_an_image_in_front_view_of_a_person_staying_in_to_b8993739-53e2-45ce-b7c2-9d064faaf7d6_2.jpg
# Procesado 349/405: 79P_Create_an_image_in_front_view_of_a_person_staying_in_to_b8993739-53e2-45ce-b7c2-9d064faaf7d6_3.jpg
# Procesado 350/405: 81P_Create_an_image_of_a_person_receiving_friends_in_a_phot_1c9ee490-9f00-41aa-87ac-030ed1673509_0.jpg
# Procesado 351/405: 81P_Create_an_image_of_a_person_receiving_friends_in_a_phot_1c9ee490-9f00-41aa-87ac-030ed1673509_1.jpg
# Procesado 352/405: 81P_Create_an_image_of_a_person_receiving_friends_in_a_phot_1c9ee490-9f00-41aa-87ac-030ed1673509_2.jpg
# Procesado 353/405: 81P_Create_an_image_of_a_person_receiving_friends_in_a_phot_1c9ee490-9f00-41aa-87ac-030ed1673509_3.jpg
# Procesado 354/405: 82P_a_person_in_a_family_meeting_in_photorealistic_style_--_2f3bff14-948c-4f67-abfb-7aea3d2130ce_0.jpg
# Procesado 355/405: 82P_a_person_in_a_family_meeting_in_photorealistic_style_--_2f3bff14-948c-4f67-abfb-7aea3d2130ce_1.jpg
# Procesado 356/405: 82P_a_person_in_a_family_meeting_in_photorealistic_style_--_2f3bff14-948c-4f67-abfb-7aea3d2130ce_2.jpg
# Procesado 357/405: 82P_a_person_in_a_family_meeting_in_photorealistic_style_--_2f3bff14-948c-4f67-abfb-7aea3d2130ce_3.jpg
# Procesado 358/405: 83P_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_0.jpg
# Procesado 359/405: 83P_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_1.jpg
# Procesado 360/405: 83P_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_2.jpg
# Procesado 361/405: 83P_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_3.jpg
# Procesado 362/405: 84P_a_person_drinking_coffee_in_photorealistic_style_--pers_2f6bb91e-a7dc-4eb8-9169-e38fd6abb5ed_0.jpg
# Procesado 363/405: 84P_a_person_drinking_coffee_in_photorealistic_style_--pers_2f6bb91e-a7dc-4eb8-9169-e38fd6abb5ed_1.jpg
# Procesado 364/405: 84P_a_person_drinking_coffee_in_photorealistic_style_--pers_2f6bb91e-a7dc-4eb8-9169-e38fd6abb5ed_2.jpg
# Procesado 365/405: 84P_a_person_drinking_coffee_in_photorealistic_style_--pers_2f6bb91e-a7dc-4eb8-9169-e38fd6abb5ed_3.jpg
# Procesado 366/405: 85P_Create_an_image_of_a_person_watching_movies_in_a_photor_df13b5bc-be89-4188-b3a8-f089bf1ffd7e_0.jpg
# Procesado 367/405: 85P_Create_an_image_of_a_person_watching_movies_in_a_photor_df13b5bc-be89-4188-b3a8-f089bf1ffd7e_1.jpg
# Procesado 368/405: 85P_Create_an_image_of_a_person_watching_movies_in_a_photor_df13b5bc-be89-4188-b3a8-f089bf1ffd7e_2.jpg
# Procesado 369/405: 85P_Create_an_image_of_a_person_watching_movies_in_a_photor_df13b5bc-be89-4188-b3a8-f089bf1ffd7e_3.jpg
# Procesado 370/405: 87P_Create_an_image_of_a_person_in_a_club_meeting_in_a_phot_fd9ee4b2-ff64-40bd-be58-16b50612c52d_0.jpg
# Procesado 371/405: 87P_Create_an_image_of_a_person_in_a_club_meeting_in_a_phot_fd9ee4b2-ff64-40bd-be58-16b50612c52d_1.jpg
# Procesado 372/405: 87P_Create_an_image_of_a_person_in_a_club_meeting_in_a_phot_fd9ee4b2-ff64-40bd-be58-16b50612c52d_2.jpg
# Procesado 373/405: 87P_Create_an_image_of_a_person_in_a_club_meeting_in_a_phot_fd9ee4b2-ff64-40bd-be58-16b50612c52d_3.jpg
# Procesado 374/405: 88P_a_person_participating_in_community_events_in_photoreal_36398ce1-72e2-4f34-bdac-b3e4dab413fb_0.jpg
# Procesado 375/405: 88P_a_person_participating_in_community_events_in_photoreal_36398ce1-72e2-4f34-bdac-b3e4dab413fb_1.jpg
# Procesado 376/405: 88P_a_person_participating_in_community_events_in_photoreal_36398ce1-72e2-4f34-bdac-b3e4dab413fb_2.jpg
# Procesado 377/405: 88P_a_person_participating_in_community_events_in_photoreal_36398ce1-72e2-4f34-bdac-b3e4dab413fb_3.jpg
# Procesado 378/405: 89P_Create_an_image_of_a_person_attending_a_webinar_in_a_ph_c849e5cd-4421-4f8d-9770-256166854f6d_0.jpg
# Procesado 379/405: 89P_Create_an_image_of_a_person_attending_a_webinar_in_a_ph_c849e5cd-4421-4f8d-9770-256166854f6d_1.jpg
# Procesado 380/405: 89P_Create_an_image_of_a_person_attending_a_webinar_in_a_ph_c849e5cd-4421-4f8d-9770-256166854f6d_2.jpg
# Procesado 381/405: 89P_Create_an_image_of_a_person_attending_a_webinar_in_a_ph_c849e5cd-4421-4f8d-9770-256166854f6d_3.jpg
# Procesado 382/405: 90P_a_portrait_of_a_person_in_a_conference_in_photorealisti_51506e77-3f7e-43fb-a0dd-ce7f89388791_0.jpg
# Procesado 383/405: 90P_a_portrait_of_a_person_in_a_conference_in_photorealisti_51506e77-3f7e-43fb-a0dd-ce7f89388791_1.jpg
# Procesado 384/405: 90P_a_portrait_of_a_person_in_a_conference_in_photorealisti_51506e77-3f7e-43fb-a0dd-ce7f89388791_2.jpg
# Procesado 385/405: 90P_a_portrait_of_a_person_in_a_conference_in_photorealisti_51506e77-3f7e-43fb-a0dd-ce7f89388791_3.jpg
# Procesado 386/405: 91P_Create_an_image_a_person_in_a_study_group_in_a_photorea_0d026547-b941-4e82-ac05-e1d675284678_0.jpg
# Procesado 387/405: 91P_Create_an_image_a_person_in_a_study_group_in_a_photorea_0d026547-b941-4e82-ac05-e1d675284678_1.jpg
# Procesado 388/405: 91P_Create_an_image_a_person_in_a_study_group_in_a_photorea_0d026547-b941-4e82-ac05-e1d675284678_2.jpg
# ...
#
# Imagen: 82OP_an_older_person_in_a_family_meeting_in_photorealistic_s_1b906e05-97b7-4dcd-bb5c-20c3e0e40d84_3.jpg
#   Brillo promedio: 95.22
#   Contraste: 72.53
#   Color dominante:
#     RGB: (6, 7, 9)
#     Hex: #060709
#     CSS: rgb(6, 7, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.23%
#
# Imagen: 83OP_Create_an_image_of_an_older_person_playing_games_in_a_p_00ee7446-8434-4029-a4ca-b13b2fb2f696_0.jpg
#   Brillo promedio: 58.33
#   Contraste: 44.32
#   Color dominante:
#     RGB: (29, 17, 26)
#     Hex: #1d111a
#     CSS: rgb(29, 17, 26)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.18%
#
# Imagen: 83OP_Create_an_image_of_an_older_person_playing_games_in_a_p_00ee7446-8434-4029-a4ca-b13b2fb2f696_1.jpg
#   Brillo promedio: 44.15
#   Contraste: 46.87
#   Color dominante:
#     RGB: (0, 0, 0)
#     Hex: #000000
#     CSS: rgb(0, 0, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 6.59%
#
# Imagen: 83OP_Create_an_image_of_an_older_person_playing_games_in_a_p_00ee7446-8434-4029-a4ca-b13b2fb2f696_2.jpg
#   Brillo promedio: 49.72
#   Contraste: 59.02
#   Color dominante:
#     RGB: (2, 2, 0)
#     Hex: #020200
#     CSS: rgb(2, 2, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.88%
#
# Imagen: 83OP_Create_an_image_of_an_older_person_playing_games_in_a_p_00ee7446-8434-4029-a4ca-b13b2fb2f696_3.jpg
#   Brillo promedio: 41.74
#   Contraste: 46.32
#   Color dominante:
#     RGB: (14, 18, 18)
#     Hex: #0e1212
#     CSS: rgb(14, 18, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.43%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_0.jpg
#   Brillo promedio: 30.78
#   Contraste: 42.78
#   Color dominante:
#     RGB: (3, 4, 6)
#     Hex: #030406
#     CSS: rgb(3, 4, 6)
#     Simplificado: Negro
#   Porcentaje del color dominante: 6.33%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_1.jpg
#   Brillo promedio: 48.66
#   Contraste: 57.12
#   Color dominante:
#     RGB: (6, 9, 8)
#     Hex: #060908
#     CSS: rgb(6, 9, 8)
#     Simplificado: Negro
#   Porcentaje del color dominante: 8.26%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_2.jpg
#   Brillo promedio: 54.99
#   Contraste: 54.49
#   Color dominante:
#     RGB: (11, 13, 14)
#     Hex: #0b0d0e
#     CSS: rgb(11, 13, 14)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.91%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_3.jpg
#   Brillo promedio: 39.21
#   Contraste: 54.05
#   Color dominante:
#     RGB: (6, 6, 4)
#     Hex: #060604
#     CSS: rgb(6, 6, 4)
#     Simplificado: Negro
#   Porcentaje del color dominante: 9.60%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_0.jpg
#   Brillo promedio: 50.72
#   Contraste: 38.26
#   Color dominante:
#     RGB: (34, 38, 39)
#     Hex: #222627
#     CSS: rgb(34, 38, 39)
#     Simplificado: Negro
#   Porcentaje del color dominante: 12.77%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_1.jpg
#   Brillo promedio: 51.82
#   Contraste: 62.84
#   Color dominante:
#     RGB: (0, 0, 0)
#     Hex: #000000
#     CSS: rgb(0, 0, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 38.18%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_2.jpg
#   Brillo promedio: 53.46
#   Contraste: 51.92
#   Color dominante:
#     RGB: (10, 21, 19)
#     Hex: #0a1513
#     CSS: rgb(10, 21, 19)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.56%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_3.jpg
#   Brillo promedio: 49.48
#   Contraste: 58.11
#   Color dominante:
#     RGB: (4, 6, 6)
#     Hex: #040606
#     CSS: rgb(4, 6, 6)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.00%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_0.jpg
#   Brillo promedio: 52.28
#   Contraste: 58.82
#   Color dominante:
#     RGB: (5, 6, 7)
#     Hex: #050607
#     CSS: rgb(5, 6, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.37%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_1.jpg
#   Brillo promedio: 63.04
#   Contraste: 66.26
#   Color dominante:
#     RGB: (24, 20, 17)
#     Hex: #181411
#     CSS: rgb(24, 20, 17)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.42%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_2.jpg
#   Brillo promedio: 66.13
#   Contraste: 79.15
#   Color dominante:
#     RGB: (4, 4, 6)
#     Hex: #040406
#     CSS: rgb(4, 4, 6)
#     Simplificado: Negro
#   Porcentaje del color dominante: 12.46%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_3.jpg
#   Brillo promedio: 58.13
#   Contraste: 54.19
#   Color dominante:
#     RGB: (14, 16, 18)
#     Hex: #0e1012
#     CSS: rgb(14, 16, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.31%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_0.jpg
#   Brillo promedio: 145.63
#   Contraste: 65.52
#   Color dominante:
#     RGB: (131, 224, 227)
#     Hex: #83e0e3
#     CSS: rgb(131, 224, 227)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 1.03%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_1.jpg
#   Brillo promedio: 135.24
#   Contraste: 68.87
#   Color dominante:
#     RGB: (255, 255, 255)
#     Hex: #ffffff
#     CSS: rgb(255, 255, 255)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 3.23%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_2.jpg
#   Brillo promedio: 65.92
#   Contraste: 56.00
#   Color dominante:
#     RGB: (12, 16, 25)
#     Hex: #0c1019
#     CSS: rgb(12, 16, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.90%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_3.jpg
#   Brillo promedio: 118.88
#   Contraste: 76.62
#   Color dominante:
#     RGB: (246, 246, 246)
#     Hex: #f6f6f6
#     CSS: rgb(246, 246, 246)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 2.90%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_0.jpg
#   Brillo promedio: 43.53
#   Contraste: 42.99
#   Color dominante:
#     RGB: (27, 30, 15)
#     Hex: #1b1e0f
#     CSS: rgb(27, 30, 15)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.99%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_1.jpg
#   Brillo promedio: 30.51
#   Contraste: 34.04
#   Color dominante:
#     RGB: (14, 15, 10)
#     Hex: #0e0f0a
#     CSS: rgb(14, 15, 10)
#     Simplificado: Negro
#   Porcentaje del color dominante: 7.04%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_2.jpg
#   Brillo promedio: 68.93
#   Contraste: 59.25
#   Color dominante:
#     RGB: (8, 20, 12)
#     Hex: #08140c
#     CSS: rgb(8, 20, 12)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.41%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_3.jpg
#   Brillo promedio: 93.84
#   Contraste: 53.82
#   Color dominante:
#     RGB: (41, 42, 39)
#     Hex: #292a27
#     CSS: rgb(41, 42, 39)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.08%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_0.jpg
#   Brillo promedio: 50.90
#   Contraste: 63.35
#   Color dominante:
#     RGB: (3, 6, 7)
#     Hex: #030607
#     CSS: rgb(3, 6, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 8.36%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_1.jpg
#   Brillo promedio: 27.33
#   Contraste: 41.62
#   Color dominante:
#     RGB: (8, 9, 7)
#     Hex: #080907
#     CSS: rgb(8, 9, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 8.96%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_2.jpg
#   Brillo promedio: 38.67
#   Contraste: 43.60
#   Color dominante:
#     RGB: (6, 7, 10)
#     Hex: #06070a
#     CSS: rgb(6, 7, 10)
#     Simplificado: Negro
#   Porcentaje del color dominante: 7.86%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_3.jpg
#   Brillo promedio: 36.00
#   Contraste: 48.25
#   Color dominante:
#     RGB: (4, 10, 9)
#     Hex: #040a09
#     CSS: rgb(4, 10, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 14.09%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_0.jpg
#   Brillo promedio: 50.38
#   Contraste: 57.74
#   Color dominante:
#     RGB: (8, 9, 11)
#     Hex: #08090b
#     CSS: rgb(8, 9, 11)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.69%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_1.jpg
#   Brillo promedio: 63.76
#   Contraste: 55.27
#   Color dominante:
#     RGB: (4, 25, 19)
#     Hex: #041913
#     CSS: rgb(4, 25, 19)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.46%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_2.jpg
#   Brillo promedio: 39.97
#   Contraste: 53.89
#   Color dominante:
#     RGB: (3, 3, 5)
#     Hex: #030305
#     CSS: rgb(3, 3, 5)
#     Simplificado: Negro
#   Porcentaje del color dominante: 7.64%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_3.jpg
#   Brillo promedio: 46.06
#   Contraste: 57.01
#   Color dominante:
#     RGB: (7, 9, 11)
#     Hex: #07090b
#     CSS: rgb(7, 9, 11)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.07%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_0.jpg
#   Brillo promedio: 70.88
#   Contraste: 50.95
#   Color dominante:
#     RGB: (25, 26, 30)
#     Hex: #191a1e
#     CSS: rgb(25, 26, 30)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.17%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_1.jpg
#   Brillo promedio: 74.26
#   Contraste: 60.40
#   Color dominante:
#     RGB: (18, 16, 18)
#     Hex: #121012
#     CSS: rgb(18, 16, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.54%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_2.jpg
#   Brillo promedio: 54.64
#   Contraste: 53.45
#   Color dominante:
#     RGB: (15, 16, 22)
#     Hex: #0f1016
#     CSS: rgb(15, 16, 22)
#     Simplificado: Negro
#   Porcentaje del color dominante: 5.84%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_3.jpg
#   Brillo promedio: 76.23
#   Contraste: 56.71
#   Color dominante:
#     RGB: (51, 46, 25)
#     Hex: #332e19
#     CSS: rgb(51, 46, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.38%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_0.jpg
#   Brillo promedio: 48.76
#   Contraste: 49.49
#   Color dominante:
#     RGB: (15, 15, 12)
#     Hex: #0f0f0c
#     CSS: rgb(15, 15, 12)
#     Simplificado: Negro
#   Porcentaje del color dominante: 5.01%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_1.jpg
#   Brillo promedio: 57.15
#   Contraste: 73.06
#   Color dominante:
#     RGB: (3, 3, 3)
#     Hex: #030303
#     CSS: rgb(3, 3, 3)
#     Simplificado: Negro
#   Porcentaje del color dominante: 13.09%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_2.jpg
#   Brillo promedio: 29.82
#   Contraste: 44.63
#   Color dominante:
#     RGB: (5, 5, 0)
#     Hex: #050500
#     CSS: rgb(5, 5, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 11.24%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_3.jpg
#   Brillo promedio: 34.57
#   Contraste: 45.82
#   Color dominante:
#     RGB: (0, 0, 0)
#     Hex: #000000
#     CSS: rgb(0, 0, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 21.56%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_0.jpg
#   Brillo promedio: 57.08
#   Contraste: 51.44
#   Color dominante:
#     RGB: (6, 9, 19)
#     Hex: #060913
#     CSS: rgb(6, 9, 19)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.16%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_1.jpg
#   Brillo promedio: 60.73
#   Contraste: 61.83
#   Color dominante:
#     RGB: (10, 10, 9)
#     Hex: #0a0a09
#     CSS: rgb(10, 10, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 6.25%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_2.jpg
#   Brillo promedio: 39.77
#   Contraste: 42.66
#   Color dominante:
#     RGB: (8, 10, 13)
#     Hex: #080a0d
#     CSS: rgb(8, 10, 13)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.23%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_3.jpg
#   Brillo promedio: 31.17
#   Contraste: 40.34
#   Color dominante:
#     RGB: (5, 6, 8)
#     Hex: #050608
#     CSS: rgb(5, 6, 8)
#     Simplificado: Negro
#   Porcentaje del color dominante: 9.35%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_0.jpg
#   Brillo promedio: 65.13
#   Contraste: 53.46
#   Color dominante:
#     RGB: (3, 15, 17)
#     Hex: #030f11
#     CSS: rgb(3, 15, 17)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.47%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_1.jpg
#   Brillo promedio: 81.31
#   Contraste: 73.73
#   Color dominante:
#     RGB: (13, 13, 17)
#     Hex: #0d0d11
#     CSS: rgb(13, 13, 17)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.96%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_2.jpg
#   Brillo promedio: 95.74
#   Contraste: 68.15
#   Color dominante:
#     RGB: (82, 7, 7)
#     Hex: #520707
#     CSS: rgb(82, 7, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.06%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_3.jpg
#   Brillo promedio: 64.75
#   Contraste: 68.08
#   Color dominante:
#     RGB: (4, 5, 9)
#     Hex: #040509
#     CSS: rgb(4, 5, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.55%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_0.jpg
#   Brillo promedio: 72.67
#   Contraste: 59.80
#   Color dominante:
#     RGB: (16, 17, 20)
#     Hex: #101114
#     CSS: rgb(16, 17, 20)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.58%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_1.jpg
#   Brillo promedio: 81.12
#   Contraste: 73.77
#   Color dominante:
#     RGB: (30, 32, 27)
#     Hex: #1e201b
#     CSS: rgb(30, 32, 27)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.50%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_2.jpg
#   Brillo promedio: 58.91
#   Contraste: 63.13
#   Color dominante:
#     RGB: (16, 16, 11)
#     Hex: #10100b
#     CSS: rgb(16, 16, 11)
#     Simplificado: Negro
#   Porcentaje del color dominante: 6.00%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_3.jpg
#   Brillo promedio: 64.75
#   Contraste: 63.15
#   Color dominante:
#     RGB: (15, 15, 10)
#     Hex: #0f0f0a
#     CSS: rgb(15, 15, 10)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.46%

# %%
pil_n = pd.DataFrame(resultados_n)
pil_o = pd.DataFrame(resultados_o)
pil = pd.concat([pil_n, pil_o], axis=0)

# %%
df_merged = pd.merge(df_merged, pil, on='filename_jpg', how='left')

# %%
df_merged['color_dominante'] = df_merged['color_dominante'].apply(
    lambda x: x.get('simplificado', '').lower())

# %%
df_merged.to_csv(f'{output_dir}/df_merged_mid_29_8.csv', index=False)
#sample = df_merged.sample(30)
#sample.to_csv(f'{output_folder}/sample.csv', index=False)
