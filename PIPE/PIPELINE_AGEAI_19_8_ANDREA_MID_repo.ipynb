# %% [markdown]
# # SETUP

# %%
import os
import re
import ast
import json
import ollama
import random
import base64
import requests
import itertools
import numpy as np
import pandas as pd
from tqdm import tqdm
from PIL import Image
from scipy import stats
from itertools import product
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# # DF

# %%
folder_path = r'06_08_midjourney_activities'

description_list = []

prompt_pattern = re.compile(r'(.*?)(?= --personalize| --style|$)', re.DOTALL)

for file_name in os.listdir(folder_path):
    if file_name.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.tiff')):
        file_path = os.path.join(folder_path, file_name)
        
        image = Image.open(file_path)
        
        info = image.info
        
        description = info.get('Description', None)
        
        if description:
            match = prompt_pattern.match(description)
            cleaned_description = match.group(1) if match else description
        else:
            cleaned_description = None
        
        description_list.append({'filename': file_name, 'prompt': cleaned_description})

df = pd.DataFrame(description_list, columns=['filename', 'prompt'])

df['codi'] = df['filename'].str.split('_').str[0]

df['age_group'] = df['filename'].apply(lambda x: 'older' if 'OP' in x else 'neutral')

df['ID_num'] = df['codi'].str.extract('(\d+)')

df['ID_num'] = pd.to_numeric(df['ID_num'])
df=df.sort_values(by='ID_num', ascending=True)

df = df.reset_index(drop=True)

df_older = df[df['age_group'] == 'older']
df_neutral = df[df['age_group'] == 'neutral']

df_older['ID'] = ''
for prompt in df_older['ID_num'].unique():
    df_subset = df_older[df_older['ID_num'] == prompt]
    count = 1
    for index, row in df_subset.iterrows():
        df_older.loc[index, 'ID'] = f'o_p{row["ID_num"]}_f{count}'
        count += 1

df_neutral['ID'] = ''
for prompt in df_neutral['ID_num'].unique():
    df_subset = df_neutral[df_neutral['ID_num'] == prompt]
    count = 1
    for index, row in df_subset.iterrows():
        df_neutral.loc[index, 'ID'] = f'a_p{row["ID_num"]}_f{count}'
        count += 1

# %%
output_dir = "06_08_midjourney_activities/CSV/"
os.makedirs(output_dir, exist_ok=True)
df_older.to_csv(os.path.join(output_dir, "df_older.csv"), index=False)
df_neutral.to_csv(os.path.join(output_dir, "df_neutral.csv"), index=False)

# %%
def reduce_image_size(image, max_width, max_height):
    width, height = image.size
    if width > max_width or height > max_height:
        image.thumbnail((max_width, max_height), Image.LANCZOS)
    return image

def process_images(input_folder, neutral_df, older_df, neutral_subfolder, older_subfolder):
    neutral_output_folder = os.path.join(input_folder, neutral_subfolder)
    older_output_folder = os.path.join(input_folder, older_subfolder)
    
    if not os.path.exists(neutral_output_folder):
        os.makedirs(neutral_output_folder)
    if not os.path.exists(older_output_folder):
        os.makedirs(older_output_folder)
    
    neutral_files = neutral_df['filename'].tolist()
    older_files = older_df['filename'].tolist()
    
    for filename in os.listdir(input_folder):
        if filename.endswith('.png'):
            input_path = os.path.join(input_folder, filename)
            
            if filename in neutral_files:
                output_folder = neutral_output_folder
            elif filename in older_files:
                output_folder = older_output_folder
            else:
                print(f"Archivo no clasificado: {filename}")
                continue
            
            output_path = os.path.join(output_folder, os.path.splitext(filename)[0] + '.jpg')

            try:
                with Image.open(input_path) as img:
                    img = reduce_image_size(img, 1024, 1024)
                    img = img.convert('RGB')
                    img.save(output_path, 'JPEG', optimize=True, quality=85)
            except Exception as e:
                print(f"Error procesando {filename}: {e}")

    print("Proceso completado.")

input_folder = folder_path
neutral_subfolder = 'neutral_comp'
older_subfolder = 'older_comp'

process_images(input_folder, df_neutral, df_older, neutral_subfolder, older_subfolder)
# Out:
# Proceso completado.

# %% [markdown]
# # OLLAMA

# %%
prompts = {
    "gender": "Answer only with the options provided: the gender of the person is: male, female, or if it's not possible to determine, none. Return answer as a JSON object {\"gender\": [\"gender\"]}.",
    "age_range": "Estimate the age range of the person in the image. Just answer with the following range of numbers: 18-24, 25-34, 35-44, 45-54, 55-64, 65-79 or 80+. Return answer only as a JSON object {\"age\": [\"range\"]}.",
    "race": "Estimate the race of the person in this image. Just answer with the following options: asian, black, white, hispanic, or other. Return answer only as a JSON object {\"race\": [\"race\"]}",
    "emotions_short": "Answer only with the options provided: the emotion expressed by the person is: neutral, positive, negative, or exaggerated. Return it as a JSON object {\"emotion\": [\"emotion\"]}",
    "personality_short": "Answer only with the options listed and no further information: the personality trait expressed by the person is: Openness, Conscientiousness, Extraversion, Agreeableness, or Neuroticism. Return it as a JSON object {\"personality\": [\"personality\"]}.",
    "location": "Answer only the options provided: The image is taken indoors, outdoors, or not possible to identify. Return it as a JSON object {\"location\": [\"location\"]} .",    
    "objects": "List up to 10 objects visible in this image. Return it as a JSON object as {\"objects\": [\"object\",...]}",
    "objects_assist_devices": "List any assistive devices visible in the image. Return it as a JSON object as {\"assistive_devices\": [\"object\",...]}",
    "objects_digi_devices": "List any digital devices visible in the image. Return it as a JSON object as {\"digital_devices\": [\"object\",...]}.",
    "person_count": "Answer only with the options provided: how many people can you count: 1, 2 or 3 or +3. Return answer as a JSON object {\"person_count\": [\"count\"]}.",
    "shot": "Answer only with the options provided: the type of shot in the image is: close-up shot, medium shot, or full shot. Return answer as a JSON object {\"shot\": [\"shot\"]}.",
    "position_short": "Describe the posture of the person in the image with one word. Be very concise and precise in you answer (standing, sitting, lying, etc.). Return answer as a JSON object {\"position\": [\"position\"]}.",
}

# %%
def call_ollama(image_path, prompt):
    try:
        with open(image_path, 'rb') as file:
            image_bytes = file.read()
        
        response = ollama.chat(
            model='llava',
            messages=[
                {
                    'role': 'user',
                    'content': prompt,
                    'images': [image_bytes],
                },
            ],
        )
        return response['message']['content']
    except Exception as e:
        print(f"Error calling Ollama: {e}")
        return "Error"

def process_image(image_path):
    try:
        results = {"ID_jpg": os.path.basename(image_path)}
        
        for prompt_name, prompt_text in prompts.items():
            results[prompt_name] = call_ollama(image_path, prompt_text)
        
        return results
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return {"ID_jpg": os.path.basename(image_path), "error": str(e)}

def process_folder(folder_path):
    all_results = []
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    for image_file in tqdm(image_files, desc="Processing images"):
        image_path = os.path.join(folder_path, image_file)
        results = process_image(image_path)
        all_results.append(results)
    
    return pd.DataFrame(all_results)

# %%
#NEUTRAL
df_neutral_results = process_folder("06_08_midjourney_activities/neutral_comp")
df_neutral_results.to_csv("06_08_midjourney_activities/CSV/neutral_analysis_llava.csv", index=False)
print(f"Results saved")
# Out:
# Processing images:   0%|          | 0/457 [00:00<?, ?it/s]
# Processing images: 100%|██████████| 457/457 [1:10:01<00:00,  9.19s/it]
# Results saved

# %%
#OLDER
df_older_results = process_folder("/06_08_midjourney_activities/older_comp")
df_older_results.to_csv("older_comp/older_analysis_llava.csv", index=False)
print(f"Results saved")
# Out:
# Processing images: 100%|██████████| 431/431 [1:14:04<00:00, 10.31s/it]
# Results saved

# %% [markdown]
# # MERGE FINAL

# %%
output_dir = "06_08_midjourney_activities/CSV/"

df_neutral = pd.read_csv(f'{output_dir}/df_neutral.csv')
df_older = pd.read_csv(f'{output_dir}/df_older.csv')
df_merged = pd.concat([df_neutral, df_older], axis=0)
df_merged = df_merged.rename(columns={'filename': 'filename_png'})
df_merged['filename_merge'] = df_merged['filename_png'].str.replace('.png', '')

df_neutral_cv = pd.read_csv("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities/CSV/neutral_analysis_llava.csv")
df_neutral_cv = df_neutral_cv.rename(columns={'number': 'person_count'})
df_older_cv = pd.read_csv("C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/06_08_midjourney_activities/CSV/older_analysis_llava.csv")

df_merged_2 = pd.concat([df_neutral_cv, df_older_cv], axis=0)
df_merged_2 = df_merged_2.rename(columns={'ID_jpg': 'filename_jpg'})   

df_merged_2['filename_merge'] = df_merged_2['filename_jpg'].str.replace('.jpg', '')
df_merged = pd.merge(df_merged, df_merged_2, on='filename_merge', how='left')
df_merged = df_merged.drop(columns=["ID_num", "filename_merge"])

# %%
def clean_json(text):
    if isinstance(text, str):
        cleaned_text = re.sub(r'```json', '', text)  
        cleaned_text = re.sub(r'```', '', cleaned_text)  
        
        cleaned_text = re.sub(r'\{\s+', '{', cleaned_text)
        cleaned_text = re.sub(r'\s+\}', '}', cleaned_text)
        
        cleaned_text = cleaned_text.replace('\n', '').strip()
        
        return cleaned_text
    return text

def ensure_list_format(value):
    if isinstance(value, str):
        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict):
                for key in data:
                    if not isinstance(data[key], list):
                        data[key] = [data[key]]
                return str(data)
            return value
        except:
            return value
    return value

columns_to_transform = [
    'gender', 
    'age_range', 
    'race', 
    'emotions_short', 
    'location', 
    'personality_short', 
    'shot', 
    'position_short',
    'objects',
    'objects_assist_devices',
    'objects_digi_devices',
    'person_count'
]

for column in df_merged.columns:
    if column not in ['filename_png', 'filename_jpg']:
        df_merged[column] = df_merged[column].apply(clean_json)
        df_merged[column] = df_merged[column].apply(lambda x: x.lower() if isinstance(x, str) else x)
        df_merged[column] = df_merged[column].apply(ensure_list_format)

# %%
df_merged
# Out:
#                                           filename_png  \
# 0    01P_a_person_walking_to_the_bathroom_in_photor...
# 1    01P_a_person_walking_to_the_bathroom_in_photor...
# 2    01P_a_person_walking_to_the_bathroom_in_photor...
# 3    01P_a_person_walking_to_the_bathroom_in_photor...
# 4    2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..                                                 ...
# 883  139OP_a_front_photo_of_an_older_person_doing_d...
# 884  140OP_an_older_person_at_the_hospital_in_photo...
# 885  140OP_an_older_person_at_the_hospital_in_photo...
# 886  140OP_an_older_person_at_the_hospital_in_photo...
# 887  140OP_an_older_person_at_the_hospital_in_photo...
#
#                                                 prompt   codi age_group  \
# 0    a person walking to the bathroom in photoreali...    01p   neutral
# 1    a person walking to the bathroom in photoreali...    01p   neutral
# 2    a person walking to the bathroom in photoreali...    01p   neutral
# 3    a person walking to the bathroom in photoreali...    01p   neutral
# 4    a front photo of a person walking to a store i...     2p   neutral
# ..                                                 ...    ...       ...
# 883  a front photo of an older person doing diet an...  139op     older
# 884  an older person at the hospital in photorealis...  140op     older
# 885  an older person at the hospital in photorealis...  140op     older
# 886  an older person at the hospital in photorealis...  140op     older
# 887  an older person at the hospital in photorealis...  140op     older
#
#             ID                                       filename_jpg  \
# 0      a_p1_f1  01P_a_person_walking_to_the_bathroom_in_photor...
# 1      a_p1_f2  01P_a_person_walking_to_the_bathroom_in_photor...
# 2      a_p1_f3  01P_a_person_walking_to_the_bathroom_in_photor...
# 3      a_p1_f4  01P_a_person_walking_to_the_bathroom_in_photor...
# 4      a_p2_f1  2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..         ...                                                ...
# 883  o_p139_f4  139OP_a_front_photo_of_an_older_person_doing_d...
# 884  o_p140_f1  140OP_an_older_person_at_the_hospital_in_photo...
# 885  o_p140_f2  140OP_an_older_person_at_the_hospital_in_photo...
# 886  o_p140_f3  140OP_an_older_person_at_the_hospital_in_photo...
# 887  o_p140_f4  140OP_an_older_person_at_the_hospital_in_photo...
#
#                      gender           age_range                 race  \
# 0      {'gender': ['male']}  {'age': ['25-34']}  {'race': ['white']}
# 1      {'gender': ['male']}  {'age': ['18-24']}  {'race': ['white']}
# 2      {'gender': ['male']}  {'age': ['45-54']}  {'race': ['white']}
# 3    {'gender': ['female']}  {'age': ['35-44']}  {'race': ['other']}
# 4      {'gender': ['male']}  {'age': ['25-34']}  {'race': ['white']}
# ..                      ...                 ...                  ...
# 883    {'gender': ['male']}  {'age': ['65-79']}  {'race': ['white']}
# 884    {'gender': ['male']}  {'age': ['65-79']}  {'race': ['white']}
# 885  {'gender': ['female']}  {'age': ['65-79']}  {'race': ['white']}
# 886    {'gender': ['male']}  {'age': ['65-79']}  {'race': ['white']}
# 887    {'gender': ['male']}  {'age': ['65-79']}  {'race': ['white']}
#
#                emotions_short                   personality_short  \
# 0    {'emotion': ['neutral']}       {'personality': ['openness']}
# 1    {'emotion': ['neutral']}    {'personality': ['neuroticism']}
# 2    {'emotion': ['neutral']}       {'personality': ['openness']}
# 3    {'emotion': ['neutral']}       {'personality': ['openness']}
# 4    {'emotion': ['neutral']}   {'personality': ['extraversion']}
# ..                        ...                                 ...
# 883  {'emotion': ['neutral']}  {'personality': ['agreeableness']}
# 884  {'emotion': ['neutral']}  {'personality': ['agreeableness']}
# 885  {'emotion': ['neutral']}       {'personality': ['openness']}
# 886  {'emotion': ['neutral']}    {'personality': ['neuroticism']}
# 887  {'emotion': ['neutral']}       {'personality': ['openness']}
#
#                        location  \
# 0    {'location': ['outdoors']}
# 1      {'location': ['indoor']}
# 2      {'location': ['indoor']}
# 3      {'location': ['indoor']}
# 4    {'location': ['outdoors']}
# ..                          ...
# 883    {'location': ['indors']}
# 884    {'location': ['indoor']}
# 885    {'location': ['indoor']}
# 886    {'location': ['indoor']}
# 887    {'location': ['indoor']}
#
#                                                objects  \
# 0    {'objects': ['toilet paper dispenser', 'shower...
# 1    {'objects': ['floor', 'wall tiles', 'person wa...
# 2    {'objects': ['person', 'plant', 'door', 'sink'...
# 3    {'objects': ['person', 'tiled floor', 'shower ...
# 4    {'objects': ['person', 'store front with signa...
# ..                                                 ...
# 883  {'objects': ['man', 'book', 'pen', 'spice jar'...
# 884  {'objects': ['person', 'bed', 'pillow', 'blank...
# 885  {'objects': ['bed', 'pillow', 'headband', 'hos...
# 886  {'objects': ['man', 'glasses', 'bench', 'waiti...
# 887  {'objects': ['man', 'hospital bed', 'sheets', ...
#
#                                 objects_assist_devices  \
# 0    {'assistive_devices': ['handicapped accessible...
# 1                            {'assistive_devices': []}
# 2    {'assistive_devices': ['sink', 'door', 'window']}
# 3                    {'assistive_devices': ['faucet']}
# 4                  {'assistive_devices': ['backpack']}
# ..                                                 ...
# 883                     {'assistive_devices': ['pen']}
# 884            {'assistive_devices': ['hospital bed']}
# 885                     {'assistive_devices': ['bed']}
# 886                          {'assistive_devices': []}
# 887            {'assistive_devices': ['hospital bed']}
#
#                           objects_digi_devices             person_count  \
# 0                      {'digital_devices': []}  {'person_count': ['1']}
# 1                      {'digital_devices': []}  {'person_count': ['1']}
# 2    {'digital_devices': ['object', Ellipsis]}  {'person_count': ['1']}
# 3      {'digital_devices': ['sink', 'toilet']}  {'person_count': ['1']}
# 4                      {'digital_devices': []}  {'person_count': ['1']}
# ..                                         ...                      ...
# 883               {'digital_devices': ['pen']}  {'person_count': ['1']}
# 884           {'digital_devices': ['monitor']}  {'person_count': ['1']}
# 885           {'digital_devices': ['monitor']}  {'person_count': ['1']}
# 886                    {'digital_devices': []}  {'person_count': ['1']}
# 887                    {'digital_devices': []}  {'person_count': ['1']}
#
#                             shot              position_short
# 0    {'shot': ['close-up shot']}  {'position': ['standing']}
# 1           {'shot': ['medium']}  {'position': ['standing']}
# 2    {'shot': ['close-up shot']}  {'position': ['standing']}
# 3    {'shot': ['close-up shot']}  {'position': ['standing']}
# 4      {'shot': ['medium shot']}  {'position': ['standing']}
# ..                           ...                         ...
# 883  {'shot': ['close-up shot']}   {'position': ['sitting']}
# 884  {'shot': ['close-up shot']}     {'position': ['lying']}
# 885  {'shot': ['close-up shot']}     {'position': ['lying']}
# 886  {'shot': ['close-up shot']}   {'position': ['sitting']}
# 887  {'shot': ['close-up shot']}   {'position': ['sitting']}
#
# [888 rows x 18 columns]

# %%
mapping = {
    #'{"location": ["indoor"]}': '{"location": ["indoors"]}',
    "{'location': ['indoor']}": "{'location': ['indoors']}",
    #'{"location": "indoors"}': '{"location": ["indoors"]}',
    #'{"location": "indoor"}': '{"location": ["indoors"]}',
    "{'location': ['indors']}": "{'location': ['indoors']}",
    "{'location': ['inddoors']}": "{'location': ['indoors']}",  
    "{'location': ['individual']}": "{'location': ['indoors']}",  
    "{'location': ['indicators']}": "{'location': ['indoors']}",  
}
df_merged['location'] = df_merged['location'].map(mapping).fillna(df_merged['location'])
df_merged['location'].unique()

mapping = {
    #'{"shot": "close-up shot"}': '{"shot": ["close-up shot"]}',
    #'{"shot": "full shot"}': '{"shot": ["full shot"]}',
    "{'shot': ['medium']}": "{'shot': ['medium shot']}",
    #'{"shot": ["medium"]}': '{"shot": ["medium shot"]}',
    #'{"shot": "medium shot"}': '{"shot": ["medium shot"]}',
    "{'shot': ['close-up']}": "{'shot': ['close-up shot']}",
}
df_merged['shot'] = df_merged['shot'].map(mapping).fillna(df_merged['shot'])
df_merged['shot'].unique()

#PERSON COUNT
def normalize_person_count(value):
    value = value.strip(".")
    
    value = re.sub(r'["]', "'", value)  
    value = re.sub(r"''", "'", value)  
    
    numbers = re.findall(r"'(\d+)'", value)
    if not numbers:  
        numbers = re.findall(r"(\d+)", value)
    
    if numbers:
        numbers = list(map(int, numbers))
        if any(num >= 3 for num in numbers):
            return "{'person_count': ['+3']}"
        else:
            return "{'person_count': ['" + "', '".join(map(str, numbers)) + "']}"
    else:
        return value

df_merged['person_count'] = df_merged['person_count'].apply(normalize_person_count)

mapping = {
    "{'person_count': [1]}": "{'person_count': ['1']}",
    "{'person_count': [2]}": "{'person_count': ['2']}",
    "{'person_count': [3]}": "{'person_count': ['3']}",
}
df_merged['person_count'] = df_merged['person_count'].map(mapping).fillna(df_merged['person_count'])
df_merged['person_count'].unique()
# Out:
# array(["{'person_count': ['1']}", "{'person_count': ['0']}",
#        "{'person_count': ['+3']}", "{'person_count': ['2']}"],
#       dtype=object)

# %%
def ensure_list(value):
    if isinstance(value, str):
        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict):
                return list(data.values())[0] if isinstance(list(data.values())[0], list) else [list(data.values())[0]]
            elif isinstance(data, list):
                return data
        except:
            return [value]  
    return value if isinstance(value, list) else [value]  

def is_list(value):
    return isinstance(value, list)

columns_to_transform = [
    'gender',
    'age_range',
    'race', 
    'emotions_short', 
    'location', 
    'personality_short', 
    'shot', 
    'position_short',
    'objects',
    'objects_assist_devices',
    'objects_digi_devices',
    'person_count',
    'shot'
]

for column in columns_to_transform:
    df_merged[column] = df_merged[column].apply(ensure_list)

for column in columns_to_transform:
    if df_merged[column].apply(is_list).all():
        print(f"Todos los valores en la columna '{column}' son listas de Python.")
    else:
        print(f"Algunos valores en la columna '{column}' NO son listas de Python.")

def convert_assist_devices(value):
    if isinstance(value, list) or isinstance(value, str):
        if isinstance(value, list):
            value = str(value)

        if 'assistive_devices' in value:
            return ['none']
        
        if isinstance(value, str) and not value.strip():
            return ['none']

        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict) and 'assistive_devices' in data:
                return ['none']
        except (ValueError, SyntaxError):
            pass

    if isinstance(value, list) and not value:
        return ['none']
    return value

df_merged['objects_assist_devices'] = df_merged['objects_assist_devices'].apply(convert_assist_devices)

def convert_digi_devices(value):
    if isinstance(value, list) or isinstance(value, str):
        if isinstance(value, list):
            value = str(value)

        if 'digital_devices' in value:
            return ['none']
        
        if isinstance(value, str) and not value.strip():
            return ['none']

        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict) and 'digital_devices' in data:
                return ['none']
        except (ValueError, SyntaxError):
            pass

    if isinstance(value, list) and not value:
        return ['none']
    return value

df_merged['objects_digi_devices'] = df_merged['objects_digi_devices'].apply(convert_digi_devices)
# Out:
# Todos los valores en la columna 'gender' son listas de Python.
# Todos los valores en la columna 'age_range' son listas de Python.
# Todos los valores en la columna 'race' son listas de Python.
# Todos los valores en la columna 'emotions_short' son listas de Python.
# Todos los valores en la columna 'location' son listas de Python.
# Todos los valores en la columna 'personality_short' son listas de Python.
# Todos los valores en la columna 'shot' son listas de Python.
# Todos los valores en la columna 'position_short' son listas de Python.
# Todos los valores en la columna 'objects' son listas de Python.
# Todos los valores en la columna 'objects_assist_devices' son listas de Python.
# Todos los valores en la columna 'objects_digi_devices' son listas de Python.
# Todos los valores en la columna 'person_count' son listas de Python.
# Todos los valores en la columna 'shot' son listas de Python.

# %%
df_merged
# Out:
#                                           filename_png  \
# 0    01P_a_person_walking_to_the_bathroom_in_photor...
# 1    01P_a_person_walking_to_the_bathroom_in_photor...
# 2    01P_a_person_walking_to_the_bathroom_in_photor...
# 3    01P_a_person_walking_to_the_bathroom_in_photor...
# 4    2P_a_front_photo_of_a_person_walking_to_a_stor...
# ..                                                 ...
# 883  139OP_a_front_photo_of_an_older_person_doing_d...
# 884  140OP_an_older_person_at_the_hospital_in_photo...
# 885  140OP_an_older_person_at_the_hospital_in_photo...
# 886  140OP_an_older_person_at_the_hospital_in_photo...
# 887  140OP_an_older_person_at_the_hospital_in_photo...
#
#                                                 prompt   codi age_group  \
# 0    a person walking to the bathroom in photoreali...    01p   neutral
# 1    a person walking to the bathroom in photoreali...    01p   neutral
# 2    a person walking to the bathroom in photoreali...    01p   neutral
# 3    a person walking to the bathroom in photoreali...    01p   neutral
# 4    a front photo of a person walking to a store i...     2p   neutral
# ..                                                 ...    ...       ...
# 883  a front photo of an older person doing diet an...  139op     older
# 884  an older person at the hospital in photorealis...  140op     older
# 885  an older person at the hospital in photorealis...  140op     older
# 886  an older person at the hospital in photorealis...  140op     older
# 887  an older person at the hospital in photorealis...  140op     older
#
#             ID                                       filename_jpg    gender  \
# 0      a_p1_f1  01P_a_person_walking_to_the_bathroom_in_photor...    [male]
# 1      a_p1_f2  01P_a_person_walking_to_the_bathroom_in_photor...    [male]
# 2      a_p1_f3  01P_a_person_walking_to_the_bathroom_in_photor...    [male]
# 3      a_p1_f4  01P_a_person_walking_to_the_bathroom_in_photor...  [female]
# 4      a_p2_f1  2P_a_front_photo_of_a_person_walking_to_a_stor...    [male]
# ..         ...                                                ...       ...
# 883  o_p139_f4  139OP_a_front_photo_of_an_older_person_doing_d...    [male]
# 884  o_p140_f1  140OP_an_older_person_at_the_hospital_in_photo...    [male]
# 885  o_p140_f2  140OP_an_older_person_at_the_hospital_in_photo...  [female]
# 886  o_p140_f3  140OP_an_older_person_at_the_hospital_in_photo...    [male]
# 887  o_p140_f4  140OP_an_older_person_at_the_hospital_in_photo...    [male]
#
#     age_range     race emotions_short personality_short    location  \
# 0     [25-34]  [white]      [neutral]        [openness]  [outdoors]
# 1     [18-24]  [white]      [neutral]     [neuroticism]   [indoors]
# 2     [45-54]  [white]      [neutral]        [openness]   [indoors]
# 3     [35-44]  [other]      [neutral]        [openness]   [indoors]
# 4     [25-34]  [white]      [neutral]    [extraversion]  [outdoors]
# ..        ...      ...            ...               ...         ...
# 883   [65-79]  [white]      [neutral]   [agreeableness]   [indoors]
# 884   [65-79]  [white]      [neutral]   [agreeableness]   [indoors]
# 885   [65-79]  [white]      [neutral]        [openness]   [indoors]
# 886   [65-79]  [white]      [neutral]     [neuroticism]   [indoors]
# 887   [65-79]  [white]      [neutral]        [openness]   [indoors]
#
#                                                objects  \
# 0    [toilet paper dispenser, shower head on wall, ...
# 1    [floor, wall tiles, person walking away, open ...
# 2    [person, plant, door, sink, bathtub, toilet, p...
# 3    [person, tiled floor, shower curtain, sink wit...
# 4    [person, store front with signage, concrete si...
# ..                                                 ...
# 883  [man, book, pen, spice jar, tomatoes, garlic c...
# 884  [person, bed, pillow, blanket, hospital gown, ...
# 885  [bed, pillow, headband, hospital gown, intrave...
# 886  [man, glasses, bench, waiting area, office bui...
# 887  [man, hospital bed, sheets, gown, iv stand, mo...
#
#                    objects_assist_devices objects_digi_devices person_count  \
# 0    ['handicapped accessible grab bars']                   []          [1]
# 1                                      []                   []          [1]
# 2              ['sink', 'door', 'window']               [none]          [1]
# 3                              ['faucet']   ['sink', 'toilet']          [1]
# 4                            ['backpack']                   []          [1]
# ..                                    ...                  ...          ...
# 883                               ['pen']              ['pen']          [1]
# 884                      ['hospital bed']          ['monitor']          [1]
# 885                               ['bed']          ['monitor']          [1]
# 886                                    []                   []          [1]
# 887                      ['hospital bed']                   []          [1]
#
#                 shot position_short
# 0    [close-up shot]     [standing]
# 1      [medium shot]     [standing]
# 2    [close-up shot]     [standing]
# 3    [close-up shot]     [standing]
# 4      [medium shot]     [standing]
# ..               ...            ...
# 883  [close-up shot]      [sitting]
# 884  [close-up shot]        [lying]
# 885  [close-up shot]        [lying]
# 886  [close-up shot]      [sitting]
# 887  [close-up shot]      [sitting]
#
# [888 rows x 18 columns]

# %% [markdown]
# # PIL BRIGHTNESS

# %%
def rgb_to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(int(rgb[0]), int(rgb[1]), int(rgb[2]))

def rgb_to_css(rgb):
    return f'rgb({int(rgb[0])}, {int(rgb[1])}, {int(rgb[2])})'

def simplify_color(rgb):
    color_names = {
        (0, 0, 0): "Negro", (255, 255, 255): "Blanco",
        (255, 0, 0): "Rojo", (0, 255, 0): "Verde", (0, 0, 255): "Azul",
        (255, 255, 0): "Amarillo", (255, 0, 255): "Magenta", (0, 255, 255): "Cian",
        (128, 128, 128): "Gris"
    }
    
    distances = {name: sum((a - b) ** 2 for a, b in zip(rgb, color_rgb))
                 for color_rgb, name in color_names.items()}
    return min(distances, key=distances.get)

def analizar_imagen(ruta_imagen, max_size=1000):
    try:
        with Image.open(ruta_imagen) as imagen:
            if max(imagen.size) > max_size:
                imagen.thumbnail((max_size, max_size))
            
            imagen_array = np.array(imagen)
        
        brillo_promedio = np.mean(imagen_array)
        
        contraste = np.std(imagen_array)
        
        if len(imagen_array.shape) == 3:  
            pixels = imagen_array.reshape(-1, 3)
            color_dominante, conteo = stats.mode(pixels, axis=0)
            color_dominante = color_dominante.ravel()
            conteo = conteo.ravel()[0]  
        else:  
            color_dominante = np.array([brillo_promedio] * 3)
            conteo = imagen_array.size
        
        total_pixels = imagen_array.size // 3 if len(imagen_array.shape) == 3 else imagen_array.size
        porcentaje_dominante = (conteo / total_pixels) * 100
        
        return {
            'filename_jpg': os.path.basename(ruta_imagen),
            'brillo_promedio': float(brillo_promedio),
            'contraste': float(contraste),
            'color_dominante': {
                'rgb': tuple(map(int, color_dominante)),
                'hex': rgb_to_hex(color_dominante),
                'css': rgb_to_css(color_dominante),
                'simplificado': simplify_color(tuple(map(int, color_dominante)))
            },
            'porcentaje_dominante': float(porcentaje_dominante)
        }
    except Exception as e:
        print(f"Error al procesar {os.path.basename(ruta_imagen)}: {str(e)}")
        return None

def analizar_carpeta(ruta_carpeta, limit=None):
    resultados = []
    archivos = [f for f in os.listdir(ruta_carpeta) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
    
    if limit:
        archivos = archivos[:limit]
    
    total = len(archivos)
    for i, archivo in enumerate(archivos, 1):
        ruta_completa = os.path.join(ruta_carpeta, archivo)
        resultado = analizar_imagen(ruta_completa)
        if resultado:
            resultados.append(resultado)
        print(f"Procesado {i}/{total}: {archivo}")
    
    return resultados

if __name__ == '__main__':
    resultados_n = analizar_carpeta("06_08_midjourney_activities/neutral_comp")
    resultados_o = analizar_carpeta("06_08_midjourney_activities/older_comp")
    
    for resultado_n in resultados_n:
        print(f"\nImagen: {resultado_n['filename_jpg']}")
        print(f"  Brillo promedio: {resultado_n['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_n['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_n['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_n['color_dominante']['hex']}")
        print(f"    CSS: {resultado_n['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_n['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_n['porcentaje_dominante']:.2f}%")

    for resultado_o in resultados_o:
        print(f"\nImagen: {resultado_o['filename_jpg']}")
        print(f"  Brillo promedio: {resultado_o['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_o['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_o['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_o['color_dominante']['hex']}")
        print(f"    CSS: {resultado_o['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_o['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_o['porcentaje_dominante']:.2f}%")
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_14940\2127906730.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   color_dominante, conteo = stats.mode(pixels, axis=0)
# Procesado 1/457: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_0.jpg
# Procesado 2/457: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_1.jpg
# Procesado 3/457: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_2.jpg
# Procesado 4/457: 01P_a_person_walking_to_the_bathroom_in_photorealistic_styl_3c1413d3-141a-4f73-821a-dc0ec97832df_3.jpg
# Procesado 5/457: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_0.jpg
# Procesado 6/457: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_1.jpg
# Procesado 7/457: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_2.jpg
# Procesado 8/457: 03P_a_full_body_portrait_of_a_person_in_his_or_her_room_in__a07105f7-5e59-489d-b0f7-c2e3dae66d69_3.jpg
# Procesado 9/457: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_0.jpg
# Procesado 10/457: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_1.jpg
# Procesado 11/457: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_2.jpg
# Procesado 12/457: 04P_a_front_view_of_a_person_strolling_in_the_neighborhood__2fb4c711-3e83-42b3-a7e7-8e4776a3542f_3.jpg
# Procesado 13/457: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_0.jpg
# Procesado 14/457: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_1.jpg
# Procesado 15/457: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_2.jpg
# Procesado 16/457: 05P_a_full_body_portrait_of_a_person_climbing_stairs_--pers_627fb7a7-0cef-46e9-9378-b93e66bdd60d_3.jpg
# Procesado 17/457: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_0.jpg
# Procesado 18/457: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_1.jpg
# Procesado 19/457: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_2.jpg
# Procesado 20/457: 05P_a_person_using_stairs_--personalize_deewgch_--v_6.1_578773a5-2ea2-4217-b014-ee17507de28b_3.jpg
# Procesado 21/457: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_0.jpg
# Procesado 22/457: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_1.jpg
# Procesado 23/457: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_2.jpg
# Procesado 24/457: 06P_a_a_front_view_of_a_person_walking_in_the_metro_in_phot_922d0740-1d98-4060-8e14-0a7c52d985b6_3.jpg
# Procesado 25/457: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_0.jpg
# Procesado 26/457: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_1.jpg
# Procesado 27/457: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_2.jpg
# Procesado 28/457: 08P_front_view___a_person_dining_at_a_restaurant_in_photore_687db7d5-6b74-4466-a4a4-5a3aafc9cc8a_3.jpg
# Procesado 29/457: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_0.jpg
# Procesado 30/457: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_1.jpg
# Procesado 31/457: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_2.jpg
# Procesado 32/457: 09P_a_full_body_portrait_of_a_person_at_the_dining_table_in_7f6d6839-2a7b-4437-aeb4-bea7b5bfca21_3.jpg
# Procesado 33/457: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_0.jpg
# Procesado 34/457: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_1.jpg
# Procesado 35/457: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_2.jpg
# Procesado 36/457: 102P_a_person_landscaping_in_photorealistic_style_--personal_be4628f8-62d2-4066-8a85-9f8301b50099_3.jpg
# Procesado 37/457: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_0.jpg
# Procesado 38/457: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_1.jpg
# Procesado 39/457: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_2.jpg
# Procesado 40/457: 103P_Create_an_image_in_front_view_of_a_person_taking_care_o_b53494f5-4010-4070-8751-3f1299e21435_3.jpg
# Procesado 41/457: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_0.jpg
# Procesado 42/457: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_1.jpg
# Procesado 43/457: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_2.jpg
# Procesado 44/457: 104P_a_person_participating_in_community_gardens_in_photorea_45a026fd-52a3-4077-8d36-4e8e55075aec_3.jpg
# Procesado 45/457: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_0.jpg
# Procesado 46/457: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_1.jpg
# Procesado 47/457: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_2.jpg
# Procesado 48/457: 105P_Create_an_image_in_front_view_of_a_person_doing_an_exer_5744ad02-05fd-4d71-81ad-29ee7928a225_3.jpg
# Procesado 49/457: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_0.jpg
# Procesado 50/457: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_1.jpg
# Procesado 51/457: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_2.jpg
# Procesado 52/457: 106P_a_person_doing_physical_activity_in_photorealistic_styl_0cbc1490-8d41-4d42-9c12-e35b69948bb9_3.jpg
# Procesado 53/457: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_0.jpg
# Procesado 54/457: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_1.jpg
# Procesado 55/457: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_2.jpg
# Procesado 56/457: 108P_a_person_playing_a_sport_in_photorealistic_style_--pers_21838e40-f687-4821-9184-9e42b1416e22_3.jpg
# Procesado 57/457: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_0.jpg
# Procesado 58/457: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_1.jpg
# Procesado 59/457: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_2.jpg
# Procesado 60/457: 10P_a_person_in_front_view_shopping_groceries_in_photoreali_9e8a0ed7-6a66-45ea-b662-d2b9901e0070_3.jpg
# Procesado 61/457: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_0.jpg
# Procesado 62/457: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_1.jpg
# Procesado 63/457: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_2.jpg
# Procesado 64/457: 117P_Create_an_image_in_front_view_of_a_person_meditating_in_ab1c8023-aaf9-402d-a806-55bd071eae90_3.jpg
# Procesado 65/457: 11oP_a_portrait_of_an_older_person_setting_the_table_--perso_efb34cee-8e1e-412d-90b4-72df2d9d35ae_1.jpg
# Procesado 66/457: 11P_a_person_setting_the_table_--personalize_deewgch_--v_6._071c54eb-c22a-48b6-b37f-5e3868acd9e7_0.jpg
# Procesado 67/457: 11P_a_person_setting_the_table_--personalize_deewgch_--v_6._071c54eb-c22a-48b6-b37f-5e3868acd9e7_1.jpg
# Procesado 68/457: 11P_a_person_setting_the_table_--personalize_deewgch_--v_6._071c54eb-c22a-48b6-b37f-5e3868acd9e7_2.jpg
# Procesado 69/457: 11P_a_person_setting_the_table_--personalize_deewgch_--v_6._071c54eb-c22a-48b6-b37f-5e3868acd9e7_3.jpg
# Procesado 70/457: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_0.jpg
# Procesado 71/457: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_1.jpg
# Procesado 72/457: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_2.jpg
# Procesado 73/457: 11P_a_portrait_of_a_person_setting_the_table_--personalize__ed8b54d0-4af3-4160-8f37-3f1955817d6b_3.jpg
# Procesado 74/457: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_0.jpg
# Procesado 75/457: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_1.jpg
# Procesado 76/457: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_2.jpg
# Procesado 77/457: 121P_Create_an_image_in_front_view_of_a_person_writing_in_a__b0173772-333a-4b02-beb2-3e561940cca0_3.jpg
# Procesado 78/457: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_0.jpg
# Procesado 79/457: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_1.jpg
# Procesado 80/457: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_2.jpg
# Procesado 81/457: 122P_a_full_body_portrait_of_a_person_attending_a_support_gr_0a14dc9e-145c-4ccd-9702-f157bbea622d_3.jpg
# Procesado 82/457: 122P_a_person_attending_a_support_group_in_photorealistic_st_cde880d5-c902-4a15-b9a1-99e46728ce8a_0.jpg
# Procesado 83/457: 122P_a_person_attending_a_support_group_in_photorealistic_st_cde880d5-c902-4a15-b9a1-99e46728ce8a_1.jpg
# Procesado 84/457: 122P_a_person_attending_a_support_group_in_photorealistic_st_cde880d5-c902-4a15-b9a1-99e46728ce8a_2.jpg
# Procesado 85/457: 122P_a_person_attending_a_support_group_in_photorealistic_st_cde880d5-c902-4a15-b9a1-99e46728ce8a_3.jpg
# Procesado 86/457: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_0.jpg
# Procesado 87/457: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_1.jpg
# Procesado 88/457: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_2.jpg
# Procesado 89/457: 123P_Create_an_image_in_front_view_of_a_person_doing_physica_91709756-00af-460a-ae9e-fe789c6be3db_3.jpg
# Procesado 90/457: 124P_an_older_person_playing_mental_games_in_photorealistic__ede32a74-fec0-43dc-9740-e078f3b94490_0.jpg
# Procesado 91/457: 124P_an_older_person_playing_mental_games_in_photorealistic__ede32a74-fec0-43dc-9740-e078f3b94490_1.jpg
# Procesado 92/457: 124P_an_older_person_playing_mental_games_in_photorealistic__ede32a74-fec0-43dc-9740-e078f3b94490_2.jpg
# Procesado 93/457: 124P_an_older_person_playing_mental_games_in_photorealistic__ede32a74-fec0-43dc-9740-e078f3b94490_3.jpg
# Procesado 94/457: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_0.jpg
# Procesado 95/457: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_1.jpg
# Procesado 96/457: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_2.jpg
# Procesado 97/457: 124P_a_portrait_of_a_person_playing_mental_games_in_photorea_86a446a8-cada-40bb-9d41-f403cbea7c78_3.jpg
# Procesado 98/457: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_0.jpg
# Procesado 99/457: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_1.jpg
# Procesado 100/457: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_2.jpg
# Procesado 101/457: 125P_Create_an_image_in_front_view_of_a_person_doing_puzzles_8c0a189c-5e32-448b-a4c2-c7ca5cf89a95_3.jpg
# Procesado 102/457: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_0.jpg
# Procesado 103/457: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_1.jpg
# Procesado 104/457: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_2.jpg
# Procesado 105/457: 126P_a_portrait_of_a_person_doing_cognitive_games_in_photore_94640a67-2e3d-42cc-a62c-8d43bd683982_3.jpg
# Procesado 106/457: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_0.jpg
# Procesado 107/457: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_1.jpg
# Procesado 108/457: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_2.jpg
# Procesado 109/457: 128P_a_person_functional_outdoor_activities_in_photorealisti_21280ce7-870b-4a52-b393-1c9e5dbee166_3.jpg
# Procesado 110/457: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_0.jpg
# Procesado 111/457: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_1.jpg
# Procesado 112/457: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_2.jpg
# Procesado 113/457: 129P_Create_an_image_in_front_view_of_a_person_taking_course_8f743830-0713-4c8d-8ddb-38c0feabfc9d_3.jpg
# Procesado 114/457: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_0.jpg
# Procesado 115/457: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_1.jpg
# Procesado 116/457: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_2.jpg
# Procesado 117/457: 12P_a_person_picnicking_in_photorealistic_style_--personali_007e6973-54cf-4f3d-95ed-c51578381a61_3.jpg
# Procesado 118/457: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_0.jpg
# Procesado 119/457: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_1.jpg
# Procesado 120/457: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_2.jpg
# Procesado 121/457: 130P_a_person_at_the_office_in_photorealistic_style_--person_d22b2d98-7f4f-4930-a039-a7f7db7edb8a_3.jpg
# Procesado 122/457: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_0.jpg
# Procesado 123/457: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_1.jpg
# Procesado 124/457: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_2.jpg
# Procesado 125/457: 130P_a_portrait_of_a_person_at_the_office_in_photorealistic__7f3c7173-8d4c-423c-8371-cef6558e8fcd_3.jpg
# Procesado 126/457: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_0.jpg
# Procesado 127/457: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_1.jpg
# Procesado 128/457: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_2.jpg
# Procesado 129/457: 131P_Create_an_image_in_front_view_of_a_person_running_a_hom_fb7de688-5aa3-4d8b-8b8f-0ca9b0264308_3.jpg
# Procesado 130/457: 132P_a_full_body_portrait_of_a_person_in_a_job_fair_in_photo_2faefc22-972a-4551-b744-0574a767ba98_0.jpg
# Procesado 131/457: 132P_a_full_body_portrait_of_a_person_in_a_job_fair_in_photo_2faefc22-972a-4551-b744-0574a767ba98_1.jpg
# Procesado 132/457: 132P_a_full_body_portrait_of_a_person_in_a_job_fair_in_photo_2faefc22-972a-4551-b744-0574a767ba98_2.jpg
# Procesado 133/457: 132P_a_full_body_portrait_of_a_person_in_a_job_fair_in_photo_2faefc22-972a-4551-b744-0574a767ba98_3.jpg
# Procesado 134/457: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_0.jpg
# Procesado 135/457: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_1.jpg
# Procesado 136/457: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_2.jpg
# Procesado 137/457: 132P_a_person_in_a_job_fair_in_photorealistic_style_--person_2560c821-4f15-4dfb-9f96-ada7df19c855_3.jpg
# Procesado 138/457: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_0.jpg
# Procesado 139/457: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_1.jpg
# Procesado 140/457: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_2.jpg
# Procesado 141/457: 134P_a_person_volunteering_in_photorealistic_style_--persona_b589f545-c448-4be0-bd66-0d2cf3f47fcc_3.jpg
# Procesado 142/457: 137P_a_front_view_photo_of_a_person_home_monitoring_--person_5564c2d0-af8f-4dc4-b31a-bb85ceb5c43e_0.jpg
# Procesado 143/457: 137P_a_front_view_photo_of_a_person_home_monitoring_--person_5564c2d0-af8f-4dc4-b31a-bb85ceb5c43e_1.jpg
# Procesado 144/457: 137P_a_front_view_photo_of_a_person_home_monitoring_--person_5564c2d0-af8f-4dc4-b31a-bb85ceb5c43e_2.jpg
# Procesado 145/457: 137P_a_front_view_photo_of_a_person_home_monitoring_--person_5564c2d0-af8f-4dc4-b31a-bb85ceb5c43e_3.jpg
# Procesado 146/457: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_0.jpg
# Procesado 147/457: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_1.jpg
# Procesado 148/457: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_2.jpg
# Procesado 149/457: 138P_a_portrait_of_a_person_at_work_in_photorealistic_style__03322683-38bd-4524-a59e-77e222fc6630_3.jpg
# Procesado 150/457: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_0.jpg
# Procesado 151/457: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_1.jpg
# Procesado 152/457: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_2.jpg
# Procesado 153/457: 139P_a_front_photo_of_a_person_doing_diet_and_nutrition_plan_3754c983-5b96-44af-92ee-e7a658180071_3.jpg
# Procesado 154/457: 13P_a_person_selecting_clothes_--personalize_deewgch_--v_6._f1ed72d0-f101-445b-a3d7-462b8b5ded6c_0.jpg
# Procesado 155/457: 13P_a_person_selecting_clothes_--personalize_deewgch_--v_6._f1ed72d0-f101-445b-a3d7-462b8b5ded6c_1.jpg
# Procesado 156/457: 13P_a_person_selecting_clothes_--personalize_deewgch_--v_6._f1ed72d0-f101-445b-a3d7-462b8b5ded6c_2.jpg
# Procesado 157/457: 13P_a_person_selecting_clothes_--personalize_deewgch_--v_6._f1ed72d0-f101-445b-a3d7-462b8b5ded6c_3.jpg
# Procesado 158/457: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_0.jpg
# Procesado 159/457: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_1.jpg
# Procesado 160/457: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_2.jpg
# Procesado 161/457: 13P_a_portrait_of_a_person_selecting_clothes_--personalize__f866f954-8db0-4b85-a233-ffd8e1485f79_3.jpg
# Procesado 162/457: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_0.jpg
# Procesado 163/457: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_1.jpg
# Procesado 164/457: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_2.jpg
# Procesado 165/457: 140P_a_full_body_portrait_of_an_person_at_the_hospital_in_ph_c0a32f8c-910c-4190-9c89-e8f1ccb5a779_3.jpg
# Procesado 166/457: 140P_a_full_body_portrait_of_a_person_at_the_hospital_in_pho_7147303b-28ca-492f-bf6a-49efa27b781c_0.jpg
# Procesado 167/457: 140P_a_full_body_portrait_of_a_person_at_the_hospital_in_pho_7147303b-28ca-492f-bf6a-49efa27b781c_1.jpg
# Procesado 168/457: 140P_a_full_body_portrait_of_a_person_at_the_hospital_in_pho_7147303b-28ca-492f-bf6a-49efa27b781c_2.jpg
# Procesado 169/457: 140P_a_full_body_portrait_of_a_person_at_the_hospital_in_pho_7147303b-28ca-492f-bf6a-49efa27b781c_3.jpg
# Procesado 170/457: 140P_a_person_at_the_hospital_in_photorealistic_style_--pers_d5107547-1e92-4baf-87b5-7c153c197f52_0.jpg
# Procesado 171/457: 140P_a_person_at_the_hospital_in_photorealistic_style_--pers_d5107547-1e92-4baf-87b5-7c153c197f52_1.jpg
# Procesado 172/457: 140P_a_person_at_the_hospital_in_photorealistic_style_--pers_d5107547-1e92-4baf-87b5-7c153c197f52_2.jpg
# Procesado 173/457: 140P_a_person_at_the_hospital_in_photorealistic_style_--pers_d5107547-1e92-4baf-87b5-7c153c197f52_3.jpg
# Procesado 174/457: 14P_a_person_shopping_clothes_in_photorealistic_style_--per_b4ade404-da4a-4eae-97b4-879c9dbc8d73_0.jpg
# Procesado 175/457: 14P_a_person_shopping_clothes_in_photorealistic_style_--per_b4ade404-da4a-4eae-97b4-879c9dbc8d73_1.jpg
# Procesado 176/457: 14P_a_person_shopping_clothes_in_photorealistic_style_--per_b4ade404-da4a-4eae-97b4-879c9dbc8d73_2.jpg
# Procesado 177/457: 14P_a_person_shopping_clothes_in_photorealistic_style_--per_b4ade404-da4a-4eae-97b4-879c9dbc8d73_3.jpg
# Procesado 178/457: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_0.jpg
# Procesado 179/457: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_1.jpg
# Procesado 180/457: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_2.jpg
# Procesado 181/457: 15P_a_portrait_of_a_person_putting_on_clothes_--personalize_c82ee71f-7eb8-4cb9-9ffb-fc7b84323ff0_3.jpg
# Procesado 182/457: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_0.jpg
# Procesado 183/457: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_1.jpg
# Procesado 184/457: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_2.jpg
# Procesado 185/457: 16P_front_view_of_a_person_attending_fittings_in_photoreali_622b84c5-e951-4358-8a38-f259cf61a8bd_3.jpg
# Procesado 186/457: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_0.jpg
# Procesado 187/457: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_1.jpg
# Procesado 188/457: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_2.jpg
# Procesado 189/457: 17P_a_person_doing_laundry_--personalize_deewgch_--v_6.1_44aa2eb0-d1e6-40a1-8555-c50bd4f589dd_3.jpg
# Procesado 190/457: 18P_front_view_of_a_person_hanging_laundry_in_photorealisti_d0ed73d7-ff7b-4dc8-89d4-a6f3b961ef99_0.jpg
# Procesado 191/457: 18P_front_view_of_a_person_hanging_laundry_in_photorealisti_d0ed73d7-ff7b-4dc8-89d4-a6f3b961ef99_1.jpg
# Procesado 192/457: 18P_front_view_of_a_person_hanging_laundry_in_photorealisti_d0ed73d7-ff7b-4dc8-89d4-a6f3b961ef99_2.jpg
# Procesado 193/457: 18P_front_view_of_a_person_hanging_laundry_in_photorealisti_d0ed73d7-ff7b-4dc8-89d4-a6f3b961ef99_3.jpg
# Procesado 194/457: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_0.jpg
# Procesado 195/457: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_1.jpg
# Procesado 196/457: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_2.jpg
# Procesado 197/457: 18P_portrait_of_a_person_hanging_laundry_in_photorealistic__ce646f81-2364-4a4e-b1ab-12d200b831fe_3.jpg
# Procesado 198/457: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_0.jpg
# Procesado 199/457: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_1.jpg
# Procesado 200/457: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_2.jpg
# Procesado 201/457: 19P_a_portrait_of_a_person_taking_a_bath_--personalize_deew_38342968-a0af-4ae0-a7e1-b74a051b2ae6_3.jpg
# Procesado 202/457: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_0.jpg
# Procesado 203/457: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_1.jpg
# Procesado 204/457: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_2.jpg
# Procesado 205/457: 20P_front_view_of_a_person_in_a_hair_salon_in_photorealisti_314cd343-37fd-49ab-830c-47fe2a73cc55_3.jpg
# Procesado 206/457: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_0.jpg
# Procesado 207/457: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_1.jpg
# Procesado 208/457: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_2.jpg
# Procesado 209/457: 21P_a_portrait_of_a_person_brushing_teeth_--personalize_dee_55874132-845f-4a3f-97e7-696186f0b105_3.jpg
# Procesado 210/457: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_0.jpg
# Procesado 211/457: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_1.jpg
# Procesado 212/457: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_2.jpg
# Procesado 213/457: 23P_a_portrait_of_a_person_grooming_--personalize_deewgch_-_7788c844-d978-44e5-a9f2-e35dd134bc4d_3.jpg
# Procesado 214/457: 24P_front_view_of_a_person_buying_personal_care_products_in_0ae4f8c8-16a2-4326-9d8c-1eb3ee642932_0.jpg
# Procesado 215/457: 24P_front_view_of_a_person_buying_personal_care_products_in_0ae4f8c8-16a2-4326-9d8c-1eb3ee642932_1.jpg
# Procesado 216/457: 24P_front_view_of_a_person_buying_personal_care_products_in_0ae4f8c8-16a2-4326-9d8c-1eb3ee642932_2.jpg
# Procesado 217/457: 24P_front_view_of_a_person_buying_personal_care_products_in_0ae4f8c8-16a2-4326-9d8c-1eb3ee642932_3.jpg
# Procesado 218/457: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_0.jpg
# Procesado 219/457: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_1.jpg
# Procesado 220/457: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_2.jpg
# Procesado 221/457: 24P_portrait_of_a_person_buying_personal_care_products_in_p_2d3abce5-15b8-4ae4-8fe4-0197ae2a58c7_3.jpg
# Procesado 222/457: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_0.jpg
# Procesado 223/457: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_1.jpg
# Procesado 224/457: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_2.jpg
# Procesado 225/457: 25P_a_portrait_of_a_person_in_the_toilet_--personalize_deew_9199bccd-c9a4-419d-93aa-427a2e154b3e_3.jpg
# Procesado 226/457: 25P_a_portrait_of_a_person_using_a_toilet_--personalize_dee_ec439556-c770-4e91-8657-445def866f80_0.jpg
# Procesado 227/457: 25P_a_portrait_of_a_person_using_a_toilet_--personalize_dee_ec439556-c770-4e91-8657-445def866f80_1.jpg
# Procesado 228/457: 25P_a_portrait_of_a_person_using_a_toilet_--personalize_dee_ec439556-c770-4e91-8657-445def866f80_2.jpg
# Procesado 229/457: 25P_a_portrait_of_a_person_using_a_toilet_--personalize_dee_ec439556-c770-4e91-8657-445def866f80_3.jpg
# Procesado 230/457: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_0.jpg
# Procesado 231/457: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_1.jpg
# Procesado 232/457: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_2.jpg
# Procesado 233/457: 2P_a_front_photo_of_a_person_walking_to_a_store_in_photore_2a2840b4-cf6e-481f-89dd-8a756a91bb52_3.jpg
# Procesado 234/457: 30P_front_view_of_a_person_attending_a_medical_appointments_4a87c741-a8b3-45a2-83db-62b6af73c884_0.jpg
# Procesado 235/457: 30P_front_view_of_a_person_attending_a_medical_appointments_4a87c741-a8b3-45a2-83db-62b6af73c884_1.jpg
# Procesado 236/457: 30P_front_view_of_a_person_attending_a_medical_appointments_4a87c741-a8b3-45a2-83db-62b6af73c884_2.jpg
# Procesado 237/457: 30P_front_view_of_a_person_attending_a_medical_appointments_4a87c741-a8b3-45a2-83db-62b6af73c884_3.jpg
# Procesado 238/457: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_0.jpg
# Procesado 239/457: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_1.jpg
# Procesado 240/457: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_2.jpg
# Procesado 241/457: 30P_portrait_of_a_person_attending_a_medical_appointments_i_5f450ef5-19c7-4c83-bf2a-441349e4836a_3.jpg
# Procesado 242/457: 31P_a_portrait_of_a_person_in_the_bathroom_--personalize_de_2085824b-898e-4463-8e58-795333db3a6a_0.jpg
# Procesado 243/457: 31P_a_portrait_of_a_person_in_the_bathroom_--personalize_de_2085824b-898e-4463-8e58-795333db3a6a_1.jpg
# Procesado 244/457: 31P_a_portrait_of_a_person_in_the_bathroom_--personalize_de_2085824b-898e-4463-8e58-795333db3a6a_2.jpg
# Procesado 245/457: 31P_a_portrait_of_a_person_in_the_bathroom_--personalize_de_2085824b-898e-4463-8e58-795333db3a6a_3.jpg
# Procesado 246/457: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_0.jpg
# Procesado 247/457: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_1.jpg
# Procesado 248/457: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_2.jpg
# Procesado 249/457: 33P_a_person_cleaning_the_bathroom_--personalize_deewgch_--_9ecd84fc-41a5-44f9-9e79-459204ff52ae_3.jpg
# Procesado 250/457: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_0.jpg
# Procesado 251/457: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_1.jpg
# Procesado 252/457: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_2.jpg
# Procesado 253/457: 37P_a_person_planning_commuting_--personalize_deewgch_--v_6_955fbfe6-32e7-4ecb-b1c9-5d16888b414d_3.jpg
# Procesado 254/457: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_0.jpg
# Procesado 255/457: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_1.jpg
# Procesado 256/457: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_2.jpg
# Procesado 257/457: 38P_3434a_portrait_of_a_person_using_public_transport_in_photorea_bb0aec7a-4673-4234-b6d0-963b54f93f39_3.jpg
# Procesado 258/457: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_0.jpg
# Procesado 259/457: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_1.jpg
# Procesado 260/457: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_2.jpg
# Procesado 261/457: 39P_a_person_booking_a_travel_--personalize_deewgch_--v_6.1_d14b1edd-41a1-4bcd-835a-727eda92d32e_3.jpg
# Procesado 262/457: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_0.jpg
# Procesado 263/457: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_1.jpg
# Procesado 264/457: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_2.jpg
# Procesado 265/457: 40P_portrait_of_a_person_driving_in_photorealistic_style_--_87ab1700-7ed8-408b-9664-5026baa96e77_3.jpg
# Procesado 266/457: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_0.jpg
# Procesado 267/457: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_1.jpg
# Procesado 268/457: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_2.jpg
# Procesado 269/457: 41P_a_person_commuting_in_a_photographic_style_--personaliz_26f037de-78cd-4119-b970-d2d0d3dfcb04_3.jpg
# Procesado 270/457: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_0.jpg
# Procesado 271/457: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_1.jpg
# Procesado 272/457: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_2.jpg
# Procesado 273/457: 43P_a_person_shopping_in_a_photographic_style_--personalize_9b07c699-8b89-401a-964a-c3b818afc3c2_3.jpg
# Procesado 274/457: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_0.jpg
# Procesado 275/457: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_1.jpg
# Procesado 276/457: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_2.jpg
# Procesado 277/457: 44P_3434a_portrait_of_a_person_visiting_stores_in_photorealistic__2ac71b72-4add-468e-81d7-ececcda06e2f_3.jpg
# Procesado 278/457: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_0.jpg
# Procesado 279/457: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_1.jpg
# Procesado 280/457: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_2.jpg
# Procesado 281/457: 45P_a_person_paying_bills_in_a_photographic_style_--persona_580d5c64-432d-40e1-ad65-c92da1ee093c_3.jpg
# Procesado 282/457: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_0.jpg
# Procesado 283/457: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_1.jpg
# Procesado 284/457: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_2.jpg
# Procesado 285/457: 46P_portrait_of_a_person_checking_bank_accounts_in_photoreal_c2222c54-004b-43c0-8916-60fd63f50969_3.jpg
# Procesado 286/457: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_0.jpg
# Procesado 287/457: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_1.jpg
# Procesado 288/457: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_2.jpg
# Procesado 289/457: 47P_a_person_budgeting_in_a_photographic_style_--personaliz_63cfd212-0509-4d2d-9a1b-93f44b6d17da_3.jpg
# Procesado 290/457: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_0.jpg
# Procesado 291/457: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_1.jpg
# Procesado 292/457: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_2.jpg
# Procesado 293/457: 48P_3434a_portrait_of_a_person_withdrawing_money_in_photorealisti_1fa5d49f-b133-42f9-9b2a-35f5f62affb5_3.jpg
# Procesado 294/457: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_0.jpg
# Procesado 295/457: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_1.jpg
# Procesado 296/457: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_2.jpg
# Procesado 297/457: 50P_portrait_of_a_person_meeting_financial_advisors_in_phot_7f317cab-ef5c-43b9-a8b2-c172cbf88d02_3.jpg
# Procesado 298/457: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_0.jpg
# Procesado 299/457: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_1.jpg
# Procesado 300/457: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_2.jpg
# Procesado 301/457: 51P_a_person_planning_shopping_in_a_photographic_style_--pe_1f18c38e-7dc6-450c-ab2e-611549060436_3.jpg
# Procesado 302/457: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_0.jpg
# Procesado 303/457: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_1.jpg
# Procesado 304/457: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_2.jpg
# Procesado 305/457: 53P_a_person_preparing_meals_in_a_photographic_style_--pers_10e96eff-ceef-465d-87eb-3656a1e130fa_3.jpg
# Procesado 306/457: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_0.jpg
# Procesado 307/457: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_1.jpg
# Procesado 308/457: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_2.jpg
# Procesado 309/457: 54P_3434a_portrait_of_a_person_visiting_farmers_markets_in_photor_542789ce-7e38-4bcd-a5e9-106168f61c0f_3.jpg
# Procesado 310/457: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_0.jpg
# Procesado 311/457: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_1.jpg
# Procesado 312/457: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_2.jpg
# Procesado 313/457: 55P_a_person_storing_groceries_in_a_photographic_style_--pe_7f228e60-eb94-4119-bc9e-ecb88ae899dc_3.jpg
# Procesado 314/457: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_0.jpg
# Procesado 315/457: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_1.jpg
# Procesado 316/457: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_2.jpg
# Procesado 317/457: 56P_portrait_of_a_person_eating_out_in_photorealistic_style_fd8e5070-1c34-4e28-96c3-7a09e776dba2_3.jpg
# Procesado 318/457: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_0.jpg
# Procesado 319/457: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_1.jpg
# Procesado 320/457: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_2.jpg
# Procesado 321/457: 57P_a_portrait_of_a_person_front_side_vacuuming_in_a_photog_ce07b9ad-d4aa-4ea6-8e2b-5a0529404a55_3.jpg
# Procesado 322/457: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_0.jpg
# Procesado 323/457: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_1.jpg
# Procesado 324/457: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_2.jpg
# Procesado 325/457: 58P_portrait_of_a_person_gardening_in_photorealistic_style__0385e417-ffbb-4969-bb80-929a8af3f2e5_3.jpg
# Procesado 326/457: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_0.jpg
# Procesado 327/457: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_1.jpg
# Procesado 328/457: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_2.jpg
# Procesado 329/457: 60P_portrait_of_a_person_doing_home_repairs_in_photorealist_4b162209-b701-4bca-a8a9-b036e9455a44_3.jpg
# Procesado 330/457: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_0.jpg
# Procesado 331/457: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_1.jpg
# Procesado 332/457: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_2.jpg
# Procesado 333/457: 61P_a_person_front_side_organizing_spaces_in_a_photographic_6d4a22a7-f433-41e0-8877-706866cbf018_3.jpg
# Procesado 334/457: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_0.jpg
# Procesado 335/457: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_1.jpg
# Procesado 336/457: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_2.jpg
# Procesado 337/457: 62P_62P_portrait_of_a_person_taking_out_the_trash_in_photoreali_33b510a6-4ae1-4b75-93d3-b893c0d993bb_3.jpg
# Procesado 338/457: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_0.jpg
# Procesado 339/457: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_1.jpg
# Procesado 340/457: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_2.jpg
# Procesado 341/457: 63P_a_front_side_person_making_phone_calls_in_a_photorealis_092c4f72-8569-432c-910c-52942d6aced6_3.jpg
# Procesado 342/457: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_0.jpg
# Procesado 343/457: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_1.jpg
# Procesado 344/457: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_2.jpg
# Procesado 345/457: 63P_person_on_a_call_--personalize_deewgch_--v_6.1_c7ad673e-9eee-44b0-9af0-9fdd5765cbf8_3.jpg
# Procesado 346/457: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_0.jpg
# Procesado 347/457: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_1.jpg
# Procesado 348/457: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_2.jpg
# Procesado 349/457: 64P_portrait_of_a_person_sending_mail_in_photorealistic_sty_c48b05a9-7860-43da-967c-56111989e663_3.jpg
# Procesado 350/457: 64P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_0.jpg
# Procesado 351/457: 64P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_1.jpg
# Procesado 352/457: 64P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_2.jpg
# Procesado 353/457: 64P_portrait_of_a_person_shopping_clothes_in_photorealistic_5c8a0830-1cfe-403a-8dac-a940670bfb68_3.jpg
# Procesado 354/457: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_0.jpg
# Procesado 355/457: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_1.jpg
# Procesado 356/457: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_2.jpg
# Procesado 357/457: 65P_a_portrait_of_person_sending_emails_--personalize_deewg_734c4e05-1d94-4ebd-807e-1965ac8a4aaa_3.jpg
# Procesado 358/457: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_0.jpg
# Procesado 359/457: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_1.jpg
# Procesado 360/457: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_2.jpg
# Procesado 361/457: 66P_portrait_of_a_person_meeting_face_to_face_in_photoreali_6bee4844-3db5-4e21-afea-9a48b7756eec_3.jpg
# Procesado 362/457: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_0.jpg
# Procesado 363/457: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_1.jpg
# Procesado 364/457: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_2.jpg
# Procesado 365/457: 67P_Create_an_image_of_a_front_view_of_a_person_writing_a_l_55d6e0de-84b1-483d-850b-a0aed05f242b_3.jpg
# Procesado 366/457: 67P_Create_an_image_of_a_person_writing_a_letter_in_a_photo_4e5b81fb-0c1a-4b47-8f97-6dd994202657_0.jpg
# Procesado 367/457: 67P_Create_an_image_of_a_person_writing_a_letter_in_a_photo_4e5b81fb-0c1a-4b47-8f97-6dd994202657_1.jpg
# Procesado 368/457: 67P_Create_an_image_of_a_person_writing_a_letter_in_a_photo_4e5b81fb-0c1a-4b47-8f97-6dd994202657_2.jpg
# Procesado 369/457: 67P_Create_an_image_of_a_person_writing_a_letter_in_a_photo_4e5b81fb-0c1a-4b47-8f97-6dd994202657_3.jpg
# Procesado 370/457: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_0.jpg
# Procesado 371/457: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_1.jpg
# Procesado 372/457: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_2.jpg
# Procesado 373/457: 68P_a_person_in_a_social_gathering_in_photorealistic_style__43357313-4990-4136-8eae-9e2091468830_3.jpg
# Procesado 374/457: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_0.jpg
# Procesado 375/457: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_1.jpg
# Procesado 376/457: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_2.jpg
# Procesado 377/457: 68P_portrait_of_a_person_in_a_social_gathering_in_photoreal_55c04fc8-0229-466c-809f-baa9ed66a183_3.jpg
# Procesado 378/457: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_0.jpg
# Procesado 379/457: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_1.jpg
# Procesado 380/457: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_2.jpg
# Procesado 381/457: 69P_Create_a_portrait_image_in_a_front_view_of_an_person_ma_68609842-740e-468d-b265-640135683e59_3.jpg
# Procesado 382/457: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_0.jpg
# Procesado 383/457: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_1.jpg
# Procesado 384/457: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_2.jpg
# Procesado 385/457: 70P_portrait_of_a_person_buying_medications_in_photorealist_2d246035-787c-41a6-be4a-bdcb0619d09c_3.jpg
# Procesado 386/457: 72P_portrait_of_a_person_consulting_the_doctors_in_photorea_8f1115a3-d82d-40fe-b30a-a9ab1d7d8657_0.jpg
# Procesado 387/457: 72P_portrait_of_a_person_consulting_the_doctors_in_photorea_8f1115a3-d82d-40fe-b30a-a9ab1d7d8657_1.jpg
# Procesado 388/457: 72P_portrait_of_a_person_consulting_the_doctors_in_photorea_8f1115a3-d82d-40fe-b30a-a9ab1d7d8657_2.jpg
# ...
#   Brillo promedio: 41.74
#   Contraste: 46.32
#   Color dominante:
#     RGB: (14, 18, 18)
#     Hex: #0e1212
#     CSS: rgb(14, 18, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.43%
#
# Imagen: 83OP_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_0.jpg
#   Brillo promedio: 56.49
#   Contraste: 41.79
#   Color dominante:
#     RGB: (14, 19, 14)
#     Hex: #0e130e
#     CSS: rgb(14, 19, 14)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.28%
#
# Imagen: 83OP_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_1.jpg
#   Brillo promedio: 64.63
#   Contraste: 56.53
#   Color dominante:
#     RGB: (20, 16, 13)
#     Hex: #14100d
#     CSS: rgb(20, 16, 13)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.75%
#
# Imagen: 83OP_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_2.jpg
#   Brillo promedio: 92.21
#   Contraste: 75.94
#   Color dominante:
#     RGB: (5, 9, 9)
#     Hex: #050909
#     CSS: rgb(5, 9, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.01%
#
# Imagen: 83OP_Create_an_image_of_a_person_playing_games_in_a_photorea_b5dcd432-b5dd-4007-8746-767dfd3df433_3.jpg
#   Brillo promedio: 88.01
#   Contraste: 70.39
#   Color dominante:
#     RGB: (41, 31, 25)
#     Hex: #291f19
#     CSS: rgb(41, 31, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.19%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_0.jpg
#   Brillo promedio: 30.78
#   Contraste: 42.78
#   Color dominante:
#     RGB: (3, 4, 6)
#     Hex: #030406
#     CSS: rgb(3, 4, 6)
#     Simplificado: Negro
#   Porcentaje del color dominante: 6.33%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_1.jpg
#   Brillo promedio: 48.66
#   Contraste: 57.12
#   Color dominante:
#     RGB: (6, 9, 8)
#     Hex: #060908
#     CSS: rgb(6, 9, 8)
#     Simplificado: Negro
#   Porcentaje del color dominante: 8.26%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_2.jpg
#   Brillo promedio: 54.99
#   Contraste: 54.49
#   Color dominante:
#     RGB: (11, 13, 14)
#     Hex: #0b0d0e
#     CSS: rgb(11, 13, 14)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.91%
#
# Imagen: 84OP_a_portrait_of_an_older_person_drinking_coffee_in_photor_51002c82-49a1-4069-a4ad-bb9bf3b0c25e_3.jpg
#   Brillo promedio: 39.21
#   Contraste: 54.05
#   Color dominante:
#     RGB: (6, 6, 4)
#     Hex: #060604
#     CSS: rgb(6, 6, 4)
#     Simplificado: Negro
#   Porcentaje del color dominante: 9.60%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_0.jpg
#   Brillo promedio: 50.72
#   Contraste: 38.26
#   Color dominante:
#     RGB: (34, 38, 39)
#     Hex: #222627
#     CSS: rgb(34, 38, 39)
#     Simplificado: Negro
#   Porcentaje del color dominante: 12.77%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_1.jpg
#   Brillo promedio: 51.82
#   Contraste: 62.84
#   Color dominante:
#     RGB: (0, 0, 0)
#     Hex: #000000
#     CSS: rgb(0, 0, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 38.18%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_2.jpg
#   Brillo promedio: 53.46
#   Contraste: 51.92
#   Color dominante:
#     RGB: (10, 21, 19)
#     Hex: #0a1513
#     CSS: rgb(10, 21, 19)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.56%
#
# Imagen: 85OP_Create_an_image_of_an_older_person_watching_movies_in_a_d898dcad-06e2-4422-bbcd-a503779f6b97_3.jpg
#   Brillo promedio: 49.48
#   Contraste: 58.11
#   Color dominante:
#     RGB: (4, 6, 6)
#     Hex: #040606
#     CSS: rgb(4, 6, 6)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.00%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_0.jpg
#   Brillo promedio: 52.28
#   Contraste: 58.82
#   Color dominante:
#     RGB: (5, 6, 7)
#     Hex: #050607
#     CSS: rgb(5, 6, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.37%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_1.jpg
#   Brillo promedio: 63.04
#   Contraste: 66.26
#   Color dominante:
#     RGB: (24, 20, 17)
#     Hex: #181411
#     CSS: rgb(24, 20, 17)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.42%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_2.jpg
#   Brillo promedio: 66.13
#   Contraste: 79.15
#   Color dominante:
#     RGB: (4, 4, 6)
#     Hex: #040406
#     CSS: rgb(4, 4, 6)
#     Simplificado: Negro
#   Porcentaje del color dominante: 12.46%
#
# Imagen: 87OP_Create_an_image_of_an_older_person_in_a_club_meeting_in_ee4334c7-53cd-4aad-9724-6000a98de569_3.jpg
#   Brillo promedio: 58.13
#   Contraste: 54.19
#   Color dominante:
#     RGB: (14, 16, 18)
#     Hex: #0e1012
#     CSS: rgb(14, 16, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.31%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_0.jpg
#   Brillo promedio: 145.63
#   Contraste: 65.52
#   Color dominante:
#     RGB: (131, 224, 227)
#     Hex: #83e0e3
#     CSS: rgb(131, 224, 227)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 1.03%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_1.jpg
#   Brillo promedio: 135.24
#   Contraste: 68.87
#   Color dominante:
#     RGB: (255, 255, 255)
#     Hex: #ffffff
#     CSS: rgb(255, 255, 255)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 3.23%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_2.jpg
#   Brillo promedio: 65.92
#   Contraste: 56.00
#   Color dominante:
#     RGB: (12, 16, 25)
#     Hex: #0c1019
#     CSS: rgb(12, 16, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.90%
#
# Imagen: 88OP_an_older_person_participating_in_community_events_in_ph_ed73dccd-3a90-4e82-b10e-43904898d93e_3.jpg
#   Brillo promedio: 118.88
#   Contraste: 76.62
#   Color dominante:
#     RGB: (246, 246, 246)
#     Hex: #f6f6f6
#     CSS: rgb(246, 246, 246)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 2.90%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_0.jpg
#   Brillo promedio: 43.53
#   Contraste: 42.99
#   Color dominante:
#     RGB: (27, 30, 15)
#     Hex: #1b1e0f
#     CSS: rgb(27, 30, 15)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.99%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_1.jpg
#   Brillo promedio: 30.51
#   Contraste: 34.04
#   Color dominante:
#     RGB: (14, 15, 10)
#     Hex: #0e0f0a
#     CSS: rgb(14, 15, 10)
#     Simplificado: Negro
#   Porcentaje del color dominante: 7.04%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_2.jpg
#   Brillo promedio: 68.93
#   Contraste: 59.25
#   Color dominante:
#     RGB: (8, 20, 12)
#     Hex: #08140c
#     CSS: rgb(8, 20, 12)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.41%
#
# Imagen: 89OP_Create_an_image_of_an_older_person_attending_a_webinar__bc1124eb-b27b-4f14-83fe-34d4f50b8565_3.jpg
#   Brillo promedio: 93.84
#   Contraste: 53.82
#   Color dominante:
#     RGB: (41, 42, 39)
#     Hex: #292a27
#     CSS: rgb(41, 42, 39)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.08%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_0.jpg
#   Brillo promedio: 50.90
#   Contraste: 63.35
#   Color dominante:
#     RGB: (3, 6, 7)
#     Hex: #030607
#     CSS: rgb(3, 6, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 8.36%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_1.jpg
#   Brillo promedio: 27.33
#   Contraste: 41.62
#   Color dominante:
#     RGB: (8, 9, 7)
#     Hex: #080907
#     CSS: rgb(8, 9, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 8.96%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_2.jpg
#   Brillo promedio: 38.67
#   Contraste: 43.60
#   Color dominante:
#     RGB: (6, 7, 10)
#     Hex: #06070a
#     CSS: rgb(6, 7, 10)
#     Simplificado: Negro
#   Porcentaje del color dominante: 7.86%
#
# Imagen: 90OP_a_portrait_of_an_older_person_in_a_conference_in_photor_c482e8da-7973-4a4b-a9e6-927be543db81_3.jpg
#   Brillo promedio: 36.00
#   Contraste: 48.25
#   Color dominante:
#     RGB: (4, 10, 9)
#     Hex: #040a09
#     CSS: rgb(4, 10, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 14.09%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_0.jpg
#   Brillo promedio: 50.38
#   Contraste: 57.74
#   Color dominante:
#     RGB: (8, 9, 11)
#     Hex: #08090b
#     CSS: rgb(8, 9, 11)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.69%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_1.jpg
#   Brillo promedio: 63.76
#   Contraste: 55.27
#   Color dominante:
#     RGB: (4, 25, 19)
#     Hex: #041913
#     CSS: rgb(4, 25, 19)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.46%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_2.jpg
#   Brillo promedio: 39.97
#   Contraste: 53.89
#   Color dominante:
#     RGB: (3, 3, 5)
#     Hex: #030305
#     CSS: rgb(3, 3, 5)
#     Simplificado: Negro
#   Porcentaje del color dominante: 7.64%
#
# Imagen: 91OP_Create_an_image_of_an_older_person_in_a_study_group_in__a0a3ca99-b78d-49b7-9237-c2d4f24ce768_3.jpg
#   Brillo promedio: 46.06
#   Contraste: 57.01
#   Color dominante:
#     RGB: (7, 9, 11)
#     Hex: #07090b
#     CSS: rgb(7, 9, 11)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.07%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_0.jpg
#   Brillo promedio: 70.88
#   Contraste: 50.95
#   Color dominante:
#     RGB: (25, 26, 30)
#     Hex: #191a1e
#     CSS: rgb(25, 26, 30)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.17%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_1.jpg
#   Brillo promedio: 74.26
#   Contraste: 60.40
#   Color dominante:
#     RGB: (18, 16, 18)
#     Hex: #121012
#     CSS: rgb(18, 16, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.54%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_2.jpg
#   Brillo promedio: 54.64
#   Contraste: 53.45
#   Color dominante:
#     RGB: (15, 16, 22)
#     Hex: #0f1016
#     CSS: rgb(15, 16, 22)
#     Simplificado: Negro
#   Porcentaje del color dominante: 5.84%
#
# Imagen: 92OP_an_older_person_in_a_football_match_in_photorealistic_s_f8b316e9-31df-4d35-a88f-15c3b3ff5452_3.jpg
#   Brillo promedio: 76.23
#   Contraste: 56.71
#   Color dominante:
#     RGB: (51, 46, 25)
#     Hex: #332e19
#     CSS: rgb(51, 46, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.38%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_0.jpg
#   Brillo promedio: 48.76
#   Contraste: 49.49
#   Color dominante:
#     RGB: (15, 15, 12)
#     Hex: #0f0f0c
#     CSS: rgb(15, 15, 12)
#     Simplificado: Negro
#   Porcentaje del color dominante: 5.01%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_1.jpg
#   Brillo promedio: 57.15
#   Contraste: 73.06
#   Color dominante:
#     RGB: (3, 3, 3)
#     Hex: #030303
#     CSS: rgb(3, 3, 3)
#     Simplificado: Negro
#   Porcentaje del color dominante: 13.09%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_2.jpg
#   Brillo promedio: 29.82
#   Contraste: 44.63
#   Color dominante:
#     RGB: (5, 5, 0)
#     Hex: #050500
#     CSS: rgb(5, 5, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 11.24%
#
# Imagen: 93OP_Create_an_image_in_front_view_of_an_older_person_prayin_ac293627-f0c9-410b-8da1-3c2972699f00_3.jpg
#   Brillo promedio: 34.57
#   Contraste: 45.82
#   Color dominante:
#     RGB: (0, 0, 0)
#     Hex: #000000
#     CSS: rgb(0, 0, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 21.56%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_0.jpg
#   Brillo promedio: 57.08
#   Contraste: 51.44
#   Color dominante:
#     RGB: (6, 9, 19)
#     Hex: #060913
#     CSS: rgb(6, 9, 19)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.16%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_1.jpg
#   Brillo promedio: 60.73
#   Contraste: 61.83
#   Color dominante:
#     RGB: (10, 10, 9)
#     Hex: #0a0a09
#     CSS: rgb(10, 10, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 6.25%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_2.jpg
#   Brillo promedio: 39.77
#   Contraste: 42.66
#   Color dominante:
#     RGB: (8, 10, 13)
#     Hex: #080a0d
#     CSS: rgb(8, 10, 13)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.23%
#
# Imagen: 94OP_an_older_person_attending_religious_services_in_photore_5b724c97-bb17-4302-9ca4-4f0d371b5997_3.jpg
#   Brillo promedio: 31.17
#   Contraste: 40.34
#   Color dominante:
#     RGB: (5, 6, 8)
#     Hex: #050608
#     CSS: rgb(5, 6, 8)
#     Simplificado: Negro
#   Porcentaje del color dominante: 9.35%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_0.jpg
#   Brillo promedio: 65.13
#   Contraste: 53.46
#   Color dominante:
#     RGB: (3, 15, 17)
#     Hex: #030f11
#     CSS: rgb(3, 15, 17)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.47%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_1.jpg
#   Brillo promedio: 81.31
#   Contraste: 73.73
#   Color dominante:
#     RGB: (13, 13, 17)
#     Hex: #0d0d11
#     CSS: rgb(13, 13, 17)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.96%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_2.jpg
#   Brillo promedio: 95.74
#   Contraste: 68.15
#   Color dominante:
#     RGB: (82, 7, 7)
#     Hex: #520707
#     CSS: rgb(82, 7, 7)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.06%
#
# Imagen: 95OP_a_full_body_portrait_of_an_older_person_in_the_living_r_a3f4abd7-6ffa-4bba-85ca-e7548948a23e_3.jpg
#   Brillo promedio: 64.75
#   Contraste: 68.08
#   Color dominante:
#     RGB: (4, 5, 9)
#     Hex: #040509
#     CSS: rgb(4, 5, 9)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.55%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_0.jpg
#   Brillo promedio: 72.67
#   Contraste: 59.80
#   Color dominante:
#     RGB: (16, 17, 20)
#     Hex: #101114
#     CSS: rgb(16, 17, 20)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.58%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_1.jpg
#   Brillo promedio: 81.12
#   Contraste: 73.77
#   Color dominante:
#     RGB: (30, 32, 27)
#     Hex: #1e201b
#     CSS: rgb(30, 32, 27)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.50%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_2.jpg
#   Brillo promedio: 58.91
#   Contraste: 63.13
#   Color dominante:
#     RGB: (16, 16, 11)
#     Hex: #10100b
#     CSS: rgb(16, 16, 11)
#     Simplificado: Negro
#   Porcentaje del color dominante: 6.00%
#
# Imagen: 9OP_a_full_body_portrait_of_an_older_person_at_the_dining_t_195a82d3-93ca-4f0d-876f-0d2fef7fa3e7_3.jpg
#   Brillo promedio: 64.75
#   Contraste: 63.15
#   Color dominante:
#     RGB: (15, 15, 10)
#     Hex: #0f0f0a
#     CSS: rgb(15, 15, 10)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.46%

# %%
pil_n = pd.DataFrame(resultados_n)
pil_o = pd.DataFrame(resultados_o)
pil = pd.concat([pil_n, pil_o], axis=0)   
df_merged = pd.merge(df_merged, pil, on='filename_jpg', how='left')

# %%
df_merged.to_csv(f'{output_dir}/df_merged_mid_19_8.csv', index=False)
