# %% [markdown]
# # SETUP

# %%
import os
import re
import ast
import json
import boto3
import random
import base64
import requests
import itertools
import numpy as np
import pandas as pd
from tqdm import tqdm
from PIL import Image
from scipy import stats
from itertools import product
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from botocore.exceptions import NoCredentialsError, PartialCredentialsError

#############################################

session = boto3.Session(profile_name='uoc')

credentials = session.get_credentials()
region = session.region_name

if credentials is None:
    print("No se encontraron credenciales.")
else:
    print(f"AWS Access Key: {credentials.access_key}")

if region is None:
    print("No se encontró la región.")
else:
    print(f"AWS Region: {region}")

client = boto3.client(
service_name= "bedrock-runtime",
region_name= "us-east-1")

output_folder = "C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7"

# %% [markdown]
# # SD (BEDROCK)

# %% [markdown]
# “DDIM”,
# “DDPM”,
# “K_DPMPP_SDE”,
# “K_DPMPP_2M”,
# “K_DPMPP_2S_ANCESTRAL”,
# “K_DPM_2”,
# “K_DPM_2_ANCESTRAL”,
# “K_EULER”,
# “K_EULER_ANCESTRAL”,
# “K_HEUN”,
# “K_LMS”
#
# Enum: 3d-model, analog-film, anime, cinematic, comic-book, digital-art, enhance, fantasy-art, isometric, line-art, low-poly, modeling-compound, neon-punk, origami,photographic, pixel-art, tile-texture.

# %%
model_id = "stability.stable-diffusion-xl-v1"

# %%
# Neutral
#negative = "hands, (hands:1.0), bad_hand, deformed, extra limbs, ugly eyes, imperfect eyes, deformed pupils, deformed iris"
#"hands, deformed, extra limbs, bad anatomy, blurry, weird eyes, facing towards camera, disfigured, fused fingers, missing limbs, mutated limbs"

df_neutral = pd.read_csv(f'{output_folder}/df_neutral.csv')

output_folder_n = f'{output_folder}/NEUTRAL'
if not os.path.exists(output_folder_n):
    os.makedirs(output_folder_n)

for index, row in df_neutral.iterrows():
    prompt = row['Prompt']
    image_id = row['ID']
    seed = random.randint(0, 4294967295)

    print(f"Generating image for: {prompt} with ID: {image_id}")

    payload = {
        "text_prompts": [{"text": prompt, "weight": 1},
                         {"text": "deformed, extra limbs, bad anatomy, blurry, weird eyes, facing backwards, disfigured, fused fingers, missing limbs, mutated limbs", "weight": -1}],
        "steps": 50,
        "seed": seed,
        "cfg_scale":7,
        "style_preset": "photographic",
        "sampler":"K_DPMPP_2M",
        "width":1024,
        "height":1024
    }
    
    request = json.dumps(payload)
    response = client.invoke_model(modelId=model_id, body=request)

    model_response = json.loads(response["body"].read())

    base64_image_data = model_response["artifacts"][0]["base64"]

    image_data = base64.b64decode(base64_image_data)
    image_path = os.path.join(output_folder_n, f"{image_id}.png")
    with open(image_path, "wb") as file:
        file.write(image_data)
 
    print(f"Image saved as: {image_path}")
    print(f"The generated image has been saved to {image_path}")

print("All images generated and saved successfully.")
# Out:
# Generating image for: A full shot of a person walking to the bathroom with ID: a_p1_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f1.png
# Generating image for: A full shot of a person walking to the bathroom with ID: a_p1_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f2.png
# Generating image for: A full shot of a person walking to the bathroom with ID: a_p1_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f3.png
# Generating image for: A full shot of a person walking to the bathroom with ID: a_p1_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p1_f4.png
# Generating image for: A full shot of a person moving between rooms with ID: a_p2_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f1.png
# Generating image for: A full shot of a person moving between rooms with ID: a_p2_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f2.png
# Generating image for: A full shot of a person moving between rooms with ID: a_p2_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f3.png
# Generating image for: A full shot of a person moving between rooms with ID: a_p2_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p2_f4.png
# Generating image for: A full shot of a person climbing stairs with ID: a_p3_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f1.png
# Generating image for: A full shot of a person climbing stairs with ID: a_p3_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f2.png
# Generating image for: A full shot of a person climbing stairs with ID: a_p3_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f3.png
# Generating image for: A full shot of a person climbing stairs with ID: a_p3_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p3_f4.png
# Generating image for: A full shot of a person cooking meals with ID: a_p4_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f1.png
# Generating image for: A full shot of a person cooking meals with ID: a_p4_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f2.png
# Generating image for: A full shot of a person cooking meals with ID: a_p4_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f3.png
# Generating image for: A full shot of a person cooking meals with ID: a_p4_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p4_f4.png
# Generating image for: A full shot of a person eating at the dining table with ID: a_p5_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f1.png
# Generating image for: A full shot of a person eating at the dining table with ID: a_p5_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f2.png
# Generating image for: A full shot of a person eating at the dining table with ID: a_p5_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f3.png
# Generating image for: A full shot of a person eating at the dining table with ID: a_p5_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p5_f4.png
# Generating image for: A full shot of a person setting the table with ID: a_p6_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f1.png
# Generating image for: A full shot of a person setting the table with ID: a_p6_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f2.png
# Generating image for: A full shot of a person setting the table with ID: a_p6_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f3.png
# Generating image for: A full shot of a person setting the table with ID: a_p6_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p6_f4.png
# Generating image for: A full shot of a person selecting clothes with ID: a_p7_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f1.png
# Generating image for: A full shot of a person selecting clothes with ID: a_p7_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f2.png
# Generating image for: A full shot of a person selecting clothes with ID: a_p7_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f3.png
# Generating image for: A full shot of a person selecting clothes with ID: a_p7_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p7_f4.png
# Generating image for: A full shot of a person putting on clothes with ID: a_p8_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f1.png
# Generating image for: A full shot of a person putting on clothes with ID: a_p8_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f2.png
# Generating image for: A full shot of a person putting on clothes with ID: a_p8_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f3.png
# Generating image for: A full shot of a person putting on clothes with ID: a_p8_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p8_f4.png
# Generating image for: A full shot of a person changing clothes with ID: a_p9_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f1.png
# Generating image for: A full shot of a person changing clothes with ID: a_p9_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f2.png
# Generating image for: A full shot of a person changing clothes with ID: a_p9_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f3.png
# Generating image for: A full shot of a person changing clothes with ID: a_p9_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p9_f4.png
# Generating image for: A full shot of a person showering or bathing with ID: a_p10_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f1.png
# Generating image for: A full shot of a person showering or bathing with ID: a_p10_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f2.png
# Generating image for: A full shot of a person showering or bathing with ID: a_p10_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f3.png
# Generating image for: A full shot of a person showering or bathing with ID: a_p10_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p10_f4.png
# Generating image for: A full shot of a person brushing teeth with ID: a_p11_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f1.png
# Generating image for: A full shot of a person brushing teeth with ID: a_p11_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f2.png
# Generating image for: A full shot of a person brushing teeth with ID: a_p11_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f3.png
# Generating image for: A full shot of a person brushing teeth with ID: a_p11_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p11_f4.png
# Generating image for: A full shot of a person grooming with ID: a_p12_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f1.png
# Generating image for: A full shot of a person grooming with ID: a_p12_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f2.png
# Generating image for: A full shot of a person grooming with ID: a_p12_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f3.png
# Generating image for: A full shot of a person grooming with ID: a_p12_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p12_f4.png
# Generating image for: A full shot of a person using the toilet with ID: a_p13_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f1.png
# Generating image for: A full shot of a person using the toilet with ID: a_p13_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f2.png
# Generating image for: A full shot of a person using the toilet with ID: a_p13_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f3.png
# Generating image for: A full shot of a person using the toilet with ID: a_p13_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p13_f4.png
# Generating image for: A full shot of a person changing incontinence products with ID: a_p14_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f1.png
# Generating image for: A full shot of a person changing incontinence products with ID: a_p14_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f2.png
# Generating image for: A full shot of a person changing incontinence products with ID: a_p14_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f3.png
# Generating image for: A full shot of a person changing incontinence products with ID: a_p14_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p14_f4.png
# Generating image for: A full shot of a person cleaning up spills with ID: a_p15_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f1.png
# Generating image for: A full shot of a person cleaning up spills with ID: a_p15_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f2.png
# Generating image for: A full shot of a person cleaning up spills with ID: a_p15_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f3.png
# Generating image for: A full shot of a person cleaning up spills with ID: a_p15_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p15_f4.png
# Generating image for: A full shot of a person walking to a nearby store with ID: a_p16_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f1.png
# Generating image for: A full shot of a person walking to a nearby store with ID: a_p16_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f2.png
# Generating image for: A full shot of a person walking to a nearby store with ID: a_p16_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f3.png
# Generating image for: A full shot of a person walking to a nearby store with ID: a_p16_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p16_f4.png
# Generating image for: A full shot of a person strolling in the neighborhood with ID: a_p17_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f1.png
# Generating image for: A full shot of a person strolling in the neighborhood with ID: a_p17_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f2.png
# Generating image for: A full shot of a person strolling in the neighborhood with ID: a_p17_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f3.png
# Generating image for: A full shot of a person strolling in the neighborhood with ID: a_p17_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p17_f4.png
# Generating image for: A full shot of a person walking to public transport with ID: a_p18_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f1.png
# Generating image for: A full shot of a person walking to public transport with ID: a_p18_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f2.png
# Generating image for: A full shot of a person walking to public transport with ID: a_p18_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f3.png
# Generating image for: A full shot of a person walking to public transport with ID: a_p18_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p18_f4.png
# Generating image for: A full shot of a person dining at restaurants with ID: a_p19_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f1.png
# Generating image for: A full shot of a person dining at restaurants with ID: a_p19_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f2.png
# Generating image for: A full shot of a person dining at restaurants with ID: a_p19_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f3.png
# Generating image for: A full shot of a person dining at restaurants with ID: a_p19_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p19_f4.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p20_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f1.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p20_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f2.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p20_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f3.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p20_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p20_f4.png
# Generating image for: A full shot of a person picnicking with ID: a_p21_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f1.png
# Generating image for: A full shot of a person picnicking with ID: a_p21_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f2.png
# Generating image for: A full shot of a person picnicking with ID: a_p21_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f3.png
# Generating image for: A full shot of a person picnicking with ID: a_p21_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p21_f4.png
# Generating image for: A full shot of a person shopping for clothes with ID: a_p22_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f1.png
# Generating image for: A full shot of a person shopping for clothes with ID: a_p22_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f2.png
# Generating image for: A full shot of a person shopping for clothes with ID: a_p22_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f3.png
# Generating image for: A full shot of a person shopping for clothes with ID: a_p22_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p22_f4.png
# Generating image for: A full shot of a person attending fittings with ID: a_p23_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f1.png
# Generating image for: A full shot of a person attending fittings with ID: a_p23_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f2.png
# Generating image for: A full shot of a person attending fittings with ID: a_p23_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f3.png
# Generating image for: A full shot of a person attending fittings with ID: a_p23_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p23_f4.png
# Generating image for: A full shot of a person picking up laundry with ID: a_p24_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f1.png
# Generating image for: A full shot of a person picking up laundry with ID: a_p24_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f2.png
# Generating image for: A full shot of a person picking up laundry with ID: a_p24_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f3.png
# Generating image for: A full shot of a person picking up laundry with ID: a_p24_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p24_f4.png
# Generating image for: A full shot of a person visiting a salon or barber with ID: a_p25_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f1.png
# Generating image for: A full shot of a person visiting a salon or barber with ID: a_p25_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f2.png
# Generating image for: A full shot of a person visiting a salon or barber with ID: a_p25_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f3.png
# Generating image for: A full shot of a person visiting a salon or barber with ID: a_p25_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p25_f4.png
# Generating image for: A full shot of a person using public restrooms (outdoors) with ID: a_p26_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f1.png
# Generating image for: A full shot of a person using public restrooms (outdoors) with ID: a_p26_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f2.png
# Generating image for: A full shot of a person using public restrooms (outdoors) with ID: a_p26_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f3.png
# Generating image for: A full shot of a person using public restrooms (outdoors) with ID: a_p26_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p26_f4.png
# Generating image for: A full shot of a person buying personal care products with ID: a_p27_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f1.png
# Generating image for: A full shot of a person buying personal care products with ID: a_p27_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f2.png
# Generating image for: A full shot of a person buying personal care products with ID: a_p27_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f3.png
# Generating image for: A full shot of a person buying personal care products with ID: a_p27_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p27_f4.png
# Generating image for: A full shot of a person using public restrooms (indoors) with ID: a_p28_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f1.png
# Generating image for: A full shot of a person using public restrooms (indoors) with ID: a_p28_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f2.png
# Generating image for: A full shot of a person using public restrooms (indoors) with ID: a_p28_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f3.png
# Generating image for: A full shot of a person using public restrooms (indoors) with ID: a_p28_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p28_f4.png
# Generating image for: A full shot of a person purchasing incontinence products with ID: a_p29_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f1.png
# Generating image for: A full shot of a person purchasing incontinence products with ID: a_p29_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f2.png
# Generating image for: A full shot of a person purchasing incontinence products with ID: a_p29_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f3.png
# Generating image for: A full shot of a person purchasing incontinence products with ID: a_p29_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p29_f4.png
# Generating image for: A full shot of a person attending medical appointments with ID: a_p30_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f1.png
# Generating image for: A full shot of a person attending medical appointments with ID: a_p30_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f2.png
# Generating image for: A full shot of a person attending medical appointments with ID: a_p30_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f3.png
# Generating image for: A full shot of a person attending medical appointments with ID: a_p30_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p30_f4.png
# Generating image for: A full shot of a person finding and using public restrooms with ID: a_p31_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f1.png
# Generating image for: A full shot of a person finding and using public restrooms with ID: a_p31_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f2.png
# Generating image for: A full shot of a person finding and using public restrooms with ID: a_p31_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f3.png
# Generating image for: A full shot of a person finding and using public restrooms with ID: a_p31_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p31_f4.png
# Generating image for: A full shot of a person traveling with portable toilets with ID: a_p32_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f1.png
# Generating image for: A full shot of a person traveling with portable toilets with ID: a_p32_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f2.png
# Generating image for: A full shot of a person traveling with portable toilets with ID: a_p32_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f3.png
# Generating image for: A full shot of a person traveling with portable toilets with ID: a_p32_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p32_f4.png
# Generating image for: A full shot of a person accessing restroom facilities in public places with ID: a_p33_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f1.png
# Generating image for: A full shot of a person accessing restroom facilities in public places with ID: a_p33_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f2.png
# Generating image for: A full shot of a person accessing restroom facilities in public places with ID: a_p33_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f3.png
# Generating image for: A full shot of a person accessing restroom facilities in public places with ID: a_p33_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p33_f4.png
# Generating image for: A full shot of a person using public transport with ID: a_p34_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f1.png
# Generating image for: A full shot of a person using public transport with ID: a_p34_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f2.png
# Generating image for: A full shot of a person using public transport with ID: a_p34_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f3.png
# Generating image for: A full shot of a person using public transport with ID: a_p34_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p34_f4.png
# Generating image for: A full shot of a person driving with ID: a_p35_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f1.png
# Generating image for: A full shot of a person driving with ID: a_p35_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f2.png
# Generating image for: A full shot of a person driving with ID: a_p35_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f3.png
# Generating image for: A full shot of a person driving with ID: a_p35_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p35_f4.png
# Generating image for: A full shot of a person walking to stores with ID: a_p36_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f1.png
# Generating image for: A full shot of a person walking to stores with ID: a_p36_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f2.png
# Generating image for: A full shot of a person walking to stores with ID: a_p36_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f3.png
# Generating image for: A full shot of a person walking to stores with ID: a_p36_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p36_f4.png
# Generating image for: A full shot of a person visiting banks with ID: a_p37_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f1.png
# Generating image for: A full shot of a person visiting banks with ID: a_p37_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f2.png
# Generating image for: A full shot of a person visiting banks with ID: a_p37_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f3.png
# Generating image for: A full shot of a person visiting banks with ID: a_p37_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p37_f4.png
# Generating image for: A full shot of a person using atms with ID: a_p38_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f1.png
# Generating image for: A full shot of a person using atms with ID: a_p38_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f2.png
# Generating image for: A full shot of a person using atms with ID: a_p38_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f3.png
# Generating image for: A full shot of a person using atms with ID: a_p38_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p38_f4.png
# Generating image for: A full shot of a person consulting financial advisors with ID: a_p39_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f1.png
# Generating image for: A full shot of a person consulting financial advisors with ID: a_p39_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f2.png
# Generating image for: A full shot of a person consulting financial advisors with ID: a_p39_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f3.png
# Generating image for: A full shot of a person consulting financial advisors with ID: a_p39_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p39_f4.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p40_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f1.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p40_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f2.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p40_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f3.png
# Generating image for: A full shot of a person grocery shopping with ID: a_p40_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p40_f4.png
# Generating image for: A full shot of a person visiting farmers’ markets with ID: a_p41_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f1.png
# Generating image for: A full shot of a person visiting farmers’ markets with ID: a_p41_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f2.png
# Generating image for: A full shot of a person visiting farmers’ markets with ID: a_p41_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f3.png
# Generating image for: A full shot of a person visiting farmers’ markets with ID: a_p41_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p41_f4.png
# Generating image for: A full shot of a person eating out with ID: a_p42_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p42_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p42_f1.png
# Generating image for: A full shot of a person eating out with ID: a_p42_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p42_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p42_f2.png
# Generating image for: A full shot of a person eating out with ID: a_p42_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p42_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p42_f3.png
# Generating image for: A full shot of a person eating out with ID: a_p42_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p42_f4.png
# ...
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p221_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p221_f3.png
# Generating image for: A close-up shot of a person hiking with ID: a_p221_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p221_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p221_f4.png
# Generating image for: A close-up shot of a person beach walks with ID: a_p222_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f1.png
# Generating image for: A close-up shot of a person beach walks with ID: a_p222_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f2.png
# Generating image for: A close-up shot of a person beach walks with ID: a_p222_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f3.png
# Generating image for: A close-up shot of a person beach walks with ID: a_p222_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p222_f4.png
# Generating image for: A close-up shot of a person nature walks with ID: a_p223_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f1.png
# Generating image for: A close-up shot of a person nature walks with ID: a_p223_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f2.png
# Generating image for: A close-up shot of a person nature walks with ID: a_p223_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f3.png
# Generating image for: A close-up shot of a person nature walks with ID: a_p223_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p223_f4.png
# Generating image for: A close-up shot of a person outdoor meditation sessions with ID: a_p224_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f1.png
# Generating image for: A close-up shot of a person outdoor meditation sessions with ID: a_p224_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f2.png
# Generating image for: A close-up shot of a person outdoor meditation sessions with ID: a_p224_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f3.png
# Generating image for: A close-up shot of a person outdoor meditation sessions with ID: a_p224_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p224_f4.png
# Generating image for: A close-up shot of a person outdoor support groups with ID: a_p225_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f1.png
# Generating image for: A close-up shot of a person outdoor support groups with ID: a_p225_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f2.png
# Generating image for: A close-up shot of a person outdoor support groups with ID: a_p225_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f3.png
# Generating image for: A close-up shot of a person outdoor support groups with ID: a_p225_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p225_f4.png
# Generating image for: A close-up shot of a person attending physical therapy sessions with ID: a_p226_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f1.png
# Generating image for: A close-up shot of a person attending physical therapy sessions with ID: a_p226_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f2.png
# Generating image for: A close-up shot of a person attending physical therapy sessions with ID: a_p226_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f3.png
# Generating image for: A close-up shot of a person attending physical therapy sessions with ID: a_p226_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p226_f4.png
# Generating image for: A close-up shot of a person participating in outdoor rehab programs with ID: a_p227_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f1.png
# Generating image for: A close-up shot of a person participating in outdoor rehab programs with ID: a_p227_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f2.png
# Generating image for: A close-up shot of a person participating in outdoor rehab programs with ID: a_p227_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f3.png
# Generating image for: A close-up shot of a person participating in outdoor rehab programs with ID: a_p227_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p227_f4.png
# Generating image for: A close-up shot of a person functional outdoor activities with ID: a_p228_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f1.png
# Generating image for: A close-up shot of a person functional outdoor activities with ID: a_p228_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f2.png
# Generating image for: A close-up shot of a person functional outdoor activities with ID: a_p228_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f3.png
# Generating image for: A close-up shot of a person functional outdoor activities with ID: a_p228_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p228_f4.png
# Generating image for: A close-up shot of a person attending workshops or seminars with ID: a_p229_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f1.png
# Generating image for: A close-up shot of a person attending workshops or seminars with ID: a_p229_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f2.png
# Generating image for: A close-up shot of a person attending workshops or seminars with ID: a_p229_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f3.png
# Generating image for: A close-up shot of a person attending workshops or seminars with ID: a_p229_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p229_f4.png
# Generating image for: A close-up shot of a person job fairs with ID: a_p230_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f1.png
# Generating image for: A close-up shot of a person job fairs with ID: a_p230_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f2.png
# Generating image for: A close-up shot of a person job fairs with ID: a_p230_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f3.png
# Generating image for: A close-up shot of a person job fairs with ID: a_p230_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p230_f4.png
# Generating image for: A close-up shot of a person volunteering with ID: a_p231_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f1.png
# Generating image for: A close-up shot of a person volunteering with ID: a_p231_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f2.png
# Generating image for: A close-up shot of a person volunteering with ID: a_p231_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f3.png
# Generating image for: A close-up shot of a person volunteering with ID: a_p231_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p231_f4.png
# Generating image for: A close-up shot of a person visiting health clinics (outdoors) with ID: a_p232_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f1.png
# Generating image for: A close-up shot of a person visiting health clinics (outdoors) with ID: a_p232_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f2.png
# Generating image for: A close-up shot of a person visiting health clinics (outdoors) with ID: a_p232_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f3.png
# Generating image for: A close-up shot of a person visiting health clinics (outdoors) with ID: a_p232_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p232_f4.png
# Generating image for: A close-up shot of a person outdoor exercise for health with ID: a_p233_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f1.png
# Generating image for: A close-up shot of a person outdoor exercise for health with ID: a_p233_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f2.png
# Generating image for: A close-up shot of a person outdoor exercise for health with ID: a_p233_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f3.png
# Generating image for: A close-up shot of a person outdoor exercise for health with ID: a_p233_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p233_f4.png
# Generating image for: A close-up shot of a person attending health workshops with ID: a_p234_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f1.png
# Generating image for: A close-up shot of a person attending health workshops with ID: a_p234_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f2.png
# Generating image for: A close-up shot of a person attending health workshops with ID: a_p234_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f3.png
# Generating image for: A close-up shot of a person attending health workshops with ID: a_p234_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/NEUTRAL\a_p234_f4.png
# All images generated and saved successfully.

# %%
# Older
df_olds = pd.read_csv(f'{output_folder}/df_older.csv')

output_folder_o = f'{output_folder}/OLDER'
if not os.path.exists(output_folder_o):
    os.makedirs(output_folder_o)

for index, row in df_olds.iterrows():
    prompt = row['Prompt']
    image_id = row['ID']
    seed = random.randint(0, 4294967295)

    print(f"Generating image for: {prompt} with ID: {image_id}")

    payload = {
        "text_prompts": [{"text": prompt, "weight": 1}, 
                         {"text": "hands, face, deformed, extra limbs, eyes", "weight": -1}],
        "steps": 50,
        "seed": seed,
        "cfg_scale":10,
        "style_preset": "photographic",
        "sampler":"K_DPMPP_2M",
        "width":1024,
        "height":1024
    }
    
    request = json.dumps(payload)
    response = client.invoke_model(modelId=model_id, body=request)

    model_response = json.loads(response["body"].read())

    base64_image_data = model_response["artifacts"][0]["base64"]

    image_data = base64.b64decode(base64_image_data)
    image_path = os.path.join(output_folder_o, f"{image_id}.png")
    with open(image_path, "wb") as file:
        file.write(image_data)
 
    print(f"Image saved as: {image_path}")
    print(f"The generated image has been saved to {image_path}")

print("All images generated and saved successfully.")
# Out:
# Generating image for: A full shot of an older person walking to the bathroom with ID: o_p1_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f1.png
# Generating image for: A full shot of an older person walking to the bathroom with ID: o_p1_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f2.png
# Generating image for: A full shot of an older person walking to the bathroom with ID: o_p1_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f3.png
# Generating image for: A full shot of an older person walking to the bathroom with ID: o_p1_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p1_f4.png
# Generating image for: A full shot of an older person moving between rooms with ID: o_p2_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f1.png
# Generating image for: A full shot of an older person moving between rooms with ID: o_p2_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f2.png
# Generating image for: A full shot of an older person moving between rooms with ID: o_p2_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f3.png
# Generating image for: A full shot of an older person moving between rooms with ID: o_p2_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p2_f4.png
# Generating image for: A full shot of an older person climbing stairs with ID: o_p3_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f1.png
# Generating image for: A full shot of an older person climbing stairs with ID: o_p3_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f2.png
# Generating image for: A full shot of an older person climbing stairs with ID: o_p3_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f3.png
# Generating image for: A full shot of an older person climbing stairs with ID: o_p3_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p3_f4.png
# Generating image for: A full shot of an older person cooking meals with ID: o_p4_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f1.png
# Generating image for: A full shot of an older person cooking meals with ID: o_p4_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f2.png
# Generating image for: A full shot of an older person cooking meals with ID: o_p4_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f3.png
# Generating image for: A full shot of an older person cooking meals with ID: o_p4_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p4_f4.png
# Generating image for: A full shot of an older person eating at the dining table with ID: o_p5_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f1.png
# Generating image for: A full shot of an older person eating at the dining table with ID: o_p5_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f2.png
# Generating image for: A full shot of an older person eating at the dining table with ID: o_p5_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f3.png
# Generating image for: A full shot of an older person eating at the dining table with ID: o_p5_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p5_f4.png
# Generating image for: A full shot of an older person setting the table with ID: o_p6_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f1.png
# Generating image for: A full shot of an older person setting the table with ID: o_p6_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f2.png
# Generating image for: A full shot of an older person setting the table with ID: o_p6_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f3.png
# Generating image for: A full shot of an older person setting the table with ID: o_p6_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p6_f4.png
# Generating image for: A full shot of an older person selecting clothes with ID: o_p7_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f1.png
# Generating image for: A full shot of an older person selecting clothes with ID: o_p7_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f2.png
# Generating image for: A full shot of an older person selecting clothes with ID: o_p7_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f3.png
# Generating image for: A full shot of an older person selecting clothes with ID: o_p7_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p7_f4.png
# Generating image for: A full shot of an older person putting on clothes with ID: o_p8_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f1.png
# Generating image for: A full shot of an older person putting on clothes with ID: o_p8_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f2.png
# Generating image for: A full shot of an older person putting on clothes with ID: o_p8_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f3.png
# Generating image for: A full shot of an older person putting on clothes with ID: o_p8_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p8_f4.png
# Generating image for: A full shot of an older person changing clothes with ID: o_p9_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f1.png
# Generating image for: A full shot of an older person changing clothes with ID: o_p9_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f2.png
# Generating image for: A full shot of an older person changing clothes with ID: o_p9_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f3.png
# Generating image for: A full shot of an older person changing clothes with ID: o_p9_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p9_f4.png
# Generating image for: A full shot of an older person showering or bathing with ID: o_p10_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f1.png
# Generating image for: A full shot of an older person showering or bathing with ID: o_p10_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f2.png
# Generating image for: A full shot of an older person showering or bathing with ID: o_p10_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f3.png
# Generating image for: A full shot of an older person showering or bathing with ID: o_p10_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p10_f4.png
# Generating image for: A full shot of an older person brushing teeth with ID: o_p11_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f1.png
# Generating image for: A full shot of an older person brushing teeth with ID: o_p11_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f2.png
# Generating image for: A full shot of an older person brushing teeth with ID: o_p11_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f3.png
# Generating image for: A full shot of an older person brushing teeth with ID: o_p11_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p11_f4.png
# Generating image for: A full shot of an older person grooming with ID: o_p12_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f1.png
# Generating image for: A full shot of an older person grooming with ID: o_p12_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f2.png
# Generating image for: A full shot of an older person grooming with ID: o_p12_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f3.png
# Generating image for: A full shot of an older person grooming with ID: o_p12_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p12_f4.png
# Generating image for: A full shot of an older person using the toilet with ID: o_p13_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f1.png
# Generating image for: A full shot of an older person using the toilet with ID: o_p13_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f2.png
# Generating image for: A full shot of an older person using the toilet with ID: o_p13_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f3.png
# Generating image for: A full shot of an older person using the toilet with ID: o_p13_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p13_f4.png
# Generating image for: A full shot of an older person changing incontinence products with ID: o_p14_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f1.png
# Generating image for: A full shot of an older person changing incontinence products with ID: o_p14_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f2.png
# Generating image for: A full shot of an older person changing incontinence products with ID: o_p14_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f3.png
# Generating image for: A full shot of an older person changing incontinence products with ID: o_p14_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p14_f4.png
# Generating image for: A full shot of an older person cleaning up spills with ID: o_p15_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f1.png
# Generating image for: A full shot of an older person cleaning up spills with ID: o_p15_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f2.png
# Generating image for: A full shot of an older person cleaning up spills with ID: o_p15_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f3.png
# Generating image for: A full shot of an older person cleaning up spills with ID: o_p15_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p15_f4.png
# Generating image for: A full shot of an older person walking to a nearby store with ID: o_p16_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f1.png
# Generating image for: A full shot of an older person walking to a nearby store with ID: o_p16_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f2.png
# Generating image for: A full shot of an older person walking to a nearby store with ID: o_p16_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f3.png
# Generating image for: A full shot of an older person walking to a nearby store with ID: o_p16_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p16_f4.png
# Generating image for: A full shot of an older person strolling in the neighborhood with ID: o_p17_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f1.png
# Generating image for: A full shot of an older person strolling in the neighborhood with ID: o_p17_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f2.png
# Generating image for: A full shot of an older person strolling in the neighborhood with ID: o_p17_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f3.png
# Generating image for: A full shot of an older person strolling in the neighborhood with ID: o_p17_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p17_f4.png
# Generating image for: A full shot of an older person walking to public transport with ID: o_p18_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f1.png
# Generating image for: A full shot of an older person walking to public transport with ID: o_p18_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f2.png
# Generating image for: A full shot of an older person walking to public transport with ID: o_p18_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f3.png
# Generating image for: A full shot of an older person walking to public transport with ID: o_p18_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p18_f4.png
# Generating image for: A full shot of an older person dining at restaurants with ID: o_p19_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f1.png
# Generating image for: A full shot of an older person dining at restaurants with ID: o_p19_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f2.png
# Generating image for: A full shot of an older person dining at restaurants with ID: o_p19_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f3.png
# Generating image for: A full shot of an older person dining at restaurants with ID: o_p19_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p19_f4.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p20_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f1.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p20_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f2.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p20_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f3.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p20_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p20_f4.png
# Generating image for: A full shot of an older person picnicking with ID: o_p21_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f1.png
# Generating image for: A full shot of an older person picnicking with ID: o_p21_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f2.png
# Generating image for: A full shot of an older person picnicking with ID: o_p21_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f3.png
# Generating image for: A full shot of an older person picnicking with ID: o_p21_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p21_f4.png
# Generating image for: A full shot of an older person shopping for clothes with ID: o_p22_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f1.png
# Generating image for: A full shot of an older person shopping for clothes with ID: o_p22_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f2.png
# Generating image for: A full shot of an older person shopping for clothes with ID: o_p22_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f3.png
# Generating image for: A full shot of an older person shopping for clothes with ID: o_p22_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p22_f4.png
# Generating image for: A full shot of an older person attending fittings with ID: o_p23_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f1.png
# Generating image for: A full shot of an older person attending fittings with ID: o_p23_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f2.png
# Generating image for: A full shot of an older person attending fittings with ID: o_p23_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f3.png
# Generating image for: A full shot of an older person attending fittings with ID: o_p23_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p23_f4.png
# Generating image for: A full shot of an older person picking up laundry with ID: o_p24_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f1.png
# Generating image for: A full shot of an older person picking up laundry with ID: o_p24_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f2.png
# Generating image for: A full shot of an older person picking up laundry with ID: o_p24_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f3.png
# Generating image for: A full shot of an older person picking up laundry with ID: o_p24_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p24_f4.png
# Generating image for: A full shot of an older person visiting a salon or barber with ID: o_p25_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f1.png
# Generating image for: A full shot of an older person visiting a salon or barber with ID: o_p25_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f2.png
# Generating image for: A full shot of an older person visiting a salon or barber with ID: o_p25_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f3.png
# Generating image for: A full shot of an older person visiting a salon or barber with ID: o_p25_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p25_f4.png
# Generating image for: A full shot of an older person using public restrooms (outdoors) with ID: o_p26_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f1.png
# Generating image for: A full shot of an older person using public restrooms (outdoors) with ID: o_p26_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f2.png
# Generating image for: A full shot of an older person using public restrooms (outdoors) with ID: o_p26_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f3.png
# Generating image for: A full shot of an older person using public restrooms (outdoors) with ID: o_p26_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p26_f4.png
# Generating image for: A full shot of an older person buying personal care products with ID: o_p27_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f1.png
# Generating image for: A full shot of an older person buying personal care products with ID: o_p27_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f2.png
# Generating image for: A full shot of an older person buying personal care products with ID: o_p27_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f3.png
# Generating image for: A full shot of an older person buying personal care products with ID: o_p27_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p27_f4.png
# Generating image for: A full shot of an older person using public restrooms (indoors) with ID: o_p28_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f1.png
# Generating image for: A full shot of an older person using public restrooms (indoors) with ID: o_p28_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f2.png
# Generating image for: A full shot of an older person using public restrooms (indoors) with ID: o_p28_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f3.png
# Generating image for: A full shot of an older person using public restrooms (indoors) with ID: o_p28_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p28_f4.png
# Generating image for: A full shot of an older person purchasing incontinence products with ID: o_p29_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f1.png
# Generating image for: A full shot of an older person purchasing incontinence products with ID: o_p29_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f2.png
# Generating image for: A full shot of an older person purchasing incontinence products with ID: o_p29_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f3.png
# Generating image for: A full shot of an older person purchasing incontinence products with ID: o_p29_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p29_f4.png
# Generating image for: A full shot of an older person attending medical appointments with ID: o_p30_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f1.png
# Generating image for: A full shot of an older person attending medical appointments with ID: o_p30_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f2.png
# Generating image for: A full shot of an older person attending medical appointments with ID: o_p30_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f3.png
# Generating image for: A full shot of an older person attending medical appointments with ID: o_p30_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p30_f4.png
# Generating image for: A full shot of an older person finding and using public restrooms with ID: o_p31_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f1.png
# Generating image for: A full shot of an older person finding and using public restrooms with ID: o_p31_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f2.png
# Generating image for: A full shot of an older person finding and using public restrooms with ID: o_p31_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f3.png
# Generating image for: A full shot of an older person finding and using public restrooms with ID: o_p31_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p31_f4.png
# Generating image for: A full shot of an older person traveling with portable toilets with ID: o_p32_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f1.png
# Generating image for: A full shot of an older person traveling with portable toilets with ID: o_p32_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f2.png
# Generating image for: A full shot of an older person traveling with portable toilets with ID: o_p32_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f3.png
# Generating image for: A full shot of an older person traveling with portable toilets with ID: o_p32_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p32_f4.png
# Generating image for: A full shot of an older person accessing restroom facilities in public places with ID: o_p33_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f1.png
# Generating image for: A full shot of an older person accessing restroom facilities in public places with ID: o_p33_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f2.png
# Generating image for: A full shot of an older person accessing restroom facilities in public places with ID: o_p33_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f3.png
# Generating image for: A full shot of an older person accessing restroom facilities in public places with ID: o_p33_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p33_f4.png
# Generating image for: A full shot of an older person using public transport with ID: o_p34_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f1.png
# Generating image for: A full shot of an older person using public transport with ID: o_p34_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f2.png
# Generating image for: A full shot of an older person using public transport with ID: o_p34_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f3.png
# Generating image for: A full shot of an older person using public transport with ID: o_p34_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p34_f4.png
# Generating image for: A full shot of an older person driving with ID: o_p35_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f1.png
# Generating image for: A full shot of an older person driving with ID: o_p35_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f2.png
# Generating image for: A full shot of an older person driving with ID: o_p35_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f3.png
# Generating image for: A full shot of an older person driving with ID: o_p35_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p35_f4.png
# Generating image for: A full shot of an older person walking to stores with ID: o_p36_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f1.png
# Generating image for: A full shot of an older person walking to stores with ID: o_p36_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f2.png
# Generating image for: A full shot of an older person walking to stores with ID: o_p36_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f3.png
# Generating image for: A full shot of an older person walking to stores with ID: o_p36_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p36_f4.png
# Generating image for: A full shot of an older person visiting banks with ID: o_p37_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f1.png
# Generating image for: A full shot of an older person visiting banks with ID: o_p37_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f2.png
# Generating image for: A full shot of an older person visiting banks with ID: o_p37_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f3.png
# Generating image for: A full shot of an older person visiting banks with ID: o_p37_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p37_f4.png
# Generating image for: A full shot of an older person using atms with ID: o_p38_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f1.png
# Generating image for: A full shot of an older person using atms with ID: o_p38_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f2.png
# Generating image for: A full shot of an older person using atms with ID: o_p38_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f3.png
# Generating image for: A full shot of an older person using atms with ID: o_p38_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p38_f4.png
# Generating image for: A full shot of an older person consulting financial advisors with ID: o_p39_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f1.png
# Generating image for: A full shot of an older person consulting financial advisors with ID: o_p39_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f2.png
# Generating image for: A full shot of an older person consulting financial advisors with ID: o_p39_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f3.png
# Generating image for: A full shot of an older person consulting financial advisors with ID: o_p39_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p39_f4.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p40_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f1.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p40_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f2.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p40_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f3.png
# Generating image for: A full shot of an older person grocery shopping with ID: o_p40_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p40_f4.png
# Generating image for: A full shot of an older person visiting farmers’ markets with ID: o_p41_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f1.png
# Generating image for: A full shot of an older person visiting farmers’ markets with ID: o_p41_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f2.png
# Generating image for: A full shot of an older person visiting farmers’ markets with ID: o_p41_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f3.png
# Generating image for: A full shot of an older person visiting farmers’ markets with ID: o_p41_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p41_f4.png
# Generating image for: A full shot of an older person eating out with ID: o_p42_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p42_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p42_f1.png
# Generating image for: A full shot of an older person eating out with ID: o_p42_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p42_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p42_f2.png
# ...
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p221_f3.png
# Generating image for: A close-up shot of an older person hiking with ID: o_p221_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p221_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p221_f4.png
# Generating image for: A close-up shot of an older person beach walks with ID: o_p222_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f1.png
# Generating image for: A close-up shot of an older person beach walks with ID: o_p222_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f2.png
# Generating image for: A close-up shot of an older person beach walks with ID: o_p222_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f3.png
# Generating image for: A close-up shot of an older person beach walks with ID: o_p222_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p222_f4.png
# Generating image for: A close-up shot of an older person nature walks with ID: o_p223_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f1.png
# Generating image for: A close-up shot of an older person nature walks with ID: o_p223_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f2.png
# Generating image for: A close-up shot of an older person nature walks with ID: o_p223_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f3.png
# Generating image for: A close-up shot of an older person nature walks with ID: o_p223_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p223_f4.png
# Generating image for: A close-up shot of an older person outdoor meditation sessions with ID: o_p224_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f1.png
# Generating image for: A close-up shot of an older person outdoor meditation sessions with ID: o_p224_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f2.png
# Generating image for: A close-up shot of an older person outdoor meditation sessions with ID: o_p224_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f3.png
# Generating image for: A close-up shot of an older person outdoor meditation sessions with ID: o_p224_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p224_f4.png
# Generating image for: A close-up shot of an older person outdoor support groups with ID: o_p225_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f1.png
# Generating image for: A close-up shot of an older person outdoor support groups with ID: o_p225_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f2.png
# Generating image for: A close-up shot of an older person outdoor support groups with ID: o_p225_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f3.png
# Generating image for: A close-up shot of an older person outdoor support groups with ID: o_p225_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p225_f4.png
# Generating image for: A close-up shot of an older person attending physical therapy sessions with ID: o_p226_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f1.png
# Generating image for: A close-up shot of an older person attending physical therapy sessions with ID: o_p226_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f2.png
# Generating image for: A close-up shot of an older person attending physical therapy sessions with ID: o_p226_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f3.png
# Generating image for: A close-up shot of an older person attending physical therapy sessions with ID: o_p226_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p226_f4.png
# Generating image for: A close-up shot of an older person participating in outdoor rehab programs with ID: o_p227_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f1.png
# Generating image for: A close-up shot of an older person participating in outdoor rehab programs with ID: o_p227_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f2.png
# Generating image for: A close-up shot of an older person participating in outdoor rehab programs with ID: o_p227_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f3.png
# Generating image for: A close-up shot of an older person participating in outdoor rehab programs with ID: o_p227_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p227_f4.png
# Generating image for: A close-up shot of an older person functional outdoor activities with ID: o_p228_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f1.png
# Generating image for: A close-up shot of an older person functional outdoor activities with ID: o_p228_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f2.png
# Generating image for: A close-up shot of an older person functional outdoor activities with ID: o_p228_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f3.png
# Generating image for: A close-up shot of an older person functional outdoor activities with ID: o_p228_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p228_f4.png
# Generating image for: A close-up shot of an older person attending workshops or seminars with ID: o_p229_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f1.png
# Generating image for: A close-up shot of an older person attending workshops or seminars with ID: o_p229_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f2.png
# Generating image for: A close-up shot of an older person attending workshops or seminars with ID: o_p229_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f3.png
# Generating image for: A close-up shot of an older person attending workshops or seminars with ID: o_p229_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p229_f4.png
# Generating image for: A close-up shot of an older person job fairs with ID: o_p230_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f1.png
# Generating image for: A close-up shot of an older person job fairs with ID: o_p230_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f2.png
# Generating image for: A close-up shot of an older person job fairs with ID: o_p230_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f3.png
# Generating image for: A close-up shot of an older person job fairs with ID: o_p230_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p230_f4.png
# Generating image for: A close-up shot of an older person volunteering with ID: o_p231_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f1.png
# Generating image for: A close-up shot of an older person volunteering with ID: o_p231_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f2.png
# Generating image for: A close-up shot of an older person volunteering with ID: o_p231_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f3.png
# Generating image for: A close-up shot of an older person volunteering with ID: o_p231_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p231_f4.png
# Generating image for: A close-up shot of an older person visiting health clinics (outdoors) with ID: o_p232_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f1.png
# Generating image for: A close-up shot of an older person visiting health clinics (outdoors) with ID: o_p232_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f2.png
# Generating image for: A close-up shot of an older person visiting health clinics (outdoors) with ID: o_p232_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f3.png
# Generating image for: A close-up shot of an older person visiting health clinics (outdoors) with ID: o_p232_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p232_f4.png
# Generating image for: A close-up shot of an older person outdoor exercise for health with ID: o_p233_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f1.png
# Generating image for: A close-up shot of an older person outdoor exercise for health with ID: o_p233_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f2.png
# Generating image for: A close-up shot of an older person outdoor exercise for health with ID: o_p233_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f3.png
# Generating image for: A close-up shot of an older person outdoor exercise for health with ID: o_p233_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p233_f4.png
# Generating image for: A close-up shot of an older person attending health workshops with ID: o_p234_f1
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f1.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f1.png
# Generating image for: A close-up shot of an older person attending health workshops with ID: o_p234_f2
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f2.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f2.png
# Generating image for: A close-up shot of an older person attending health workshops with ID: o_p234_f3
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f3.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f3.png
# Generating image for: A close-up shot of an older person attending health workshops with ID: o_p234_f4
# Image saved as: C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f4.png
# The generated image has been saved to C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/10_7/OLDER\o_p234_f4.png
# All images generated and saved successfully.

# %% [markdown]
# # SONNET

# %%
prompts = {
    "age_range": "Estimate the age range of the person in this image. Just answer with the following range of numbers: 18-24, 25-34, 35-44, 45-54, 55-64, 65-79 or 80+. Return only a JSON object with no further information. If there's no person visible, return none.",
    "gender": "Answer only with the options provided: the gender of the person is: male, female, or if it's not possible to determine, none. Return it as a JSON object.",
    "adj_image": "List a maximum of 10 adjectives that describe the image. Return only a JSON object with no further information.",
    "adj_person": "List a maximum of 10 adjectives that describe the person in the image. Return only a JSON object with no further information.",
    "verbs": "List the visible actions (verbs) by the person in this image. Be concise and precise in your answers. Return it as a JSON object as {\"verbs\": [\"verb1\", \"verb2\", ...]}. If none are visible, return an empty JSON object.",
    "emotions_short": "Answer only with the options provided: the emotion expressed by the person is: neutral, positive, negative, or exaggerated. Return it as a JSON object with no further information.",
    "emotions_long": "Answer only the options provided: classify the emotion expressed by the person as: neutral, positive, negative, or exaggerated.",
    "personality_short": "Answer only with the options listed and no further information: the personality trait expressed by the person is: Openness, Conscientiousness, Extraversion, Agreeableness, or Neuroticism. Return it as a JSON object.",
    "personality_long": "Answer only with the options provided: classify the personality trait expressed by the person with one of the following options: Openness, Conscientiousness, Extraversion, Agreeableness, or Neuroticism.",
    #"img_prop": "Analyze the image and provide: it's dominant colors in hex code and RGB and it's pixel percentage. Return only the information requested as a JSON object.",
    "position_short": "Describe the posture of the person in the image with one word. Be very concise and precise in you answer. Return it as a JSON object with no further information.",
    "position_long": "Describe the posture of the person in the image. Be concise and precise in you answer.",
    "location": "Answer only the options provided: the image is taken indoors or outdoors. Return it as a JSON object.",    
    "objects": "List up to 10 objects visible in this image. Return it as a JSON object.",
    "objects_assist_devices": "List any assistive devices visible in the image. Return it as a JSON object as {\"assistive_devices\": [\"object1\", \"object2\", ...]}. If none are visible, return an empty JSON object.",   
    "objects_digi_devices": "List any digital devices visible in the image. Return it as a JSON object as {\"digital_devices\": [\"object1\", \"object2\", ...]}. If none are visible, return an empty JSON object."
}

# %%
def call_claude_sonnet(base64_string, prompt):
    prompt_config = {
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 500,
        "system": """You are a helpful visual assistant. Please analyze the following image and provide answers to these prompts. 
        Be concise and precise in your answers and provide only the information requested. Do not provide any additional information:""",
        "messages": [
            {
                "role": "user",
                "content": [
                    {
                        "type": "image",
                        "source": {
                            "type": "base64",
                            "media_type": "image/png",
                            "data": base64_string,
                        },
                    },
                    {"type": "text", 
                     "text": prompt},
                ],
            }
        ],
    }

    body = json.dumps(prompt_config)

    modelId = "anthropic.claude-3-5-sonnet-20240620-v1:0"
    accept = "application/json"
    contentType = "application/json"

    response = client.invoke_model(
        body=body, modelId=modelId, accept=accept, contentType=contentType)
    response_body = json.loads(response.get("body").read())

    results = response_body.get("content")[0].get("text")
    return results

def image_to_base64(image_path):
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"The file {image_path} does not exist.")
    
    try:
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')
    except IOError as e:
        raise IOError(f"Error reading the file {image_path}: {str(e)}")

def process_image(image_path):
    base64_string = image_to_base64(image_path)
    results = {"ID_jpg": os.path.basename(image_path)}
    
    for prompt_name, prompt_text in prompts.items():
        results[prompt_name] = call_claude_sonnet(base64_string, prompt_text)
    
    return results

def process_folder(folder_path):
    all_results = []
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    for image_file in tqdm(image_files, desc="Processing images"):
        image_path = os.path.join(folder_path, image_file)
        try:
            results = process_image(image_path)
            all_results.append(results)
        except Exception as e:
            print(f"Error processing {image_file}: {str(e)}")
    
    return pd.DataFrame(all_results)

# %%
#NEUTRAL
#folder_path_n = f'{output_folder}/NEUTRAL'
df_neutral_results = process_folder(output_folder_n)
df_neutral_results.to_csv(f'{output_folder_n}/neutral_sonnet_analysis.csv', index=False)
print(f"Results saved")
# Out:
# Processing images: 100%|██████████| 8/8 [05:03<00:00, 37.98s/it]
# Results saved

# %%
#OLDER
#folder_path_o = f'{output_folder}/OLDER'
df_older_results = process_folder(output_folder_o)
df_older_results.to_csv(f'{output_folder_o}/older_sonnet_analysis.csv', index=False)
print(f"Results saved")
# Out:
# Processing images: 100%|██████████| 8/8 [04:45<00:00, 35.72s/it]
# Results saved

# %%
df_neutral = pd.read_csv(f'{output_folder}/df_neutral.csv')
df_older = pd.read_csv(f'{output_folder}/df_older.csv')
df_merged = pd.concat([df_neutral, df_older], axis=0)   
df_merged.to_csv(f'{output_folder}/df_final_02_7_v2.csv', index=False)

# %% [markdown]
# # PIL BRIGHTNESS

# %%
def rgb_to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(int(rgb[0]), int(rgb[1]), int(rgb[2]))

def rgb_to_css(rgb):
    return f'rgb({int(rgb[0])}, {int(rgb[1])}, {int(rgb[2])})'

def simplify_color(rgb):
    color_names = {
        (0, 0, 0): "Negro", (255, 255, 255): "Blanco",
        (255, 0, 0): "Rojo", (0, 255, 0): "Verde", (0, 0, 255): "Azul",
        (255, 255, 0): "Amarillo", (255, 0, 255): "Magenta", (0, 255, 255): "Cian",
        (128, 128, 128): "Gris"
    }
    
    distances = {name: sum((a - b) ** 2 for a, b in zip(rgb, color_rgb))
                 for color_rgb, name in color_names.items()}
    return min(distances, key=distances.get)

def analizar_imagen(ruta_imagen, max_size=1000):
    try:
        with Image.open(ruta_imagen) as imagen:
            if max(imagen.size) > max_size:
                imagen.thumbnail((max_size, max_size))
            
            imagen_array = np.array(imagen)
        
        brillo_promedio = np.mean(imagen_array)
        
        contraste = np.std(imagen_array)
        
        if len(imagen_array.shape) == 3:  # Imagen a color
            pixels = imagen_array.reshape(-1, 3)
            color_dominante, conteo = stats.mode(pixels, axis=0)
            color_dominante = color_dominante.ravel()
            conteo = conteo.ravel()[0]  # Tomar el primer elemento del array de conteo
        else:  # Imagen en escala de grises
            color_dominante = np.array([brillo_promedio] * 3)
            conteo = imagen_array.size
        
        # Calcular el porcentaje de píxeles del color dominante
        total_pixels = imagen_array.size // 3 if len(imagen_array.shape) == 3 else imagen_array.size
        porcentaje_dominante = (conteo / total_pixels) * 100
        
        return {
            'ID_jpg': os.path.basename(ruta_imagen),
            'brillo_promedio': float(brillo_promedio),
            'contraste': float(contraste),
            'color_dominante': {
                'rgb': tuple(map(int, color_dominante)),
                'hex': rgb_to_hex(color_dominante),
                'css': rgb_to_css(color_dominante),
                'simplificado': simplify_color(tuple(map(int, color_dominante)))
            },
            'porcentaje_dominante': float(porcentaje_dominante)
        }
    except Exception as e:
        print(f"Error al procesar {os.path.basename(ruta_imagen)}: {str(e)}")
        return None

def analizar_carpeta(ruta_carpeta, limit=None):
    resultados = []
    archivos = [f for f in os.listdir(ruta_carpeta) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
    
    if limit:
        archivos = archivos[:limit]
    
    total = len(archivos)
    for i, archivo in enumerate(archivos, 1):
        ruta_completa = os.path.join(ruta_carpeta, archivo)
        resultado = analizar_imagen(ruta_completa)
        if resultado:
            resultados.append(resultado)
        print(f"Procesado {i}/{total}: {archivo}")
    
    return resultados

if __name__ == '__main__':
    resultados_n = analizar_carpeta(n_output_folder)
    resultados_o = analizar_carpeta(o_output_folder)
    
    for resultado_n in resultados_n:
        print(f"\nImagen: {resultado_n['ID_jpg']}")
        print(f"  Brillo promedio: {resultado_n['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_n['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_n['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_n['color_dominante']['hex']}")
        print(f"    CSS: {resultado_n['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_n['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_n['porcentaje_dominante']:.2f}%")

    for resultado_o in resultados_o:
        print(f"\nImagen: {resultado_o['ID_jpg']}")
        print(f"  Brillo promedio: {resultado_o['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_o['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_o['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_o['color_dominante']['hex']}")
        print(f"    CSS: {resultado_o['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_o['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_o['porcentaje_dominante']:.2f}%")
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_7608\4132544109.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   color_dominante, conteo = stats.mode(pixels, axis=0)
# Procesado 1/8: a_p1_f1.jpg
# Procesado 2/8: a_p1_f2.jpg
# Procesado 3/8: a_p1_f3.jpg
# Procesado 4/8: a_p1_f4.jpg
# Procesado 5/8: a_p2_f1.jpg
# Procesado 6/8: a_p2_f2.jpg
# Procesado 7/8: a_p2_f3.jpg
# Procesado 8/8: a_p2_f4.jpg
# Procesado 1/8: o_p1_f1.jpg
# Procesado 2/8: o_p1_f2.jpg
# Procesado 3/8: o_p1_f3.jpg
# Procesado 4/8: o_p1_f4.jpg
# Procesado 5/8: o_p2_f1.jpg
# Procesado 6/8: o_p2_f2.jpg
# Procesado 7/8: o_p2_f3.jpg
# Procesado 8/8: o_p2_f4.jpg
#
# Imagen: a_p1_f1.jpg
#   Brillo promedio: 95.75
#   Contraste: 70.89
#   Color dominante:
#     RGB: (19, 35, 32)
#     Hex: #132320
#     CSS: rgb(19, 35, 32)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.37%
#
# Imagen: a_p1_f2.jpg
#   Brillo promedio: 93.89
#   Contraste: 59.65
#   Color dominante:
#     RGB: (18, 20, 26)
#     Hex: #12141a
#     CSS: rgb(18, 20, 26)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.93%
#
# Imagen: a_p1_f3.jpg
#   Brillo promedio: 87.32
#   Contraste: 58.95
#   Color dominante:
#     RGB: (28, 29, 33)
#     Hex: #1c1d21
#     CSS: rgb(28, 29, 33)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.42%
#
# Imagen: a_p1_f4.jpg
#   Brillo promedio: 117.38
#   Contraste: 72.13
#   Color dominante:
#     RGB: (231, 206, 194)
#     Hex: #e7cec2
#     CSS: rgb(231, 206, 194)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 2.82%
#
# Imagen: a_p2_f1.jpg
#   Brillo promedio: 81.18
#   Contraste: 56.12
#   Color dominante:
#     RGB: (12, 20, 23)
#     Hex: #0c1417
#     CSS: rgb(12, 20, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.57%
#
# Imagen: a_p2_f2.jpg
#   Brillo promedio: 85.10
#   Contraste: 65.05
#   Color dominante:
#     RGB: (13, 19, 21)
#     Hex: #0d1315
#     CSS: rgb(13, 19, 21)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.28%
#
# Imagen: a_p2_f3.jpg
#   Brillo promedio: 91.23
#   Contraste: 62.50
#   Color dominante:
#     RGB: (19, 20, 22)
#     Hex: #131416
#     CSS: rgb(19, 20, 22)
#     Simplificado: Negro
#   Porcentaje del color dominante: 3.25%
#
# Imagen: a_p2_f4.jpg
#   Brillo promedio: 116.40
#   Contraste: 61.49
#   Color dominante:
#     RGB: (137, 111, 29)
#     Hex: #896f1d
#     CSS: rgb(137, 111, 29)
#     Simplificado: Gris
#   Porcentaje del color dominante: 1.34%
#
# Imagen: o_p1_f1.jpg
#   Brillo promedio: 110.49
#   Contraste: 71.83
#   Color dominante:
#     RGB: (17, 22, 23)
#     Hex: #111617
#     CSS: rgb(17, 22, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.94%
#
# Imagen: o_p1_f2.jpg
#   Brillo promedio: 111.24
#   Contraste: 62.63
#   Color dominante:
#     RGB: (10, 18, 23)
#     Hex: #0a1217
#     CSS: rgb(10, 18, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.43%
#
# Imagen: o_p1_f3.jpg
#   Brillo promedio: 103.75
#   Contraste: 73.88
#   Color dominante:
#     RGB: (19, 21, 25)
#     Hex: #131519
#     CSS: rgb(19, 21, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.56%
#
# Imagen: o_p1_f4.jpg
#   Brillo promedio: 104.69
#   Contraste: 68.63
#   Color dominante:
#     RGB: (15, 14, 16)
#     Hex: #0f0e10
#     CSS: rgb(15, 14, 16)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.64%
#
# Imagen: o_p2_f1.jpg
#   Brillo promedio: 97.30
#   Contraste: 69.33
#   Color dominante:
#     RGB: (15, 17, 24)
#     Hex: #0f1118
#     CSS: rgb(15, 17, 24)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.61%
#
# Imagen: o_p2_f2.jpg
#   Brillo promedio: 109.19
#   Contraste: 69.94
#   Color dominante:
#     RGB: (56, 35, 27)
#     Hex: #38231b
#     CSS: rgb(56, 35, 27)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.92%
#
# Imagen: o_p2_f3.jpg
#   Brillo promedio: 88.11
#   Contraste: 63.21
#   Color dominante:
#     RGB: (25, 25, 25)
#     Hex: #191919
#     CSS: rgb(25, 25, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.44%
#
# Imagen: o_p2_f4.jpg
#   Brillo promedio: 101.19
#   Contraste: 76.37
#   Color dominante:
#     RGB: (20, 18, 19)
#     Hex: #141213
#     CSS: rgb(20, 18, 19)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.83%

# %%
pil_n = pd.DataFrame(resultados_n)
pil_o = pd.DataFrame(resultados_o)
pil = pd.concat([pil_n, pil_o], axis=0)   
df_merged = df_merged.merge(pil, left_on='ID_jpg', right_on='ID_jpg', how='left')
