# %% [markdown]
# # SETUP

# %%
import os
import re
import ast
import json
import ollama
import random
import base64
import requests
import itertools
import numpy as np
import pandas as pd
from tqdm import tqdm
from PIL import Image
from scipy import stats
from itertools import product
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# # DF

# %%
folder_path = r'\05_08_copilot_activities'

description_list = []

prompt_pattern = re.compile(r'(.*?)(?= --personalize| --style|$)', re.DOTALL)

for file_name in os.listdir(folder_path):
    if file_name.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.tiff')):
        file_path = os.path.join(folder_path, file_name)
        
        image = Image.open(file_path)
        
        info = image.info
        
        description = info.get('Description', None)
        
        if description:
            match = prompt_pattern.match(description)
            cleaned_description = match.group(1) if match else description
        else:
            cleaned_description = None
        
        description_list.append({'filename': file_name, 'prompt': cleaned_description})

df = pd.DataFrame(description_list, columns=['filename', 'prompt'])

def clean_filename(filename):
    cleaned = re.sub(r'\d+', '', filename)
    cleaned = cleaned.replace('.jpeg', '').strip()
    return cleaned

df['prompt'] = df['filename'].apply(clean_filename)
df['codi'] = df['filename'].str.extract(r'(\d{2,3})')
df['age_group'] = df['prompt'].apply(lambda x: 'older' if 'older' in x else 'neutral')

df['ID_num'] = df['codi'].str.extract('(\d+)')
df['ID_num'] = pd.to_numeric(df['ID_num'])
df=df.sort_values(by='ID_num', ascending=True)

df = df.reset_index(drop=True)

df_older = df[df['age_group'] == 'older']
df_neutral = df[df['age_group'] == 'neutral']

df_older['ID'] = ''
for prompt in df_older['ID_num'].unique():
    df_subset = df_older[df_older['ID_num'] == prompt]
    count = 1
    for index, row in df_subset.iterrows():
        df_older.loc[index, 'ID'] = f'o_p{row["ID_num"]}_f{count}'
        count += 1

df_neutral['ID'] = ''
for prompt in df_neutral['ID_num'].unique():
    df_subset = df_neutral[df_neutral['ID_num'] == prompt]
    count = 1
    for index, row in df_subset.iterrows():
        df_neutral.loc[index, 'ID'] = f'a_p{row["ID_num"]}_f{count}'
        count += 1

# %%
df
# Out:
#                                     filename                          prompt  \
# 0     01 walking to the bathroom older1.jpeg   walking to the bathroom older
# 1     01 walking to the bathroom older2.jpeg   walking to the bathroom older
# 2    01 walking to the bathroom person1.jpeg  walking to the bathroom person
# 3       03 moving between rooms person1.jpeg     moving between rooms person
# 4          03 walking to a room person1.jpeg        walking to a room person
# ..                                       ...                             ...
# 769          137 home monitoring older4.jpeg           home monitoring older
# 770          137 home monitoring older3.jpeg           home monitoring older
# 771          137 home monitoring older2.jpeg           home monitoring older
# 772          137 home monitoring older1.jpeg           home monitoring older
# 773         137 home monitoring person4.jpeg          home monitoring person
#
#     codi age_group  ID_num
# 0     01     older       1
# 1     01     older       1
# 2     01   neutral       1
# 3     03   neutral       3
# 4     03   neutral       3
# ..   ...       ...     ...
# 769  137     older     137
# 770  137     older     137
# 771  137     older     137
# 772  137     older     137
# 773  137   neutral     137
#
# [774 rows x 5 columns]

# %%
output_dir = "C:/Users/David/Documents/AGEAI/Scripts/OUTPUTS/ANDREA/05_08_copilot_activities/CSV"

os.makedirs(output_dir, exist_ok=True)
df_older.to_csv(os.path.join(output_dir, "df_older.csv"), index=False)
df_neutral.to_csv(os.path.join(output_dir, "df_neutral.csv"), index=False)

# %%
# Comprimir imagenes / AQUI NO CAL
def reduce_image_size(image, max_width, max_height):
    width, height = image.size
    if width > max_width or height > max_height:
        image.thumbnail((max_width, max_height), Image.LANCZOS)
    return image

def process_images(input_folder, neutral_df, older_df, neutral_subfolder, older_subfolder):
    neutral_output_folder = os.path.join(input_folder, neutral_subfolder)
    older_output_folder = os.path.join(input_folder, older_subfolder)
    
    if not os.path.exists(neutral_output_folder):
        os.makedirs(neutral_output_folder)
    if not os.path.exists(older_output_folder):
        os.makedirs(older_output_folder)
    
    neutral_files = neutral_df['filename'].tolist()
    older_files = older_df['filename'].tolist()
    
    for filename in os.listdir(input_folder):
        if filename.endswith('.png'):
            input_path = os.path.join(input_folder, filename)
            
            if filename in neutral_files:
                output_folder = neutral_output_folder
            elif filename in older_files:
                output_folder = older_output_folder
            else:
                print(f"Archivo no clasificado: {filename}")
                continue
            
            output_path = os.path.join(output_folder, os.path.splitext(filename)[0] + '.jpg')

            try:
                with Image.open(input_path) as img:
                    img = reduce_image_size(img, 1024, 1024)
                    img = img.convert('RGB')
                    img.save(output_path, 'JPEG', optimize=True, quality=85)
            except Exception as e:
                print(f"Error procesando {filename}: {e}")

    print("Proceso completado.")

input_folder = folder_path
neutral_subfolder = 'neutral_comp'
older_subfolder = 'older_comp'

process_images(input_folder, df_neutral, df_older, neutral_subfolder, older_subfolder)

# %%
import os
import shutil

source_folder = "05_08_copilot_activities
destination_base_folder = source_folder

os.makedirs(os.path.join(destination_base_folder, 'older'), exist_ok=True)
os.makedirs(os.path.join(destination_base_folder, 'neutral'), exist_ok=True)

for index, row in df.iterrows():
    source_file = os.path.join(source_folder, row['filename'])
    
    destination_folder = os.path.join(destination_base_folder, row['age_group'])
    
    destination_file = os.path.join(destination_folder, row['filename'])
    
    if os.path.exists(source_file):
        shutil.copy(source_file, destination_file)
        print(f"Copiado: {source_file} a {destination_file}")
    else:
        print(f"No encontrado: {source_file}")

# %% [markdown]
# # OLLAMA

# %%
prompts = {
    "gender": "Answer only with the options provided: the gender of the person is: male, female, or if it's not possible to determine, none. Return answer as a JSON object {\"gender\": [\"gender\"]}.",
    "age_range": "Estimate the age range of the person in the image. Just answer with the following range of numbers: 18-24, 25-34, 35-44, 45-54, 55-64, 65-79 or 80+. Return answer only as a JSON object {\"age\": [\"range\"]}.",
    "race": "Estimate the race of the person in this image. Just answer with the following options: asian, black, white, hispanic, or other. Return answer only as a JSON object {\"race\": [\"race\"]}",
    "emotions_short": "Answer only with the options provided: the emotion expressed by the person is: neutral, positive, negative, or exaggerated. Return it as a JSON object {\"emotion\": [\"emotion\"]}",
    "personality_short": "Answer only with the options listed and no further information: the personality trait expressed by the person is: Openness, Conscientiousness, Extraversion, Agreeableness, or Neuroticism. Return it as a JSON object {\"personality\": [\"personality\"]}.",
    "location": "Answer only the options provided: The image is taken indoors, outdoors, or not possible to identify. Return it as a JSON object {\"location\": [\"location\"]} .",    
    "objects": "List up to 10 objects visible in this image. Return it as a JSON object as {\"objects\": [\"object\",...]}",
    "objects_assist_devices": "List any assistive devices visible in the image. Return it as a JSON object as {\"assistive_devices\": [\"object\",...]}",
    "objects_digi_devices": "List any digital devices visible in the image. Return it as a JSON object as {\"digital_devices\": [\"object\",...]}.",
    "person_count": "Answer only with the options provided: how many people can you count: 1, 2 or 3 or +3. Return answer as a JSON object {\"person_count\": [\"count\"]}.",
    "shot": "Answer only with the options provided: the type of shot in the image is: close-up shot, medium shot, or full shot. Return answer as a JSON object {\"shot\": [\"shot\"]}.",
    "position_short": "Describe the posture of the person in the image with one word. Be very concise and precise in you answer (standing, sitting, lying, etc.). Return answer as a JSON object {\"position\": [\"position\"]}.",
}

# %%
def call_ollama(image_path, prompt):
    try:
        with open(image_path, 'rb') as file:
            image_bytes = file.read()
        
        response = ollama.chat(
            model='llava',
            messages=[
                {
                    'role': 'user',
                    'content': prompt,
                    'images': [image_bytes],
                },
            ],
        )
        return response['message']['content']
    except Exception as e:
        print(f"Error calling Ollama: {e}")
        return "Error"

def process_image(image_path):
    try:
        results = {"ID_jpg": os.path.basename(image_path)}
        
        for prompt_name, prompt_text in prompts.items():
            results[prompt_name] = call_ollama(image_path, prompt_text)
        
        return results
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return {"ID_jpg": os.path.basename(image_path), "error": str(e)}

def process_folder(folder_path):
    all_results = []
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    for image_file in tqdm(image_files, desc="Processing images"):
        image_path = os.path.join(folder_path, image_file)
        results = process_image(image_path)
        all_results.append(results)
    
    return pd.DataFrame(all_results)

# %%
#NEUTRAL
df_neutral_results = process_folder("05_08_copilot_activities/neutral")
df_neutral_results.to_csv("05_08_copilot_activities/neutral/neutral_analysis_llava.csv", index=False)
print(f"Results saved")
# Out:
# Results saved

# %%
#OLDER
df_older_results = process_folder("05_08_copilot_activities/older")
df_older_results.to_csv("05_08_copilot_activities/older/older_analysis_llava.csv", index=False)
print(f"Results saved")
# Out:
# Processing images: 100%|██████████| 379/379 [59:46<00:00,  9.46s/it]
# Results saved

# %% [markdown]
# # MERGE FINAL

# %%
df_neutral = pd.read_csv(f'{output_dir}/df_neutral.csv')
df_older = pd.read_csv(f'{output_dir}/df_older.csv')
df_merged = pd.concat([df_neutral, df_older], axis=0)
df_neutral_cv = pd.read_csv(f'{output_dir}/neutral_analysis_llava.csv')
df_older_cv = pd.read_csv(f'{output_dir}/older_analysis_llava.csv')
df_merged_2 = pd.concat([df_neutral_cv, df_older_cv], axis=0)

df_merged_2 = df_merged_2.rename(columns={'ID_jpg': 'filename'})   

df_merged = pd.merge(df_merged, df_merged_2, on='filename', how='left')

# %%
def clean_json(text):
    if isinstance(text, str):
        cleaned_text = re.sub(r'```json', '', text)  
        cleaned_text = re.sub(r'```', '', cleaned_text)  
        
        cleaned_text = re.sub(r'\{\s+', '{', cleaned_text)
        cleaned_text = re.sub(r'\s+\}', '}', cleaned_text)
        
        cleaned_text = cleaned_text.replace('\n', '').strip()
        
        return cleaned_text
    return text

def ensure_list_format(value):
    if isinstance(value, str):
        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict):
                for key in data:
                    if not isinstance(data[key], list):
                        data[key] = [data[key]]
                return str(data)
            return value
        except:
            return value
    return value

columns_to_transform = [
    'gender', 
    'age_range', 
    'race', 
    'emotions_short', 
    'location', 
    'personality_short', 
    'shot', 
    'position_short',
    'objects',
    'objects_assist_devices',
    'objects_digi_devices',
    'person_count'
]

for column in df_merged.columns:
    if column not in ['filename_png', 'filename_jpg']:
        df_merged[column] = df_merged[column].apply(clean_json)
        df_merged[column] = df_merged[column].apply(lambda x: x.lower() if isinstance(x, str) else x)
        df_merged[column] = df_merged[column].apply(ensure_list_format)

# %%
df_merged
# Out:
#                                     filename                          prompt  \
# 0    01 walking to the bathroom person1.jpeg  walking to the bathroom person
# 1       03 moving between rooms person1.jpeg     moving between rooms person
# 2          03 walking to a room person1.jpeg        walking to a room person
# 3          03 walking to a room person2.jpeg        walking to a room person
# 4         04 walking to a store person1.jpeg       walking to a store person
# ..                                       ...                             ...
# 769          136 at the hospital older1.jpeg           at the hospital older
# 770          137 home monitoring older4.jpeg           home monitoring older
# 771          137 home monitoring older3.jpeg           home monitoring older
# 772          137 home monitoring older2.jpeg           home monitoring older
# 773          137 home monitoring older1.jpeg           home monitoring older
#
#      codi age_group  ID_num         ID                  gender  \
# 0       1   neutral       1    a_p1_f1  {'gender': ['female']}
# 1       3   neutral       3    a_p3_f1  {'gender': ['female']}
# 2       3   neutral       3    a_p3_f2  {'gender': ['female']}
# 3       3   neutral       3    a_p3_f3    {'gender': ['male']}
# 4       4   neutral       4    a_p4_f1    {'gender': ['male']}
# ..    ...       ...     ...        ...                     ...
# 769   136     older     136  o_p136_f4  {'gender': ['female']}
# 770   137     older     137  o_p137_f1  {'gender': ['female']}
# 771   137     older     137  o_p137_f2  {'gender': ['female']}
# 772   137     older     137  o_p137_f3  {'gender': ['female']}
# 773   137     older     137  o_p137_f4    {'gender': ['male']}
#
#               age_range                 race             emotions_short  \
# 0    {'age': ['35-44']}  {'race': ['asian']}  {'emotion': ['positive']}
# 1    {'age': ['65-79']}  {'race': ['white']}   {'emotion': ['neutral']}
# 2    {'age': ['25-34']}  {'race': ['white']}  {'emotion': ['positive']}
# 3    {'age': ['25-34']}  {'race': ['asian']}  {'emotion': ['positive']}
# 4    {'age': ['35-44']}  {'race': ['black']}   {'emotion': ['neutral']}
# ..                  ...                  ...                        ...
# 769  {'age': ['65-79']}  {'race': ['asian']}   {'emotion': ['neutral']}
# 770  {'age': ['65-79']}  {'race': ['white']}   {'emotion': ['neutral']}
# 771  {'age': ['55-64']}  {'race': ['white']}   {'emotion': ['neutral']}
# 772  {'age': ['65-79']}  {'race': ['white']}   {'emotion': ['neutral']}
# 773  {'age': ['45-54']}  {'race': ['asian']}   {'emotion': ['neutral']}
#
#                       personality_short                    location  \
# 0      {'personality': ['neuroticism']}    {'location': ['indoor']}
# 1    {'personality': ['agreeableness']}    {'location': ['indoor']}
# 2         {'personality': ['openness']}  {'location': ['outdoors']}
# 3         {'personality': ['openness']}    {'location': ['indoor']}
# 4         {'personality': ['openness']}    {'location': ['indoor']}
# ..                                  ...                         ...
# 769       {'personality': ['openness']}    {'location': ['indoor']}
# 770  {'personality': ['agreeableness']}    {'location': ['indoor']}
# 771    {'personality': ['neuroticism']}    {'location': ['indoor']}
# 772       {'personality': ['openness']}   {'location': ['indoors']}
# 773  {'personality': ['agreeableness']}   {'location': ['indoors']}
#
#                                                objects  \
# 0    {'objects': ['person', 'mug', 'newspaper', 'si...
# 1    {'objects': ['person', 'table', 'cup', 'tea po...
# 2    {'objects': ['woman', 'cat', 'backpack', 'door...
# 3    {'objects': ['person', 'coffee table', 'booksh...
# 4    {'objects': ['person with backpack and yellow ...
# ..                                                 ...
# 769  {'objects': ['person sitting in bed', "book in...
# 770  {'objects': ['older woman sitting in a chair',...
# 771  {'objects': ['woman sitting on couch', 'coffee...
# 772  {'objects': ['person', 'tablet robot', 'coffee...
# 773  {'objects': ['tablet', 'tea cup', 'smart robot...
#
#                                 objects_assist_devices  \
# 0                 {'assistive_devices': ['newspaper']}
# 1                      {'assistive_devices': ['cane']}
# 2                            {'assistive_devices': []}
# 3                      {'assistive_devices': ['none']}
# 4                            {'assistive_devices': []}
# ..                                                 ...
# 769              {'assistive_devices': ['eyeglasses']}
# 770  {'assistive_devices': ['tablet with a heart on...
# 771                   {'assistive_devices': ['robot']}
# 772                   {'assistive_devices': ['robot']}
# 773                   {'assistive_devices': ['robot']}
#
#                                   objects_digi_devices  \
# 0                              {'digital_devices': []}
# 1                        {'digital_devices': ['none']}
# 2                  {'digital_devices': ['cell phone']}
# 3                              {'digital_devices': []}
# 4                       {'digital_devices': ['phone']}
# ..                                                 ...
# 769                      {'digital_devices': ['book']}
# 770           {'digital_devices': ['tablet', 'robot']}
# 771             {'digital_devices': ['book', 'robot']}
# 772  {'digital_devices': [{'type': 'robot', 'image'...
# 773                    {'digital_devices': ['tablet']}
#
#                 person_count                         shot  \
# 0    {'person_count': ['1']}  {'shot': ['close-up shot']}
# 1    {'person_count': ['1']}      {'shot': ['full shot']}
# 2    {'person_count': ['1']}    {'shot': ['medium shot']}
# 3    {'person_count': ['1']}    {'shot': ['medium shot']}
# 4    {'person_count': ['2']}    {'shot': ['medium shot']}
# ..                       ...                          ...
# 769  {'person_count': ['1']}  {'shot': ['close-up shot']}
# 770  {'person_count': ['1']}  {'shot': ['close-up shot']}
# 771  {'person_count': ['2']}      {'shot': ['full shot']}
# 772  {'person_count': ['1']}  {'shot': ['close-up shot']}
# 773  {'person_count': ['2']}      {'shot': ['full shot']}
#
#                  position_short
# 0    {'position': ['standing']}
# 1    {'position': ['standing']}
# 2    {'position': ['standing']}
# 3    {'position': ['standing']}
# 4    {'position': ['standing']}
# ..                          ...
# 769     {'position': ['lying']}
# 770   {'position': ['sitting']}
# 771   {'position': ['sitting']}
# 772   {'position': ['sitting']}
# 773   {'position': ['sitting']}
#
# [774 rows x 18 columns]

# %%
mapping = {
    #'{"location": ["indoor"]}': '{"location": ["indoors"]}',
    "{'location': ['indoor']}": "{'location': ['indoors']}",
    #'{"location": "indoors"}': '{"location": ["indoors"]}',
    #'{"location": "indoor"}': '{"location": ["indoors"]}',
    "{'location': ['indors']}": "{'location': ['indoors']}",
    "{'location': ['inddoors']}": "{'location': ['indoors']}",  
    "{'location': ['individual']}": "{'location': ['indoors']}",  
    "{'location': ['indicators']}": "{'location': ['indoors']}",  
}
df_merged['location'] = df_merged['location'].map(mapping).fillna(df_merged['location'])
df_merged['location'].unique()

mapping = {
    #'{"shot": "close-up shot"}': '{"shot": ["close-up shot"]}',
    #'{"shot": "full shot"}': '{"shot": ["full shot"]}',
    "{'shot': ['medium']}": "{'shot': ['medium shot']}",
    #'{"shot": ["medium"]}': '{"shot": ["medium shot"]}',
    #'{"shot": "medium shot"}': '{"shot": ["medium shot"]}',
    "{'shot': ['close-up']}": "{'shot': ['close-up shot']}",
}
df_merged['shot'] = df_merged['shot'].map(mapping).fillna(df_merged['shot'])
df_merged['shot'].unique()

#PERSON COUNT
def normalize_person_count(value):
    value = value.strip(".")
    
    value = re.sub(r'["]', "'", value)  
    value = re.sub(r"''", "'", value)   
    
    numbers = re.findall(r"'(\d+)'", value)
    if not numbers: 
        numbers = re.findall(r"(\d+)", value)
    
    if numbers:
        numbers = list(map(int, numbers))
        if any(num >= 3 for num in numbers):
            return "{'person_count': ['+3']}"
        else:
            return "{'person_count': ['" + "', '".join(map(str, numbers)) + "']}"
    else:
        return value

df_merged['person_count'] = df_merged['person_count'].apply(normalize_person_count)

mapping = {
    "{'person_count': [1]}": "{'person_count': ['1']}",
    "{'person_count': [2]}": "{'person_count': ['2']}",
    "{'person_count': [3]}": "{'person_count': ['3']}",
    "{'person_count': [''1'']}": "{'person_count': ['1']}",
    "{'person_count': [''2'']}": "{'person_count': ['2']}",
    "{'person_count': [1]}": "{'person_count': ['1']}",
    "{'person_count': [7]}": "{'person_count': ['+3']}",
    "{'person_count': ['1', '2']}": "{'person_count': ['+3']}",
}
df_merged['person_count'] = df_merged['person_count'].map(mapping).fillna(df_merged['person_count'])
df_merged['person_count'].unique()

# %%
def ensure_list(value):
    if isinstance(value, str):
        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict):
                return list(data.values())[0] if isinstance(list(data.values())[0], list) else [list(data.values())[0]]
            elif isinstance(data, list):
                return data
        except:
            return [value]  
    return value if isinstance(value, list) else [value]  

def is_list(value):
    return isinstance(value, list)

columns_to_transform = [
    'gender',
    'age_range',
    'race', 
    'emotions_short', 
    'location', 
    'personality_short', 
    'shot', 
    'position_short',
    'objects',
    'objects_assist_devices',
    'objects_digi_devices',
    'person_count',
    'shot'
]

for column in columns_to_transform:
    df_merged[column] = df_merged[column].apply(ensure_list)

for column in columns_to_transform:
    if df_merged[column].apply(is_list).all():
        print(f"Todos los valores en la columna '{column}' son listas de Python.")
    else:
        print(f"Algunos valores en la columna '{column}' NO son listas de Python.")

def convert_assist_devices(value):
    if isinstance(value, list) or isinstance(value, str):
        if isinstance(value, list):
            value = str(value)

        if 'assistive_devices' in value:
            return ['none']
        
        if isinstance(value, str) and not value.strip():
            return ['none']

        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict) and 'assistive_devices' in data:
                return ['none']
        except (ValueError, SyntaxError):
            pass

    if isinstance(value, list) and not value:
        return ['none']
    return value

df_merged['objects_assist_devices'] = df_merged['objects_assist_devices'].apply(convert_assist_devices)

def convert_digi_devices(value):
    if isinstance(value, list) or isinstance(value, str):
        if isinstance(value, list):
            value = str(value)

        if 'digital_devices' in value:
            return ['none']
        
        if isinstance(value, str) and not value.strip():
            return ['none']

        try:
            data = ast.literal_eval(value)
            if isinstance(data, dict) and 'digital_devices' in data:
                return ['none']
        except (ValueError, SyntaxError):
            pass

    if isinstance(value, list) and not value:
        return ['none']
    return value

df_merged['objects_digi_devices'] = df_merged['objects_digi_devices'].apply(convert_digi_devices)

def categorize_person_count(value):
    if isinstance(value, str):
        try:
            value = ast.literal_eval(value)
        except:
            return value
    
    if isinstance(value, list):
        if any(int(num) >= 3 for num in value):
            return ['+3']
        else:
            return [str(value[0])] 
    else:
        return value

df_merged['person_count'] = df_merged['person_count'].apply(categorize_person_count)
# Out:
# Todos los valores en la columna 'gender' son listas de Python.
# Todos los valores en la columna 'age_range' son listas de Python.
# Todos los valores en la columna 'race' son listas de Python.
# Todos los valores en la columna 'emotions_short' son listas de Python.
# Todos los valores en la columna 'location' son listas de Python.
# Todos los valores en la columna 'personality_short' son listas de Python.
# Todos los valores en la columna 'shot' son listas de Python.
# Todos los valores en la columna 'position_short' son listas de Python.
# Todos los valores en la columna 'objects' son listas de Python.
# Todos los valores en la columna 'objects_assist_devices' son listas de Python.
# Todos los valores en la columna 'objects_digi_devices' son listas de Python.
# Todos los valores en la columna 'person_count' son listas de Python.
# Todos los valores en la columna 'shot' son listas de Python.

# %% [markdown]
# # PIL BRIGHTNESS

# %%
def rgb_to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(int(rgb[0]), int(rgb[1]), int(rgb[2]))

def rgb_to_css(rgb):
    return f'rgb({int(rgb[0])}, {int(rgb[1])}, {int(rgb[2])})'

def simplify_color(rgb):
    color_names = {
        (0, 0, 0): "Negro", (255, 255, 255): "Blanco",
        (255, 0, 0): "Rojo", (0, 255, 0): "Verde", (0, 0, 255): "Azul",
        (255, 255, 0): "Amarillo", (255, 0, 255): "Magenta", (0, 255, 255): "Cian",
        (128, 128, 128): "Gris"
    }
    
    distances = {name: sum((a - b) ** 2 for a, b in zip(rgb, color_rgb))
                 for color_rgb, name in color_names.items()}
    return min(distances, key=distances.get)

def analizar_imagen(ruta_imagen, max_size=1000):
    try:
        with Image.open(ruta_imagen) as imagen:
            if max(imagen.size) > max_size:
                imagen.thumbnail((max_size, max_size))
            
            imagen_array = np.array(imagen)
        
        brillo_promedio = np.mean(imagen_array)
        
        contraste = np.std(imagen_array)
        
        if len(imagen_array.shape) == 3:  
            pixels = imagen_array.reshape(-1, 3)
            color_dominante, conteo = stats.mode(pixels, axis=0)
            color_dominante = color_dominante.ravel()
            conteo = conteo.ravel()[0]  
        else:  
            color_dominante = np.array([brillo_promedio] * 3)
            conteo = imagen_array.size
        
        total_pixels = imagen_array.size // 3 if len(imagen_array.shape) == 3 else imagen_array.size
        porcentaje_dominante = (conteo / total_pixels) * 100
        
        return {
            'filename': os.path.basename(ruta_imagen),
            'brillo_promedio': float(brillo_promedio),
            'contraste': float(contraste),
            'color_dominante': {
                'rgb': tuple(map(int, color_dominante)),
                'hex': rgb_to_hex(color_dominante),
                'css': rgb_to_css(color_dominante),
                'simplificado': simplify_color(tuple(map(int, color_dominante)))
            },
            'porcentaje_dominante': float(porcentaje_dominante)
        }
    except Exception as e:
        print(f"Error al procesar {os.path.basename(ruta_imagen)}: {str(e)}")
        return None

def analizar_carpeta(ruta_carpeta, limit=None):
    resultados = []
    archivos = [f for f in os.listdir(ruta_carpeta) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
    
    if limit:
        archivos = archivos[:limit]
    
    total = len(archivos)
    for i, archivo in enumerate(archivos, 1):
        ruta_completa = os.path.join(ruta_carpeta, archivo)
        resultado = analizar_imagen(ruta_completa)
        if resultado:
            resultados.append(resultado)
        print(f"Procesado {i}/{total}: {archivo}")
    
    return resultados

if __name__ == '__main__':
    resultados_n = analizar_carpeta("05_08_copilot_activities/neutral")
    resultados_o = analizar_carpeta("05_08_copilot_activities/older")
    
    for resultado_n in resultados_n:
        print(f"\nImagen: {resultado_n['filename']}")
        print(f"  Brillo promedio: {resultado_n['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_n['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_n['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_n['color_dominante']['hex']}")
        print(f"    CSS: {resultado_n['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_n['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_n['porcentaje_dominante']:.2f}%")

    for resultado_o in resultados_o:
        print(f"\nImagen: {resultado_o['filename']}")
        print(f"  Brillo promedio: {resultado_o['brillo_promedio']:.2f}")
        print(f"  Contraste: {resultado_o['contraste']:.2f}")
        print(f"  Color dominante:")
        print(f"    RGB: {resultado_o['color_dominante']['rgb']}")
        print(f"    Hex: {resultado_o['color_dominante']['hex']}")
        print(f"    CSS: {resultado_o['color_dominante']['css']}")
        print(f"    Simplificado: {resultado_o['color_dominante']['simplificado']}")
        print(f"  Porcentaje del color dominante: {resultado_o['porcentaje_dominante']:.2f}%")
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_16716\1780155287.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# Procesado 360/379: 90 attending a conference older1.jpeg
# Procesado 361/379: 90 attending a conference older2.jpeg
# Procesado 362/379: 90 attending a conference older3.jpeg
# Procesado 363/379: 90 attending a conference older4.jpeg
# Procesado 364/379: 91 in a study group older1.jpeg
# Procesado 365/379: 91 in a study group older2.jpeg
# Procesado 366/379: 91 in a study group older3.jpeg
# Procesado 367/379: 91 in a study group older4.jpeg
# Procesado 368/379: 92 in a football match older1.jpeg
# Procesado 369/379: 92 in a football match older2.jpeg
# Procesado 370/379: 92 in a football match older3.jpeg
# Procesado 371/379: 92 in a football match older4.jpeg
# Procesado 372/379: 93 praying older1.jpeg
# Procesado 373/379: 93 praying older2.jpeg
# Procesado 374/379: 93 praying older3.jpeg
# Procesado 375/379: 93 praying older4.jpeg
# Procesado 376/379: 94 attending religious services older1.jpeg
# Procesado 377/379: 94 attending religious services older2.jpeg
# Procesado 378/379: 94 attending religious services older3.jpeg
# Procesado 379/379: 94 attending religious services older4.jpeg
#
# Imagen: 01 walking to the bathroom person1.jpeg
#   Brillo promedio: 107.68
#   Contraste: 66.58
#   Color dominante:
#     RGB: (82, 4, 12)
#     Hex: #52040c
#     CSS: rgb(82, 4, 12)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.88%
#
# Imagen: 03 moving between rooms person1.jpeg
#   Brillo promedio: 104.20
#   Contraste: 63.06
#   Color dominante:
#     RGB: (47, 55, 53)
#     Hex: #2f3735
#     CSS: rgb(47, 55, 53)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.07%
#
# Imagen: 03 walking to a room person1.jpeg
#   Brillo promedio: 120.43
#   Contraste: 70.12
#   Color dominante:
#     RGB: (251, 41, 41)
#     Hex: #fb2929
#     CSS: rgb(251, 41, 41)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 1.75%
#
# Imagen: 03 walking to a room person2.jpeg
#   Brillo promedio: 141.89
#   Contraste: 60.74
#   Color dominante:
#     RGB: (203, 253, 50)
#     Hex: #cbfd32
#     CSS: rgb(203, 253, 50)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.78%
#
# Imagen: 04 strolling in the neighborhood person1.jpeg
#   Brillo promedio: 143.49
#   Contraste: 65.55
#   Color dominante:
#     RGB: (237, 210, 66)
#     Hex: #edd242
#     CSS: rgb(237, 210, 66)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.75%
#
# Imagen: 04 strolling in the neighborhood person2.jpeg
#   Brillo promedio: 132.53
#   Contraste: 68.08
#   Color dominante:
#     RGB: (184, 238, 31)
#     Hex: #b8ee1f
#     CSS: rgb(184, 238, 31)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.72%
#
# Imagen: 04 walking to a store person1.jpeg
#   Brillo promedio: 107.89
#   Contraste: 60.93
#   Color dominante:
#     RGB: (64, 87, 40)
#     Hex: #405728
#     CSS: rgb(64, 87, 40)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.06%
#
# Imagen: 04 walking to a store person3.jpeg
#   Brillo promedio: 136.59
#   Contraste: 68.38
#   Color dominante:
#     RGB: (255, 39, 40)
#     Hex: #ff2728
#     CSS: rgb(255, 39, 40)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 1.38%
#
# Imagen: 05 climbing stairs person1.jpeg
#   Brillo promedio: 103.41
#   Contraste: 69.67
#   Color dominante:
#     RGB: (26, 29, 36)
#     Hex: #1a1d24
#     CSS: rgb(26, 29, 36)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.85%
#
# Imagen: 05 climbing stairs person2.jpeg
#   Brillo promedio: 120.96
#   Contraste: 66.68
#   Color dominante:
#     RGB: (251, 56, 61)
#     Hex: #fb383d
#     CSS: rgb(251, 56, 61)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 1.21%
#
# Imagen: 06 walking in the metro person1.jpeg
#   Brillo promedio: 89.82
#   Contraste: 60.97
#   Color dominante:
#     RGB: (23, 28, 34)
#     Hex: #171c22
#     CSS: rgb(23, 28, 34)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.85%
#
# Imagen: 06 walking in the metro person2.jpeg
#   Brillo promedio: 83.94
#   Contraste: 62.92
#   Color dominante:
#     RGB: (17, 21, 23)
#     Hex: #111517
#     CSS: rgb(17, 21, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.22%
#
# Imagen: 07 cooking person1.jpeg
#   Brillo promedio: 105.92
#   Contraste: 63.40
#   Color dominante:
#     RGB: (34, 36, 38)
#     Hex: #222426
#     CSS: rgb(34, 36, 38)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.74%
#
# Imagen: 07 cooking person2.jpeg
#   Brillo promedio: 135.18
#   Contraste: 61.09
#   Color dominante:
#     RGB: (186, 187, 181)
#     Hex: #babbb5
#     CSS: rgb(186, 187, 181)
#     Simplificado: Gris
#   Porcentaje del color dominante: 1.19%
#
# Imagen: 07 cooking person3.jpeg
#   Brillo promedio: 154.05
#   Contraste: 63.08
#   Color dominante:
#     RGB: (252, 253, 253)
#     Hex: #fcfdfd
#     CSS: rgb(252, 253, 253)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 1.54%
#
# Imagen: 07 cooking person4.jpeg
#   Brillo promedio: 127.57
#   Contraste: 67.02
#   Color dominante:
#     RGB: (27, 26, 31)
#     Hex: #1b1a1f
#     CSS: rgb(27, 26, 31)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.09%
#
# Imagen: 08 dining at a restaurant person1.jpeg
#   Brillo promedio: 110.56
#   Contraste: 71.83
#   Color dominante:
#     RGB: (27, 26, 31)
#     Hex: #1b1a1f
#     CSS: rgb(27, 26, 31)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.89%
#
# Imagen: 08 dining at a restaurant person2.jpeg
#   Brillo promedio: 95.31
#   Contraste: 68.64
#   Color dominante:
#     RGB: (16, 34, 25)
#     Hex: #102219
#     CSS: rgb(16, 34, 25)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.90%
#
# Imagen: 08 dining at a restaurant person3.jpeg
#   Brillo promedio: 117.30
#   Contraste: 72.61
#   Color dominante:
#     RGB: (15, 35, 37)
#     Hex: #0f2325
#     CSS: rgb(15, 35, 37)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.86%
#
# Imagen: 08 dining at a restaurant person4.jpeg
#   Brillo promedio: 117.11
#   Contraste: 73.25
#   Color dominante:
#     RGB: (21, 28, 26)
#     Hex: #151c1a
#     CSS: rgb(21, 28, 26)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.88%
#
# Imagen: 09 at the dinning table person1.jpeg
#   Brillo promedio: 103.46
#   Contraste: 70.76
#   Color dominante:
#     RGB: (25, 26, 28)
#     Hex: #191a1c
#     CSS: rgb(25, 26, 28)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.36%
#
# Imagen: 09 at the dinning table person2.jpeg
#   Brillo promedio: 128.12
#   Contraste: 65.76
#   Color dominante:
#     RGB: (198, 192, 11)
#     Hex: #c6c00b
#     CSS: rgb(198, 192, 11)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.68%
#
# Imagen: 09 at the dinning table person3.jpeg
#   Brillo promedio: 143.44
#   Contraste: 71.26
#   Color dominante:
#     RGB: (253, 248, 236)
#     Hex: #fdf8ec
#     CSS: rgb(253, 248, 236)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 1.71%
#
# Imagen: 09 at the dinning table person4.jpeg
#   Brillo promedio: 85.40
#   Contraste: 69.39
#   Color dominante:
#     RGB: (5, 12, 15)
#     Hex: #050c0f
#     CSS: rgb(5, 12, 15)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.73%
#
# Imagen: 10 shopping groceries person 1.jpeg
#   Brillo promedio: 120.95
#   Contraste: 71.92
#   Color dominante:
#     RGB: (26, 27, 31)
#     Hex: #1a1b1f
#     CSS: rgb(26, 27, 31)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.37%
#
# Imagen: 10 shopping groceries person 2.jpeg
#   Brillo promedio: 117.67
#   Contraste: 65.57
#   Color dominante:
#     RGB: (38, 56, 60)
#     Hex: #26383c
#     CSS: rgb(38, 56, 60)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.81%
#
# Imagen: 10 shopping groceries person 3.jpeg
#   Brillo promedio: 116.95
#   Contraste: 63.05
#   Color dominante:
#     RGB: (43, 57, 52)
#     Hex: #2b3934
#     CSS: rgb(43, 57, 52)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.64%
#
# Imagen: 10 shopping groceries person 4.jpeg
#   Brillo promedio: 124.39
#   Contraste: 67.23
#   Color dominante:
#     RGB: (213, 59, 45)
#     Hex: #d53b2d
#     CSS: rgb(213, 59, 45)
# ...
#   Porcentaje del color dominante: 0.85%
#
# Imagen: 75 calling friends older1.jpeg
#   Brillo promedio: 116.58
#   Contraste: 67.29
#   Color dominante:
#     RGB: (67, 53, 40)
#     Hex: #433528
#     CSS: rgb(67, 53, 40)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.70%
#
# Imagen: 75 calling friends older2.jpeg
#   Brillo promedio: 109.02
#   Contraste: 58.59
#   Color dominante:
#     RGB: (51, 48, 40)
#     Hex: #333028
#     CSS: rgb(51, 48, 40)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.58%
#
# Imagen: 75 calling friends older3.jpeg
#   Brillo promedio: 103.86
#   Contraste: 64.09
#   Color dominante:
#     RGB: (39, 36, 33)
#     Hex: #272421
#     CSS: rgb(39, 36, 33)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.74%
#
# Imagen: 75 calling friends older4.jpeg
#   Brillo promedio: 120.73
#   Contraste: 70.72
#   Color dominante:
#     RGB: (29, 34, 38)
#     Hex: #1d2226
#     CSS: rgb(29, 34, 38)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.21%
#
# Imagen: 77 talking older1.jpeg
#   Brillo promedio: 122.99
#   Contraste: 69.94
#   Color dominante:
#     RGB: (241, 13, 16)
#     Hex: #f10d10
#     CSS: rgb(241, 13, 16)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 0.80%
#
# Imagen: 77 talking older2.jpeg
#   Brillo promedio: 96.19
#   Contraste: 59.17
#   Color dominante:
#     RGB: (39, 52, 26)
#     Hex: #27341a
#     CSS: rgb(39, 52, 26)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.72%
#
# Imagen: 77 talking older3.jpeg
#   Brillo promedio: 105.73
#   Contraste: 60.52
#   Color dominante:
#     RGB: (0, 58, 59)
#     Hex: #003a3b
#     CSS: rgb(0, 58, 59)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.53%
#
# Imagen: 77 talking older4.jpeg
#   Brillo promedio: 145.84
#   Contraste: 87.29
#   Color dominante:
#     RGB: (253, 253, 253)
#     Hex: #fdfdfd
#     CSS: rgb(253, 253, 253)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 5.59%
#
# Imagen: 79 staying in touch older1.jpeg
#   Brillo promedio: 115.34
#   Contraste: 68.80
#   Color dominante:
#     RGB: (27, 32, 24)
#     Hex: #1b2018
#     CSS: rgb(27, 32, 24)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.17%
#
# Imagen: 79 staying in touch older2.jpeg
#   Brillo promedio: 109.64
#   Contraste: 64.68
#   Color dominante:
#     RGB: (72, 97, 23)
#     Hex: #486117
#     CSS: rgb(72, 97, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.73%
#
# Imagen: 79 staying in touch older3.jpeg
#   Brillo promedio: 113.84
#   Contraste: 68.09
#   Color dominante:
#     RGB: (10, 157, 18)
#     Hex: #0a9d12
#     CSS: rgb(10, 157, 18)
#     Simplificado: Verde
#   Porcentaje del color dominante: 0.84%
#
# Imagen: 79 staying in touch older4.jpeg
#   Brillo promedio: 112.83
#   Contraste: 64.65
#   Color dominante:
#     RGB: (41, 46, 35)
#     Hex: #292e23
#     CSS: rgb(41, 46, 35)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.87%
#
# Imagen: 81 receiving friends older1.jpeg
#   Brillo promedio: 123.22
#   Contraste: 62.69
#   Color dominante:
#     RGB: (253, 253, 63)
#     Hex: #fdfd3f
#     CSS: rgb(253, 253, 63)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.85%
#
# Imagen: 81 receiving friends older2.jpeg
#   Brillo promedio: 117.87
#   Contraste: 63.47
#   Color dominante:
#     RGB: (253, 46, 38)
#     Hex: #fd2e26
#     CSS: rgb(253, 46, 38)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 1.38%
#
# Imagen: 81 receiving friends older3.jpeg
#   Brillo promedio: 130.57
#   Contraste: 68.48
#   Color dominante:
#     RGB: (252, 253, 45)
#     Hex: #fcfd2d
#     CSS: rgb(252, 253, 45)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 1.53%
#
# Imagen: 81 receiving friends older4.jpeg
#   Brillo promedio: 126.82
#   Contraste: 63.34
#   Color dominante:
#     RGB: (96, 83, 60)
#     Hex: #60533c
#     CSS: rgb(96, 83, 60)
#     Simplificado: Gris
#   Porcentaje del color dominante: 0.65%
#
# Imagen: 82 in a family meeting older1.jpeg
#   Brillo promedio: 127.15
#   Contraste: 68.17
#   Color dominante:
#     RGB: (193, 30, 23)
#     Hex: #c11e17
#     CSS: rgb(193, 30, 23)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 0.90%
#
# Imagen: 82 in a family meeting older2.jpeg
#   Brillo promedio: 122.00
#   Contraste: 68.93
#   Color dominante:
#     RGB: (195, 198, 27)
#     Hex: #c3c61b
#     CSS: rgb(195, 198, 27)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.80%
#
# Imagen: 82 in a family meeting older3.jpeg
#   Brillo promedio: 168.95
#   Contraste: 58.96
#   Color dominante:
#     RGB: (251, 253, 232)
#     Hex: #fbfde8
#     CSS: rgb(251, 253, 232)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 2.59%
#
# Imagen: 82 in a family meeting older4.jpeg
#   Brillo promedio: 146.35
#   Contraste: 68.12
#   Color dominante:
#     RGB: (253, 253, 253)
#     Hex: #fdfdfd
#     CSS: rgb(253, 253, 253)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 2.93%
#
# Imagen: 83 playing games older1.jpeg
#   Brillo promedio: 83.11
#   Contraste: 57.72
#   Color dominante:
#     RGB: (19, 18, 17)
#     Hex: #131211
#     CSS: rgb(19, 18, 17)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.82%
#
# Imagen: 83 playing games older2.jpeg
#   Brillo promedio: 96.96
#   Contraste: 60.67
#   Color dominante:
#     RGB: (39, 38, 38)
#     Hex: #272626
#     CSS: rgb(39, 38, 38)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.16%
#
# Imagen: 83 playing games older3.jpeg
#   Brillo promedio: 124.60
#   Contraste: 69.19
#   Color dominante:
#     RGB: (17, 222, 223)
#     Hex: #11dedf
#     CSS: rgb(17, 222, 223)
#     Simplificado: Cian
#   Porcentaje del color dominante: 0.89%
#
# Imagen: 83 playing games older4.jpeg
#   Brillo promedio: 90.88
#   Contraste: 62.04
#   Color dominante:
#     RGB: (23, 41, 24)
#     Hex: #172918
#     CSS: rgb(23, 41, 24)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.31%
#
# Imagen: 84 having a coffee older1.jpeg
#   Brillo promedio: 80.72
#   Contraste: 62.59
#   Color dominante:
#     RGB: (18, 19, 26)
#     Hex: #12131a
#     CSS: rgb(18, 19, 26)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.28%
#
# Imagen: 84 having a coffee older2.jpeg
#   Brillo promedio: 82.24
#   Contraste: 55.16
#   Color dominante:
#     RGB: (32, 37, 27)
#     Hex: #20251b
#     CSS: rgb(32, 37, 27)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.85%
#
# Imagen: 84 having a coffee older3.jpeg
#   Brillo promedio: 100.15
#   Contraste: 67.66
#   Color dominante:
#     RGB: (16, 17, 18)
#     Hex: #101112
#     CSS: rgb(16, 17, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.80%
#
# Imagen: 84 having a coffee older4.jpeg
#   Brillo promedio: 98.75
#   Contraste: 63.99
#   Color dominante:
#     RGB: (45, 36, 30)
#     Hex: #2d241e
#     CSS: rgb(45, 36, 30)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.78%
#
# Imagen: 85 in a movie night older1.jpeg
#   Brillo promedio: 109.03
#   Contraste: 68.08
#   Color dominante:
#     RGB: (0, 33, 31)
#     Hex: #00211f
#     CSS: rgb(0, 33, 31)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.19%
#
# Imagen: 85 in a movie night older2.jpeg
#   Brillo promedio: 89.07
#   Contraste: 63.80
#   Color dominante:
#     RGB: (9, 29, 12)
#     Hex: #091d0c
#     CSS: rgb(9, 29, 12)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.81%
#
# Imagen: 85 in a movie night older3.jpeg
#   Brillo promedio: 96.43
#   Contraste: 67.71
#   Color dominante:
#     RGB: (27, 24, 27)
#     Hex: #1b181b
#     CSS: rgb(27, 24, 27)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.09%
#
# Imagen: 85 in a movie night older4.jpeg
#   Brillo promedio: 97.86
#   Contraste: 64.04
#   Color dominante:
#     RGB: (33, 25, 23)
#     Hex: #211917
#     CSS: rgb(33, 25, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.97%
#
# Imagen: 86 dining out older1.jpeg
#   Brillo promedio: 87.29
#   Contraste: 73.15
#   Color dominante:
#     RGB: (20, 22, 23)
#     Hex: #141617
#     CSS: rgb(20, 22, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.10%
#
# Imagen: 86 dining out older2.jpeg
#   Brillo promedio: 83.37
#   Contraste: 62.42
#   Color dominante:
#     RGB: (29, 25, 26)
#     Hex: #1d191a
#     CSS: rgb(29, 25, 26)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.10%
#
# Imagen: 86 dining out older3.jpeg
#   Brillo promedio: 94.93
#   Contraste: 63.05
#   Color dominante:
#     RGB: (37, 32, 34)
#     Hex: #252022
#     CSS: rgb(37, 32, 34)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.19%
#
# Imagen: 86 dining out older4.jpeg
#   Brillo promedio: 114.50
#   Contraste: 66.10
#   Color dominante:
#     RGB: (255, 38, 38)
#     Hex: #ff2626
#     CSS: rgb(255, 38, 38)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 1.90%
#
# Imagen: 87 in a club meeting older1.jpeg
#   Brillo promedio: 98.60
#   Contraste: 67.90
#   Color dominante:
#     RGB: (27, 25, 34)
#     Hex: #1b1922
#     CSS: rgb(27, 25, 34)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.53%
#
# Imagen: 87 in a club meeting older2.jpeg
#   Brillo promedio: 85.11
#   Contraste: 64.75
#   Color dominante:
#     RGB: (29, 26, 27)
#     Hex: #1d1a1b
#     CSS: rgb(29, 26, 27)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.11%
#
# Imagen: 87 in a club meeting older3.jpeg
#   Brillo promedio: 82.23
#   Contraste: 66.92
#   Color dominante:
#     RGB: (32, 25, 22)
#     Hex: #201916
#     CSS: rgb(32, 25, 22)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.47%
#
# Imagen: 87 in a club meeting older4.jpeg
#   Brillo promedio: 107.52
#   Contraste: 65.54
#   Color dominante:
#     RGB: (251, 39, 42)
#     Hex: #fb272a
#     CSS: rgb(251, 39, 42)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 1.59%
#
# Imagen: 88 participating in community events older1.jpeg
#   Brillo promedio: 127.48
#   Contraste: 60.37
#   Color dominante:
#     RGB: (181, 69, 55)
#     Hex: #b54537
#     CSS: rgb(181, 69, 55)
#     Simplificado: Gris
#   Porcentaje del color dominante: 0.62%
#
# Imagen: 88 participating in community events older2.jpeg
#   Brillo promedio: 134.01
#   Contraste: 61.92
#   Color dominante:
#     RGB: (234, 188, 19)
#     Hex: #eabc13
#     CSS: rgb(234, 188, 19)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.59%
#
# Imagen: 88 participating in community events older3.jpeg
#   Brillo promedio: 120.59
#   Contraste: 62.50
#   Color dominante:
#     RGB: (34, 33, 32)
#     Hex: #222120
#     CSS: rgb(34, 33, 32)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.65%
#
# Imagen: 88 participating in community events older4.jpeg
#   Brillo promedio: 146.99
#   Contraste: 57.29
#   Color dominante:
#     RGB: (202, 158, 82)
#     Hex: #ca9e52
#     CSS: rgb(202, 158, 82)
#     Simplificado: Gris
#   Porcentaje del color dominante: 0.67%
#
# Imagen: 89 attending a webinar older1.jpeg
#   Brillo promedio: 106.76
#   Contraste: 67.56
#   Color dominante:
#     RGB: (29, 28, 28)
#     Hex: #1d1c1c
#     CSS: rgb(29, 28, 28)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.99%
#
# Imagen: 89 attending a webinar older2.jpeg
#   Brillo promedio: 105.68
#   Contraste: 63.17
#   Color dominante:
#     RGB: (22, 26, 37)
#     Hex: #161a25
#     CSS: rgb(22, 26, 37)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.33%
#
# Imagen: 89 attending a webinar older3.jpeg
#   Brillo promedio: 114.62
#   Contraste: 68.43
#   Color dominante:
#     RGB: (22, 27, 28)
#     Hex: #161b1c
#     CSS: rgb(22, 27, 28)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.20%
#
# Imagen: 89 attending a webinar older4.jpeg
#   Brillo promedio: 101.37
#   Contraste: 67.41
#   Color dominante:
#     RGB: (28, 33, 38)
#     Hex: #1c2126
#     CSS: rgb(28, 33, 38)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.55%
#
# Imagen: 90 attending a conference older1.jpeg
#   Brillo promedio: 77.21
#   Contraste: 60.74
#   Color dominante:
#     RGB: (0, 15, 28)
#     Hex: #000f1c
#     CSS: rgb(0, 15, 28)
#     Simplificado: Negro
#   Porcentaje del color dominante: 7.17%
#
# Imagen: 90 attending a conference older2.jpeg
#   Brillo promedio: 63.23
#   Contraste: 57.05
#   Color dominante:
#     RGB: (11, 19, 29)
#     Hex: #0b131d
#     CSS: rgb(11, 19, 29)
#     Simplificado: Negro
#   Porcentaje del color dominante: 4.12%
#
# Imagen: 90 attending a conference older3.jpeg
#   Brillo promedio: 77.98
#   Contraste: 61.54
#   Color dominante:
#     RGB: (19, 17, 18)
#     Hex: #131112
#     CSS: rgb(19, 17, 18)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.64%
#
# Imagen: 90 attending a conference older4.jpeg
#   Brillo promedio: 78.29
#   Contraste: 59.13
#   Color dominante:
#     RGB: (0, 0, 0)
#     Hex: #000000
#     CSS: rgb(0, 0, 0)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.18%
#
# Imagen: 91 in a study group older1.jpeg
#   Brillo promedio: 126.10
#   Contraste: 71.69
#   Color dominante:
#     RGB: (251, 251, 44)
#     Hex: #fbfb2c
#     CSS: rgb(251, 251, 44)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 1.20%
#
# Imagen: 91 in a study group older2.jpeg
#   Brillo promedio: 124.24
#   Contraste: 69.20
#   Color dominante:
#     RGB: (224, 57, 45)
#     Hex: #e0392d
#     CSS: rgb(224, 57, 45)
#     Simplificado: Rojo
#   Porcentaje del color dominante: 0.79%
#
# Imagen: 91 in a study group older3.jpeg
#   Brillo promedio: 123.38
#   Contraste: 70.07
#   Color dominante:
#     RGB: (252, 253, 255)
#     Hex: #fcfdff
#     CSS: rgb(252, 253, 255)
#     Simplificado: Blanco
#   Porcentaje del color dominante: 1.09%
#
# Imagen: 91 in a study group older4.jpeg
#   Brillo promedio: 124.13
#   Contraste: 68.06
#   Color dominante:
#     RGB: (32, 49, 32)
#     Hex: #203120
#     CSS: rgb(32, 49, 32)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.73%
#
# Imagen: 92 in a football match older1.jpeg
#   Brillo promedio: 108.48
#   Contraste: 70.64
#   Color dominante:
#     RGB: (0, 19, 39)
#     Hex: #001327
#     CSS: rgb(0, 19, 39)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.45%
#
# Imagen: 92 in a football match older2.jpeg
#   Brillo promedio: 141.45
#   Contraste: 70.69
#   Color dominante:
#     RGB: (218, 223, 40)
#     Hex: #dadf28
#     CSS: rgb(218, 223, 40)
#     Simplificado: Amarillo
#   Porcentaje del color dominante: 0.97%
#
# Imagen: 92 in a football match older3.jpeg
#   Brillo promedio: 103.38
#   Contraste: 70.79
#   Color dominante:
#     RGB: (12, 32, 45)
#     Hex: #0c202d
#     CSS: rgb(12, 32, 45)
#     Simplificado: Negro
#   Porcentaje del color dominante: 2.84%
#
# Imagen: 92 in a football match older4.jpeg
#   Brillo promedio: 112.32
#   Contraste: 74.05
#   Color dominante:
#     RGB: (19, 17, 28)
#     Hex: #13111c
#     CSS: rgb(19, 17, 28)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.13%
#
# Imagen: 93 praying older1.jpeg
#   Brillo promedio: 75.85
#   Contraste: 56.64
#   Color dominante:
#     RGB: (0, 18, 20)
#     Hex: #001214
#     CSS: rgb(0, 18, 20)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.60%
#
# Imagen: 93 praying older2.jpeg
#   Brillo promedio: 72.86
#   Contraste: 55.71
#   Color dominante:
#     RGB: (24, 25, 23)
#     Hex: #181917
#     CSS: rgb(24, 25, 23)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.88%
#
# Imagen: 93 praying older3.jpeg
#   Brillo promedio: 96.80
#   Contraste: 58.91
#   Color dominante:
#     RGB: (45, 42, 35)
#     Hex: #2d2a23
#     CSS: rgb(45, 42, 35)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.21%
#
# Imagen: 93 praying older4.jpeg
#   Brillo promedio: 102.73
#   Contraste: 58.52
#   Color dominante:
#     RGB: (36, 39, 33)
#     Hex: #242721
#     CSS: rgb(36, 39, 33)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.93%
#
# Imagen: 94 attending religious services older1.jpeg
#   Brillo promedio: 94.52
#   Contraste: 67.64
#   Color dominante:
#     RGB: (16, 10, 10)
#     Hex: #100a0a
#     CSS: rgb(16, 10, 10)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.85%
#
# Imagen: 94 attending religious services older2.jpeg
#   Brillo promedio: 99.63
#   Contraste: 62.46
#   Color dominante:
#     RGB: (39, 39, 31)
#     Hex: #27271f
#     CSS: rgb(39, 39, 31)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.80%
#
# Imagen: 94 attending religious services older3.jpeg
#   Brillo promedio: 87.36
#   Contraste: 60.19
#   Color dominante:
#     RGB: (21, 37, 26)
#     Hex: #15251a
#     CSS: rgb(21, 37, 26)
#     Simplificado: Negro
#   Porcentaje del color dominante: 1.15%
#
# Imagen: 94 attending religious services older4.jpeg
#   Brillo promedio: 105.09
#   Contraste: 64.44
#   Color dominante:
#     RGB: (27, 40, 35)
#     Hex: #1b2823
#     CSS: rgb(27, 40, 35)
#     Simplificado: Negro
#   Porcentaje del color dominante: 0.73%

# %%
pil_n = pd.DataFrame(resultados_n)
pil_o = pd.DataFrame(resultados_o)
pil = pd.concat([pil_n, pil_o], axis=0)   
df_merged = df_merged.merge(pil, left_on='filename', right_on='filename', how='left')

# %%
df_merged.to_csv(f'{output_dir}/df_merged_copilot_19_8.csv', index=False)
